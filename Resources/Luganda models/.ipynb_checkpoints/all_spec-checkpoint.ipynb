# %% [markdown]
# # Work FLow
# - `Packages and Libraries`
# -  `Load raw audio data` from files in .WAV format that can be processed
# -  `EDA`
# -  `Spectral Representations` Convert the audio signal into a frequency domain representation, such as a spectrogram or mel spectrogram.
# -  `Conversion to TensorFlow` Convert the preprocessed data into a format suitable for the deep learning framework.
# -  `Data Splitting` Split the dataset into training, validation, and testing sets.
# -  `Model Building` Build your machine learning model using the preprocessed data.
# -  `Converting to TFLite model`

# %% [markdown]
# # Packages and Libraries

# %%
import os
import json
import math
import wave
import h5py
import logging
import librosa
import pathlib
import numpy as np
import pandas as pd
import seaborn as sns
import soundfile as sf
import tensorflow as tf 
from sys import getsizeof
from tensorflow import keras
import matplotlib.pyplot as plt
import IPython.display as display
from IPython.display import Audio
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score
# Out:
# 2024-02-26 08:17:46.121927: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-26 08:17:46.226720: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-26 08:17:46.226793: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-26 08:17:46.229519: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-26 08:17:46.251856: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-26 08:17:46.252415: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-26 08:17:48.885615: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
logging.getLogger('tensorflow').setLevel(logging.ERROR)
tf.get_logger().setLevel(logging.ERROR)

# %% [markdown]
# # Loading Raw Audio Data
#
# The dataset's audio clips are of 6 classes and stored in six folders corresponding to each speech command:
# - `ddyo`
# - `kkono`
# - `mu maaso`
# - `emabega`
# - `yimirira`
# - `gaali`

# %% [markdown]
# ## Mount google drive
# adisamproject@gmail.com

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# DATASET_PATH = "/content/drive/My Drive/2_Luganda/dataset"
# data_dir = pathlib.Path(DATASET_PATH)

# %% [markdown]
# ## Dataset path

# %%
TRAIN_DATASET_PATH = 'Dataset/Train'
TEST_DATASET_PATH = 'Dataset/Test'

train_data_dir = pathlib.Path(TRAIN_DATASET_PATH)
test_data_dir = pathlib.Path(TEST_DATASET_PATH)

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Labels (Train and Test Directories)

# %%
commands = np.array(tf.io.gfile.listdir(str(train_data_dir)))
print('Train commands labels:\n', commands)
# Out:
# Train commands labels:
#  ['emabega' 'ddyo' 'gaali' 'kkono' 'mu masso' 'yimirira']

# %%
commands = np.array(tf.io.gfile.listdir(str(test_data_dir)))
print('Test commands labels:\n', commands)
# Out:
# Test commands labels:
#  ['emabega' 'ddyo' 'gaali' 'kkono' 'mu masso' 'yimirira']

# %% [markdown]
# ## Number of audio files

# %%
def count_audio_files_in_subfolders(data_dir):
    counts = {}
    for subfolder in os.listdir(data_dir):
        subfolder_path = os.path.join(data_dir, subfolder)

        if os.path.isdir(subfolder_path):
            audio_files_count = len([f for f in os.listdir(subfolder_path) if f.endswith('.wav')])
            counts[subfolder] = audio_files_count

    return counts

# %% [markdown]
# ### Training dataset

# %%
counts = count_audio_files_in_subfolders(train_data_dir)

# %%
plt.figure(figsize=(12, 5))
plt.barh(list(counts.keys()), list(counts.values()), color='green')
plt.xlabel('Number of Audio Files')
plt.ylabel('Command labels')
plt.title('Number of Audio Files For Training for Each Command')
plt.show()

# %% [markdown]
# ### Test dataset

# %%
counts = count_audio_files_in_subfolders(test_data_dir)

# %%
plt.figure(figsize=(12, 5))
plt.barh(list(counts.keys()), list(counts.values()), color='green')
plt.xlabel('Number of Audio Files')
plt.ylabel('Command labels')
plt.title('Number of Audio Files For Training for Each Command')
plt.show()

# %% [markdown]
# ## Audio Properties and Parameters
# - using one audio file

# %%
SAMPLE_RATE = 16000

# %%
example_audio_path = os.path.join(TRAIN_DATASET_PATH, 'emabega', 'audio #4251.wav')
audio_signal, sample_rate = librosa.load(example_audio_path, sr=SAMPLE_RATE)
audio = wave.open(example_audio_path, 'rb')

# %%
num_channels = audio.getnchannels()
sample_width = audio.getsampwidth()
frame_rate = audio.getframerate()
num_frames = audio.getnframes()
duration = num_frames / float(frame_rate)

# %%
print("Number of channels:    ", num_channels)
print("Sample width (bytes):  ", sample_width)
print("Frame rate (Hz):       ", frame_rate)
print("Number of frames:      ", num_frames)
print("Duration (s):          ", duration)
print("Parameters:            ", audio.getparams())
# Out:
# Number of channels:     1
# Sample width (bytes):   2
# Frame rate (Hz):        16000
# Number of frames:       20160
# Duration (s):           1.26
# Parameters:             _wave_params(nchannels=1, sampwidth=2, framerate=16000, nframes=20160, comptype='NONE', compname='not compressed')

# %%
audio.close()

# %% [markdown]
# ### Visualize the audio waveform

# %%
time = librosa.times_like(audio_signal, sr=SAMPLE_RATE)

plt.figure(figsize=(12, 5))
plt.plot(time, audio_signal)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Audio Signal Waveform')
plt.show()

# %% [markdown]
# ### Amplitude Distribution

# %%
# Calculate statistical summary information
mean_amplitude = np.mean(audio_signal)
std_deviation = np.std(audio_signal)
max_amplitude = np.max(audio_signal)
min_amplitude = np.min(audio_signal)
median_amplitude = np.median(audio_signal)

# Plot the histogram with additional features
plt.figure(figsize=(12, 5))

# Plot the histogram
sns.histplot(audio_signal, bins=50, kde=True)

# Add vertical lines for statistical summary information
plt.axvline(mean_amplitude, color='r', linestyle='--', label=f'Mean: {mean_amplitude:.2f}')
plt.axvline(mean_amplitude + std_deviation, color='g', linestyle='--', label=f'Std Dev: {std_deviation:.2f}')
plt.axvline(mean_amplitude - std_deviation, color='g', linestyle='--')
plt.axvline(median_amplitude, color='b', linestyle='--', label=f'Median: {median_amplitude:.2f}')
plt.axvline(max_amplitude, color='m', linestyle='--', label=f'Max: {max_amplitude:.2f}')
plt.axvline(min_amplitude, color='m', linestyle='--', label=f'Min: {min_amplitude:.2f}')

# Set plot title and labels
plt.title('Amplitude Distribution')
plt.xlabel('Amplitude')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# ### Play audio file

# %%
Audio(example_audio_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Split into Train and validation

# %%
train_ds, val_ds = tf.keras.utils.audio_dataset_from_directory(
    directory=train_data_dir,
    batch_size=64,
    validation_split=0.25,
    seed=0,
    output_sequence_length=SAMPLE_RATE,
    subset='both')

label_names = np.array(train_ds.class_names)
print()
print("label names:", label_names)
# Out:
# Found 3600 files belonging to 6 classes.
# Using 2700 files for training.
# Using 900 files for validation.
#
# label names: ['ddyo' 'emabega' 'gaali' 'kkono' 'mu masso' 'yimirira']

# %% [markdown]
# ## The shape of the audio clip
# - (batch, samples, channels)

# %%
element_spec = train_ds.element_spec
print(element_spec)
# Out:
# (TensorSpec(shape=(None, 16000, None), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))

# %%
def squeeze(audio, labels):
  audio = tf.squeeze(audio, axis=-1)
  return audio, labels

train_ds = train_ds.map(squeeze, tf.data.AUTOTUNE)
val_ds = val_ds.map(squeeze, tf.data.AUTOTUNE)

# %%
test_ds = val_ds.shard(num_shards=2, index=0)
val_ds = val_ds.shard(num_shards=2, index=1)

# %%
for example_audio, example_labels in train_ds.take(1):
  print(example_audio.shape)
  print(example_labels.shape)
# Out:
# (64, 16000)
# (64,)

# %% [markdown]
# # Preparing Test dataset

# %%
test_ds = tf.keras.utils.audio_dataset_from_directory(
    directory=test_data_dir,
    batch_size=64,
    validation_split=None,  # No need to split the test dataset
    seed=0,
    output_sequence_length=SAMPLE_RATE,
    shuffle=False  # Disable shuffling for the test dataset
)

test_ds = test_ds.map(squeeze, tf.data.AUTOTUNE)

# Shard the test dataset
test_ds = test_ds.shard(num_shards=2, index=0)
# Out:
# Found 325 files belonging to 6 classes.

# %%
for example_audio, example_labels in test_ds.take(1):
  print(example_audio.shape)
  print(example_labels.shape)
# Out:
# (64, 16000)
# (64,)

# %% [markdown]
# # Plot a few audio waveforms:

# %%
label_names_slice = label_names[:6]  # Select the first six labels
plt.figure(figsize=(16, 10))
rows = 2
cols = 3
n = rows * cols
for i in range(n):
    plt.subplot(rows, cols, i+1)
    audio_signal = example_audio[i]
    time = librosa.times_like(audio_signal, sr=SAMPLE_RATE)
    plt.plot(time, audio_signal)
    plt.title(label_names_slice[i])
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')
    plt.ylim([-1.1, 1.1])
plt.tight_layout()
plt.show()

# %% [markdown]
# # Feature Extraction

# %%
def get_spectrogram(waveform):
  spectrogram = tf.signal.stft(
      waveform, frame_length=255, frame_step=128)
  spectrogram = tf.abs(spectrogram)
  spectrogram = spectrogram[..., tf.newaxis]
  return spectrogram

# %% [markdown]
# ## Tensorized waveform
# The shapes of a tensorized waveform and the corresponding spectrogram, and play the original audio.

# %%
for i in range(3):
  label = label_names[example_labels[i]]
  waveform = example_audio[i]
  spectrogram = get_spectrogram(waveform)

  print('Label:', label)
  print('Waveform shape:', waveform.shape)
  print('Spectrogram shape:', spectrogram.shape)
  print('Audio playback')
  display.display(display.Audio(waveform, rate=16000))
# Out:
# Label: ddyo
# Waveform shape: (16000,)
# Spectrogram shape: (124, 129, 1)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Label: ddyo
# Waveform shape: (16000,)
# Spectrogram shape: (124, 129, 1)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Label: ddyo
# Waveform shape: (16000,)
# Spectrogram shape: (124, 129, 1)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Visualization of spectrogram

# %%
def plot_spectrogram(spectrogram, ax):
  if len(spectrogram.shape) > 2:
    assert len(spectrogram.shape) == 3
    spectrogram = np.squeeze(spectrogram, axis=-1)
      
  log_spec = np.log(spectrogram.T + np.finfo(float).eps)
  height = log_spec.shape[0]
  width = log_spec.shape[1]
  X = np.linspace(0, np.size(spectrogram), num=width, dtype=int)
  Y = range(height)
  ax.pcolormesh(X, Y, log_spec)

# %% [markdown]
# ### Plot of waveform and spectrogram.

# %%
fig, axes = plt.subplots(2, figsize=(12, 5))
timescale = np.arange(waveform.shape[0])
axes[0].plot(timescale, waveform.numpy())
axes[0].set_title('Waveform')
axes[0].set_xlim([0, 16000])

plot_spectrogram(spectrogram.numpy(), axes[1])
axes[1].set_title('Spectrogram')
plt.suptitle(label.title())
plt.show()

# %% [markdown]
# ## Create spectrogram datasets

# %%
def make_spec_ds(ds):
  return ds.map(
      map_func=lambda audio,label: (get_spectrogram(audio), label),
      num_parallel_calls=tf.data.AUTOTUNE)

# %%
train_spectrogram_ds = make_spec_ds(train_ds)
val_spectrogram_ds = make_spec_ds(val_ds)
test_spectrogram_ds = make_spec_ds(test_ds)

# %% [markdown]
# ## Visualization of the spectrograms

# %%
for example_spectrograms, example_spect_labels in train_spectrogram_ds.take(1):
  break

# %%
rows = 2
cols = 3
n = rows*cols
fig, axes = plt.subplots(rows, cols, figsize=(16, 9))

for i in range(n):
    r = i // cols
    c = i % cols
    ax = axes[r][c]
    plot_spectrogram(example_spectrograms[i].numpy(), ax)
    ax.set_title(label_names[example_spect_labels[i].numpy()])

plt.show()

# %% [markdown]
#  `Dataset.cache` and `Dataset.prefetch` operations to reduce read latency while training the model:

# %%
train_spectrogram_ds = train_spectrogram_ds.cache().shuffle(10000).prefetch(tf.data.AUTOTUNE)
val_spectrogram_ds = val_spectrogram_ds.cache().prefetch(tf.data.AUTOTUNE)
test_spectrogram_ds = test_spectrogram_ds.cache().prefetch(tf.data.AUTOTUNE)

# %%
train_spectrogram_ds
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 124, 129, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %% [markdown]
# # Building Models

# %% [markdown]
# ## Model 1
#
# 1. **Input Layer**: Defines the input shape for the model based on the shape of the spectrogram images.
# 2. **Convolutional Layers**:
#    - 2.1. First Conv2D Layer: Applies 32 filters with a 3x3 kernel size, ReLU activation function, and dilation rate of (2, 2).
#    - 2.2. MaxPooling2D Layer: Performs max pooling to downsample the feature maps.
# 3. **Convolutional Layers**:
#    - 3.1. Second Conv2D Layer: Applies 64 filters with a 3x3 kernel size, ReLU activation function, and dilation rate of (2, 2).
#    - 3.2. MaxPooling2D Layer: Performs max pooling to downsample the feature maps.
# 4. **Convolutional Layers**:
#    - 4.1. Third Conv2D Layer: Applies 128 filters with a 3x3 kernel size, ReLU activation function, and dilation rate of (2, 2).
#    - 4.2. GlobalAveragePooling2D Layer: Performs global average pooling to reduce spatial dimensions.
# 5. **Dense Layers**:
#    - 5.1. Dense Layer: Applies 128 neurons with ReLU activation function.
#    - 5.2. Dropout Layer: Applies dropout regularization with a dropout rate of 0.5.
#    - 5.3. Dense Layer: Outputs logits for each class, with the number of units equal to the number of labels.

# %% [markdown]
# ### Input shape

# %%
input_shape = example_spectrograms.shape[1:]
print('Input shape:', input_shape)
# Out:
# Input shape: (124, 129, 1)

# %% [markdown]
# ### Normalization layer

# %%
num_labels = len(label_names)
norm_layer = layers.Normalization()
norm_layer.adapt(data=train_spectrogram_ds.map(map_func=lambda spec, label: spec))

# %% [markdown]
# ### Model Arch

# %%
model = models.Sequential([
    layers.Input(shape=input_shape),
    layers.Conv2D(32, 3, activation='relu', dilation_rate=(2, 2)),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, activation='relu', dilation_rate=(2, 2)),
    layers.MaxPooling2D(),
    layers.Conv2D(128, 3, activation='relu', dilation_rate=(2, 2)),
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(num_labels),
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 120, 125, 32)      320
#
#  max_pooling2d (MaxPooling2  (None, 60, 62, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 56, 58, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 28, 29, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 24, 25, 128)       73856
#
#  global_average_pooling2d (  (None, 128)               0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               16512
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 109958 (429.52 KB)
# Trainable params: 109958 (429.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Compile the model

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)

# %% [markdown]
# ### Train the model

# %%
EPOCHS = 20
history = model.fit(
    train_spectrogram_ds,
    validation_data=val_spectrogram_ds,
    epochs=EPOCHS,
    callbacks=tf.keras.callbacks.EarlyStopping(verbose=1, patience=2),
)
# Out:
# Epoch 1/20
# 43/43 [==============================] - 32s 658ms/step - loss: 1.5158 - accuracy: 0.3696 - val_loss: 1.0631 - val_accuracy: 0.5603
# Epoch 2/20
# 43/43 [==============================] - 27s 617ms/step - loss: 0.8603 - accuracy: 0.6637 - val_loss: 0.6595 - val_accuracy: 0.7746
# Epoch 3/20
# 43/43 [==============================] - 29s 666ms/step - loss: 0.5711 - accuracy: 0.7948 - val_loss: 0.4174 - val_accuracy: 0.8549
# Epoch 4/20
# 43/43 [==============================] - 29s 679ms/step - loss: 0.4001 - accuracy: 0.8637 - val_loss: 0.4016 - val_accuracy: 0.8638
# Epoch 5/20
# 43/43 [==============================] - 30s 689ms/step - loss: 0.3246 - accuracy: 0.8900 - val_loss: 0.2734 - val_accuracy: 0.9062
# Epoch 6/20
# 43/43 [==============================] - 31s 721ms/step - loss: 0.2653 - accuracy: 0.9148 - val_loss: 0.1974 - val_accuracy: 0.9241
# Epoch 7/20
# 43/43 [==============================] - 32s 754ms/step - loss: 0.2275 - accuracy: 0.9244 - val_loss: 0.2137 - val_accuracy: 0.9129
# Epoch 8/20
# 43/43 [==============================] - 32s 752ms/step - loss: 0.2141 - accuracy: 0.9274 - val_loss: 0.1587 - val_accuracy: 0.9375
# Epoch 9/20
# 43/43 [==============================] - 32s 755ms/step - loss: 0.1999 - accuracy: 0.9259 - val_loss: 0.1629 - val_accuracy: 0.9464
# Epoch 10/20
# 43/43 [==============================] - 33s 758ms/step - loss: 0.1807 - accuracy: 0.9411 - val_loss: 0.1603 - val_accuracy: 0.9263
# Epoch 10: early stopping

# %% [markdown]
# ### Plot Accuracy and Loss

# %%
metrics = history.history
plt.figure(figsize=(14,5))
plt.subplot(1,2,1)
plt.plot(history.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.ylim([0, max(plt.ylim())])
plt.xlabel('Epoch')
plt.ylabel('Loss [CrossEntropy]')

plt.subplot(1,2,2)
plt.plot(history.epoch, 100*np.array(metrics['accuracy']), 100*np.array(metrics['val_accuracy']))
plt.legend(['accuracy', 'val_accuracy'])
plt.ylim([0, 100])
plt.xlabel('Epoch')
plt.ylabel('Accuracy [%]')
# Out:
# Text(0, 0.5, 'Accuracy [%]')

# %% [markdown]
# ### Evaluate the model performance
#
# Run the model on the test set and check the model's performance:

# %%
model.evaluate(test_spectrogram_ds, return_dict=True)
# Out:
# 3/3 [==============================] - 1s 273ms/step - loss: 2.0104 - accuracy: 0.3281
# {'loss': 2.010390043258667, 'accuracy': 0.328125}

# %% [markdown]
# ### Display a confusion matrix

# %%
y_pred = model.predict(test_spectrogram_ds)
y_pred = tf.argmax(y_pred, axis=1)
y_true = tf.concat(list(test_spectrogram_ds.map(lambda s,lab: lab)), axis=0)
# Out:
# 3/3 [==============================] - 1s 266ms/step

# %%
precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# Precision: 0.8066437796537452
# Recall: 0.328125
# F1-score: 0.3543928333986422

# %% [markdown]
# ## Display the confusion matix

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_mtx,
            xticklabels=label_names,
            yticklabels=label_names,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %% [markdown]
# ## Function to determine the size of the model

# %%
def get_file_size(file_path):
    size = os.path.getsize(file_path)
    return size

# %%
def convert_bytes(size, unit=None):
    if unit == "KB":
        return print('File size: ' + str(round(size / 1024, 3)) + ' Kilobytes')
    elif unit == "MB":
        return print('File size: ' + str(round(size / (1024 * 1024), 3)) + ' Megabytes')
    else:
        return print('File size: ' + str(size) + ' bytes')

# %% [markdown]
# ## Tensorflow model

# %%
KERAS_MODEL_NAME = "my_model_1.keras"
model.save(KERAS_MODEL_NAME)

# %%
convert_bytes(get_file_size(KERAS_MODEL_NAME), "MB")
# Out:
# File size: 1.301 Megabytes

# %% [markdown]
# ## TFLite Model for model

# %%
# Convert the model to TensorFlow Lite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the TensorFlow Lite model to a file
with open('model.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# 2024-02-26 08:23:21.615544: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2024-02-26 08:23:21.615582: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2024-02-26 08:23:21.615879: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpeolibl2o
# 2024-02-26 08:23:21.616971: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2024-02-26 08:23:21.616990: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmpeolibl2o
# 2024-02-26 08:23:21.619385: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:388] MLIR V1 optimization pass is not enabled
# 2024-02-26 08:23:21.620431: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2024-02-26 08:23:21.672997: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmpeolibl2o
# 2024-02-26 08:23:21.690794: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 74915 microseconds.
# 2024-02-26 08:23:21.721209: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# Summary on the non-converted ops:
# ---------------------------------
#  * Accepted dialects: tfl, builtin, func
#  * Non-Converted Ops: 17, Total Ops 37, % non-converted = 45.95 %
#  * 17 ARITH ops
#
# - arith.constant:   17 occurrences  (f32: 13, i32: 4)
#
#
#
#   (f32: 3)
#   (f32: 3)
#   (f32: 3)
#   (f32: 2)
#   (f32: 2)
#   (f32: 1)
#   (f32: 3)

# %%
# Load the TensorFlow Lite model:
interpreter = tf.lite.Interpreter(model_path='model.tflite')
interpreter.allocate_tensors()
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %%
# input shape
input_details = interpreter.get_input_details()
input_shape = input_details[0]['shape']
print('Input shape:', input_shape)
# Out:
# Input shape: [  1 124 129   1]

# %%
# output shape
output_details = interpreter.get_output_details()
output_shape = output_details[0]['shape']
print('Output shape:', output_shape)
# Out:
# Output shape: [1 6]

# %%
# Prepare the test dataset 
test_spectrogram_ds = test_spectrogram_ds.unbatch().batch(1)

# %%
# Run inference on the test dataset and collect predictions:
y_true = []
y_pred = []

for spectrogram, label in test_spectrogram_ds:
    # Perform inference
    interpreter.set_tensor(interpreter.get_input_details()[0]['index'], spectrogram)
    interpreter.invoke()
    output = interpreter.get_tensor(interpreter.get_output_details()[0]['index'])

    # Collect predictions
    y_true.append(label.numpy()[0])
    y_pred.append(np.argmax(output))

# %%
accuracy = accuracy_score(y_true, y_pred)
print(f'Accuracy is {int(accuracy*100)}%')
# Out:
# Accuracy is 32%

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 5))
sns.heatmap(confusion_mtx,
            xticklabels=label_names,
            yticklabels=label_names,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %%
convert_bytes(get_file_size("model.tflite"), "KB")
# Out:
# File size: 436.039 Kilobytes

# %% [markdown]
# ## Quntized model

# %%
# Convert the model to TensorFlow Lite format
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the TensorFlow Lite model
with open('model.tflite', 'wb') as f:
    f.write(tflite_model)

# Quantize the TensorFlow Lite model
converter.optimizations = [tf.lite.Optimize.DEFAULT]
quantized_tflite_model = converter.convert()

# Save the quantized TensorFlow Lite model
with open('quantized_model.tflite', 'wb') as f:
    f.write(quantized_tflite_model)
# Out:
# 2024-02-26 08:23:25.942261: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2024-02-26 08:23:25.942292: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2024-02-26 08:23:25.942493: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpynw_hzrr
# 2024-02-26 08:23:25.944042: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2024-02-26 08:23:25.944056: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmpynw_hzrr
# 2024-02-26 08:23:25.947930: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2024-02-26 08:23:25.999234: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmpynw_hzrr
# 2024-02-26 08:23:26.016537: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 74044 microseconds.
# Summary on the non-converted ops:
# ---------------------------------
#  * Accepted dialects: tfl, builtin, func
#  * Non-Converted Ops: 17, Total Ops 37, % non-converted = 45.95 %
#  * 17 ARITH ops
#
# - arith.constant:   17 occurrences  (f32: 13, i32: 4)
#
#
#
#   (f32: 3)
#   (f32: 3)
#   (f32: 3)
#   (f32: 2)
#   (f32: 2)
#   (f32: 1)
#   (f32: 3)
# 2024-02-26 08:23:29.109693: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2024-02-26 08:23:29.109735: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2024-02-26 08:23:29.109944: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmp86b0_wnv
# 2024-02-26 08:23:29.111551: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2024-02-26 08:23:29.111566: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmp86b0_wnv
# 2024-02-26 08:23:29.115619: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2024-02-26 08:23:29.168588: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmp86b0_wnv
# 2024-02-26 08:23:29.185905: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 75960 microseconds.
# Summary on the non-converted ops:
# ---------------------------------
#  * Accepted dialects: tfl, builtin, func
#  * Non-Converted Ops: 14, Total Ops 37, % non-converted = 37.84 %
#  * 14 ARITH ops
#
# - arith.constant:   14 occurrences  (f32: 10, i32: 4)
#
#
#
#   (f32: 3)
#   (f32: 3)
#   (f32: 3)
#   (f32: 2)
#   (f32: 2)
#   (f32: 1)
#   (uq_8: 3)
#   (f32: 3)

# %%
convert_bytes(get_file_size("quantized_model.tflite"), "KB")
# Out:
# File size: 120.414 Kilobytes

# %%
# Evaluate the model on the test dataset
correct = 0
total = 0
for spectrogram, label in test_spectrogram_ds:
    interpreter.set_tensor(input_details[0]['index'], spectrogram)
    interpreter.invoke()
    output = interpreter.get_tensor(output_details[0]['index'])
    predicted_label = np.argmax(output)
    correct += bool(predicted_label == label)  # Convert to boolean
    total += 1

accuracy = correct / total
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.328125

# %%
# Evaluate the model on the test dataset
y_true = []
y_pred = []

for spectrogram, label in test_spectrogram_ds:
    interpreter.set_tensor(input_details[0]['index'], spectrogram)
    interpreter.invoke()
    output = interpreter.get_tensor(output_details[0]['index'])
    predicted_label = np.argmax(output)
    y_true.append(label)
    y_pred.append(predicted_label)


confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_mtx,
            xticklabels=label_names,
            yticklabels=label_names,
            annot=True, fmt='g')
plt.title('Confusion Matrix')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %%
accuracy = accuracy_score(y_true, y_pred)
print(f'Accuracy is {int(accuracy*100)}%')
# Out:
# Accuracy is 32%

# %% [markdown]
# ## Model 2
#
# 1. Input layer: Accepts input data of shape `input_shape`.
# 2. Conv2D layer with 32 filters, kernel size 3x3, and ReLU activation. Dilated convolution with dilation rate (2, 2).
# 3. MaxPooling2D layer.
# 4. Conv2D layer with 64 filters, kernel size 3x3, and ReLU activation. Dilated convolution with dilation rate (2, 2).
# 5. GlobalAveragePooling2D layer: Reduces spatial dimensions to 1x1.
# 6. Dense layer with 64 neurons and ReLU activation.
# 7. Dropout layer with dropout rate of 0.5.
# 8. Dense output layer with `num_labels` neurons (output classes).

# %% [markdown]
# ### Input shape

# %%
input_shape = example_spectrograms.shape[1:]
print('Input shape:', input_shape)
num_labels = len(label_names)
# Out:
# Input shape: (124, 129, 1)

# %% [markdown]
# ### Model Arch

# %%
model2 = models.Sequential([
    layers.Input(shape=input_shape),
    layers.Conv2D(32, 3, activation='relu', dilation_rate=(2, 2)),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, activation='relu', dilation_rate=(2, 2)),
    layers.GlobalAveragePooling2D(),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(num_labels),
])

model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 120, 125, 32)      320
#
#  max_pooling2d_2 (MaxPoolin  (None, 60, 62, 32)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 56, 58, 64)        18496
#
#  global_average_pooling2d_1  (None, 64)                0
#   (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 6)                 390
#
# =================================================================
# Total params: 23366 (91.27 KB)
# Trainable params: 23366 (91.27 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Compile the model

# %%
model2.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)

# %% [markdown]
# ### Train the model

# %%
EPOCHS = 20
history = model2.fit(
    train_spectrogram_ds,
    validation_data=val_spectrogram_ds,
    epochs=EPOCHS,
    callbacks=tf.keras.callbacks.EarlyStopping(verbose=1, patience=2),
)
# Out:
# Epoch 1/20
# 43/43 [==============================] - 27s 610ms/step - loss: 1.7518 - accuracy: 0.2207 - val_loss: 1.6690 - val_accuracy: 0.2723
# Epoch 2/20
# 43/43 [==============================] - 26s 612ms/step - loss: 1.5751 - accuracy: 0.3570 - val_loss: 1.3986 - val_accuracy: 0.5134
# Epoch 3/20
# 43/43 [==============================] - 26s 612ms/step - loss: 1.3097 - accuracy: 0.4652 - val_loss: 1.1334 - val_accuracy: 0.6451
# Epoch 4/20
# 43/43 [==============================] - 26s 594ms/step - loss: 1.1210 - accuracy: 0.5522 - val_loss: 0.9610 - val_accuracy: 0.6853
# Epoch 5/20
# 43/43 [==============================] - 26s 599ms/step - loss: 0.9373 - accuracy: 0.6344 - val_loss: 0.7989 - val_accuracy: 0.7143
# Epoch 6/20
# 43/43 [==============================] - 26s 600ms/step - loss: 0.8444 - accuracy: 0.6748 - val_loss: 0.6847 - val_accuracy: 0.7567
# Epoch 7/20
# 43/43 [==============================] - 25s 593ms/step - loss: 0.7289 - accuracy: 0.7211 - val_loss: 0.5947 - val_accuracy: 0.7746
# Epoch 8/20
# 43/43 [==============================] - 26s 598ms/step - loss: 0.6659 - accuracy: 0.7504 - val_loss: 0.5413 - val_accuracy: 0.7857
# Epoch 9/20
# 43/43 [==============================] - 26s 607ms/step - loss: 0.6061 - accuracy: 0.7730 - val_loss: 0.4832 - val_accuracy: 0.8036
# Epoch 10/20
# 43/43 [==============================] - 26s 599ms/step - loss: 0.5861 - accuracy: 0.7607 - val_loss: 0.4685 - val_accuracy: 0.8125
# Epoch 11/20
# 43/43 [==============================] - 26s 598ms/step - loss: 0.5379 - accuracy: 0.7941 - val_loss: 0.4314 - val_accuracy: 0.8080
# Epoch 12/20
# 43/43 [==============================] - 26s 598ms/step - loss: 0.5118 - accuracy: 0.8059 - val_loss: 0.4099 - val_accuracy: 0.8259
# Epoch 13/20
# 43/43 [==============================] - 26s 599ms/step - loss: 0.5063 - accuracy: 0.7989 - val_loss: 0.4082 - val_accuracy: 0.8348
# Epoch 14/20
# 43/43 [==============================] - 26s 602ms/step - loss: 0.4652 - accuracy: 0.8181 - val_loss: 0.3827 - val_accuracy: 0.8281
# Epoch 15/20
# 43/43 [==============================] - 26s 600ms/step - loss: 0.4598 - accuracy: 0.8259 - val_loss: 0.3808 - val_accuracy: 0.8326
# Epoch 16/20
# 43/43 [==============================] - 26s 601ms/step - loss: 0.4496 - accuracy: 0.8252 - val_loss: 0.3397 - val_accuracy: 0.8393
# Epoch 17/20
# 43/43 [==============================] - 26s 599ms/step - loss: 0.4322 - accuracy: 0.8407 - val_loss: 0.3436 - val_accuracy: 0.8661
# Epoch 18/20
# 43/43 [==============================] - 26s 612ms/step - loss: 0.4179 - accuracy: 0.8363 - val_loss: 0.3325 - val_accuracy: 0.8638
# Epoch 19/20
# 43/43 [==============================] - 26s 600ms/step - loss: 0.4176 - accuracy: 0.8352 - val_loss: 0.3196 - val_accuracy: 0.8594
# Epoch 20/20
# 43/43 [==============================] - 26s 599ms/step - loss: 0.3831 - accuracy: 0.8478 - val_loss: 0.3212 - val_accuracy: 0.8571

# %% [markdown]
# ### Plot Accuracy and Loss

# %%
metrics = history.history
plt.figure(figsize=(14,5))
plt.subplot(1,2,1)
plt.plot(history.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.ylim([0, max(plt.ylim())])
plt.xlabel('Epoch')
plt.ylabel('Loss [CrossEntropy]')

plt.subplot(1,2,2)
plt.plot(history.epoch, 100*np.array(metrics['accuracy']), 100*np.array(metrics['val_accuracy']))
plt.legend(['accuracy', 'val_accuracy'])
plt.ylim([0, 100])
plt.xlabel('Epoch')
plt.ylabel('Accuracy [%]')
# Out:
# Text(0, 0.5, 'Accuracy [%]')

# %% [markdown]
# ### Evaluate the model performance
#
# Run the model on the test set and check the model's performance:

# %%
model2.evaluate(test_spectrogram_ds, return_dict=True)
# Out:
# 192/192 [==============================] - 1s 4ms/step - loss: 2.9163 - accuracy: 0.1927
# {'loss': 2.916294813156128, 'accuracy': 0.1927083283662796}

# %%
y_pred = model2.predict(test_spectrogram_ds)
y_pred = tf.argmax(y_pred, axis=1)
y_true = tf.concat(list(test_spectrogram_ds.map(lambda s,lab: lab)), axis=0)
# Out:
# 192/192 [==============================] - 1s 4ms/step

# %%
precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# Precision: 0.5775917202818627
# Recall: 0.19270833333333334
# F1-score: 0.22973671463988365

# %% [markdown]
# ### Display the confusion matix

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_mtx,
            xticklabels=label_names,
            yticklabels=label_names,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %% [markdown]
# ## Function to determine the size of the model

# %%
def get_file_size(file_path):
    size = os.path.getsize(file_path)
    return size

# %%
def convert_bytes(size, unit=None):
    if unit == "KB":
        return print('File size: ' + str(round(size / 1024, 3)) + ' Kilobytes')
    elif unit == "MB":
        return print('File size: ' + str(round(size / (1024 * 1024), 3)) + ' Megabytes')
    else:
        return print('File size: ' + str(size) + ' bytes')

# %% [markdown]
# ## Tensorflow model

# %%
KERAS_MODEL_NAME = "my_model_2.keras"
model2.save(KERAS_MODEL_NAME)

# %%
convert_bytes(get_file_size(KERAS_MODEL_NAME), "KB")
# Out:
# File size: 310.559 Kilobytes

# %% [markdown]
# ## TFLite Model for model

# %%
# Convert the model to TensorFlow Lite
converter = tf.lite.TFLiteConverter.from_keras_model(model2)
tflite_model = converter.convert()

# Save the TensorFlow Lite model to a file
with open('model2.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# 2024-02-26 08:32:14.567984: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2024-02-26 08:32:14.568022: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2024-02-26 08:32:14.568242: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmp2_hj9qdk
# 2024-02-26 08:32:14.569747: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2024-02-26 08:32:14.569762: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmp2_hj9qdk
# 2024-02-26 08:32:14.573539: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2024-02-26 08:32:14.621940: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmp2_hj9qdk
# 2024-02-26 08:32:14.634864: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 66623 microseconds.
# Summary on the non-converted ops:
# ---------------------------------
#  * Accepted dialects: tfl, builtin, func
#  * Non-Converted Ops: 14, Total Ops 29, % non-converted = 48.28 %
#  * 14 ARITH ops
#
# - arith.constant:   14 occurrences  (f32: 10, i32: 4)
#
#
#
#   (f32: 2)
#   (f32: 2)
#   (f32: 2)
#   (f32: 2)
#   (f32: 1)
#   (f32: 1)
#   (f32: 2)

# %%
# Load the TensorFlow Lite model:
interpreter = tf.lite.Interpreter(model_path='model2.tflite')
interpreter.allocate_tensors()

# %%
# input shape
input_details = interpreter.get_input_details()
input_shape = input_details[0]['shape']
print('Input shape:', input_shape)
# Out:
# Input shape: [  1 124 129   1]

# %%
# output shape
output_details = interpreter.get_output_details()
output_shape = output_details[0]['shape']
print('Output shape:', output_shape)
# Out:
# Output shape: [1 6]

# %%
# Prepare the test dataset 
test_spectrogram_ds = test_spectrogram_ds.unbatch().batch(1)

# %%
# Run inference on the test dataset and collect predictions:
y_true = []
y_pred = []

for spectrogram, label in test_spectrogram_ds:
    # Perform inference
    interpreter.set_tensor(interpreter.get_input_details()[0]['index'], spectrogram)
    interpreter.invoke()
    output = interpreter.get_tensor(interpreter.get_output_details()[0]['index'])

    # Collect predictions
    y_true.append(label.numpy()[0])
    y_pred.append(np.argmax(output))

# %%
accuracy = accuracy_score(y_true, y_pred)
print(f'Accuracy is {int(accuracy*100)}%')
# Out:
# Accuracy is 19%

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 4))
sns.heatmap(confusion_mtx,
            xticklabels=label_names,
            yticklabels=label_names,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %%
convert_bytes(get_file_size("model2.tflite"), "KB")
# Out:
# File size: 96.195 Kilobytes

# %% [markdown]
# ## Quntized model

# %%
# Convert the model to TensorFlow Lite format
converter = tf.lite.TFLiteConverter.from_keras_model(model2)
tflite_model = converter.convert()

# Save the TensorFlow Lite model
with open('model2.tflite', 'wb') as f:
    f.write(tflite_model)

# Quantize the TensorFlow Lite model
converter.optimizations = [tf.lite.Optimize.DEFAULT]
quantized_tflite_model = converter.convert()

# Save the quantized TensorFlow Lite model
with open('quantized_model.tflite', 'wb') as f:
    f.write(quantized_tflite_model)
# Out:
# 2024-02-26 08:32:18.237666: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2024-02-26 08:32:18.237707: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2024-02-26 08:32:18.237929: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpun9pwgum
# 2024-02-26 08:32:18.239386: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2024-02-26 08:32:18.239402: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmpun9pwgum
# 2024-02-26 08:32:18.243062: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2024-02-26 08:32:18.290877: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmpun9pwgum
# 2024-02-26 08:32:18.306249: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 68320 microseconds.
# Summary on the non-converted ops:
# ---------------------------------
#  * Accepted dialects: tfl, builtin, func
#  * Non-Converted Ops: 14, Total Ops 29, % non-converted = 48.28 %
#  * 14 ARITH ops
#
# - arith.constant:   14 occurrences  (f32: 10, i32: 4)
#
#
#
#   (f32: 2)
#   (f32: 2)
#   (f32: 2)
#   (f32: 2)
#   (f32: 1)
#   (f32: 1)
#   (f32: 2)
# 2024-02-26 08:32:21.309026: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2024-02-26 08:32:21.309059: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2024-02-26 08:32:21.309276: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmp_vi1ow2u
# 2024-02-26 08:32:21.311546: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2024-02-26 08:32:21.311584: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmp_vi1ow2u
# 2024-02-26 08:32:21.316352: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2024-02-26 08:32:21.369534: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmp_vi1ow2u
# 2024-02-26 08:32:21.386911: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 77635 microseconds.
# Summary on the non-converted ops:
# ---------------------------------
#  * Accepted dialects: tfl, builtin, func
#  * Non-Converted Ops: 12, Total Ops 29, % non-converted = 41.38 %
#  * 12 ARITH ops
#
# - arith.constant:   12 occurrences  (f32: 8, i32: 4)
#
#
#
#   (f32: 2)
#   (f32: 2)
#   (f32: 2)
#   (f32: 2)
#   (f32: 1)
#   (f32: 1)
#   (uq_8: 2)
#   (f32: 2)

# %%
convert_bytes(get_file_size("quantized_model.tflite"), "KB")
# Out:
# File size: 31.047 Kilobytes

# %%
# Evaluate the model on the test dataset
correct = 0
total = 0
for spectrogram, label in test_spectrogram_ds:
    interpreter.set_tensor(input_details[0]['index'], spectrogram)
    interpreter.invoke()
    output = interpreter.get_tensor(output_details[0]['index'])
    predicted_label = np.argmax(output)
    correct += bool(predicted_label == label)  # Convert to boolean
    total += 1

accuracy = correct / total
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.19270833333333334

# %%
# Evaluate the model on the test dataset
y_true = []
y_pred = []

for spectrogram, label in test_spectrogram_ds:
    interpreter.set_tensor(input_details[0]['index'], spectrogram)
    interpreter.invoke()
    output = interpreter.get_tensor(output_details[0]['index'])
    predicted_label = np.argmax(output)
    y_true.append(label)
    y_pred.append(predicted_label)


confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_mtx,
            xticklabels=label_names,
            yticklabels=label_names,
            annot=True, fmt='g')
plt.title('Confusion Matrix')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %%
accuracy = accuracy_score(y_true, y_pred)
print(f'Accuracy is {int(accuracy*100)}%')
# Out:
# Accuracy is 19%

# %% [markdown]
# ## Model 3
#
# 1. **Input Layer:** Defines the input shape for the model based on the shape of the spectrogram images.
# 2. **Resizing Layer:** Resizes the input spectrogram images to a fixed size of 32x32 pixels.
# 3. **Normalization Layer:** Normalizes the input data using statistics computed from the training dataset.
# 4. **Convolutional Layers:** Two Conv2D layers with ReLU activation functions, followed by max pooling.
# 5. **Dropout Layer:** Applies dropout regularization to prevent overfitting.
# 6. **Flatten Layer:** Flattens the output of the previous layer into a 1D vector.
# 7. **Dense Layers:** Two Dense layers with ReLU activation functions, followed by the output layer with logits for each class.

# %% [markdown]
# ### Input shape

# %%
input_shape = example_spectrograms.shape[1:]
print('Input shape:', input_shape)
num_labels = len(label_names)
# Out:
# Input shape: (124, 129, 1)

# %% [markdown]
# ### Model Arch

# %%
model3 = models.Sequential([
    layers.Input(shape=input_shape),
    layers.Resizing(32, 32),
    norm_layer,
    layers.Conv2D(32, 3, activation='relu'),
    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Dropout(0.25),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(num_labels),
])

model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resizing (Resizing)         (None, 32, 32, 1)         0
#
#  normalization (Normalizati  (None, 32, 32, 1)         3
#  on)
#
#  conv2d_5 (Conv2D)           (None, 30, 30, 32)        320
#
#  conv2d_6 (Conv2D)           (None, 28, 28, 64)        18496
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 64)        0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 14, 14, 64)        0
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense_4 (Dense)             (None, 128)               1605760
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 1625353 (6.20 MB)
# Trainable params: 1625350 (6.20 MB)
# Non-trainable params: 3 (16.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Compile the model

# %%
model3.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)

# %% [markdown]
# ### Train the model

# %%
EPOCHS = 20
history = model3.fit(
    train_spectrogram_ds,
    validation_data=val_spectrogram_ds,
    epochs=EPOCHS,
    callbacks=tf.keras.callbacks.EarlyStopping(verbose=1, patience=2),
)
# Out:
# Epoch 1/20
# 43/43 [==============================] - 4s 77ms/step - loss: 0.8707 - accuracy: 0.6656 - val_loss: 0.4282 - val_accuracy: 0.8594
# Epoch 2/20
# 43/43 [==============================] - 3s 73ms/step - loss: 0.3634 - accuracy: 0.8807 - val_loss: 0.1971 - val_accuracy: 0.9464
# Epoch 3/20
# 43/43 [==============================] - 4s 93ms/step - loss: 0.2241 - accuracy: 0.9226 - val_loss: 0.1521 - val_accuracy: 0.9397
# Epoch 4/20
# 43/43 [==============================] - 4s 92ms/step - loss: 0.1611 - accuracy: 0.9470 - val_loss: 0.1272 - val_accuracy: 0.9576
# Epoch 5/20
# 43/43 [==============================] - 4s 88ms/step - loss: 0.1261 - accuracy: 0.9570 - val_loss: 0.0984 - val_accuracy: 0.9665
# Epoch 6/20
# 43/43 [==============================] - 4s 82ms/step - loss: 0.1046 - accuracy: 0.9633 - val_loss: 0.0816 - val_accuracy: 0.9688
# Epoch 7/20
# 43/43 [==============================] - 4s 90ms/step - loss: 0.0901 - accuracy: 0.9674 - val_loss: 0.0711 - val_accuracy: 0.9777
# Epoch 8/20
# 43/43 [==============================] - 4s 96ms/step - loss: 0.0901 - accuracy: 0.9726 - val_loss: 0.0601 - val_accuracy: 0.9777
# Epoch 9/20
# 43/43 [==============================] - 4s 91ms/step - loss: 0.0682 - accuracy: 0.9789 - val_loss: 0.0612 - val_accuracy: 0.9754
# Epoch 10/20
# 43/43 [==============================] - 4s 88ms/step - loss: 0.0621 - accuracy: 0.9793 - val_loss: 0.0481 - val_accuracy: 0.9799
# Epoch 11/20
# 43/43 [==============================] - 4s 97ms/step - loss: 0.0472 - accuracy: 0.9830 - val_loss: 0.0346 - val_accuracy: 0.9911
# Epoch 12/20
# 43/43 [==============================] - 4s 92ms/step - loss: 0.0466 - accuracy: 0.9848 - val_loss: 0.0415 - val_accuracy: 0.9777
# Epoch 13/20
# 43/43 [==============================] - 4s 96ms/step - loss: 0.0376 - accuracy: 0.9874 - val_loss: 0.0455 - val_accuracy: 0.9777
# Epoch 13: early stopping

# %% [markdown]
# ### Plot Accuracy and Loss

# %%
metrics = history.history
plt.figure(figsize=(14,5))
plt.subplot(1,2,1)
plt.plot(history.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.ylim([0, max(plt.ylim())])
plt.xlabel('Epoch')
plt.ylabel('Loss [CrossEntropy]')

plt.subplot(1,2,2)
plt.plot(history.epoch, 100*np.array(metrics['accuracy']), 100*np.array(metrics['val_accuracy']))
plt.legend(['accuracy', 'val_accuracy'])
plt.ylim([0, 100])
plt.xlabel('Epoch')
plt.ylabel('Accuracy [%]')
# Out:
# Text(0, 0.5, 'Accuracy [%]')

# %% [markdown]
# ### Evaluate the model performance
#
# Run the model on the test set and check the model's performance:

# %%
model3.evaluate(test_spectrogram_ds, return_dict=True)
# Out:
# 192/192 [==============================] - 0s 2ms/step - loss: 3.7039 - accuracy: 0.1562
# {'loss': 3.7039308547973633, 'accuracy': 0.15625}

# %%
y_pred = model3.predict(test_spectrogram_ds)
y_pred = tf.argmax(y_pred, axis=1)
y_true = tf.concat(list(test_spectrogram_ds.map(lambda s,lab: lab)), axis=0)
# Out:
# 192/192 [==============================] - 0s 2ms/step

# %%
precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# Precision: 0.46655426412206435
# Recall: 0.15625
# F1-score: 0.18592785493827158

# %% [markdown]
# ### Display the confusion matix

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_mtx,
            xticklabels=label_names,
            yticklabels=label_names,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %% [markdown]
# ## Function to determine the size of the model

# %%
def get_file_size(file_path):
    size = os.path.getsize(file_path)
    return size

# %%
def convert_bytes(size, unit=None):
    if unit == "KB":
        return print('File size: ' + str(round(size / 1024, 3)) + ' Kilobytes')
    elif unit == "MB":
        return print('File size: ' + str(round(size / (1024 * 1024), 3)) + ' Megabytes')
    else:
        return print('File size: ' + str(size) + ' bytes')

# %% [markdown]
# ## Tensorflow model

# %%
KERAS_MODEL_NAME = "my_model_3.keras"
model.save(KERAS_MODEL_NAME)

# %%
convert_bytes(get_file_size(KERAS_MODEL_NAME), "MB")
# Out:
# File size: 1.301 Megabytes

# %% [markdown]
# ## TFLite Model for model

# %%
# Convert the model to TensorFlow Lite
converter = tf.lite.TFLiteConverter.from_keras_model(model3)
tflite_model = converter.convert()

# Save the TensorFlow Lite model to a file
with open('model3.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# 2024-02-26 08:33:18.985961: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2024-02-26 08:33:18.985996: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2024-02-26 08:33:18.986220: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpsflcngm1
# 2024-02-26 08:33:18.987914: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2024-02-26 08:33:18.987929: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmpsflcngm1
# 2024-02-26 08:33:18.993895: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2024-02-26 08:33:19.062239: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmpsflcngm1
# 2024-02-26 08:33:19.077137: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 90917 microseconds.
# Summary on the non-converted ops:
# ---------------------------------
#  * Accepted dialects: tfl, builtin, func
#  * Non-Converted Ops: 10, Total Ops 20, % non-converted = 50.00 %
#  * 10 ARITH ops
#
# - arith.constant:   10 occurrences  (f32: 8, i32: 2)
#
#
#
#   (f32: 2)
#   (f32: 2)
#   (f32: 1)
#   (f32: 1)
#   (f32: 1)

# %%
# Load the TensorFlow Lite model:
interpreter = tf.lite.Interpreter(model_path='model3.tflite')
interpreter.allocate_tensors()

# %%
# input shape
input_details = interpreter.get_input_details()
input_shape = input_details[0]['shape']
print('Input shape:', input_shape)
# Out:
# Input shape: [  1 124 129   1]

# %%
# output shape
output_details = interpreter.get_output_details()
output_shape = output_details[0]['shape']
print('Output shape:', output_shape)
# Out:
# Output shape: [1 6]

# %%
# Prepare the test dataset 
test_spectrogram_ds = test_spectrogram_ds.unbatch().batch(1)

# %%
# Run inference on the test dataset and collect predictions:
y_true = []
y_pred = []

for spectrogram, label in test_spectrogram_ds:
    # Perform inference
    interpreter.set_tensor(interpreter.get_input_details()[0]['index'], spectrogram)
    interpreter.invoke()
    output = interpreter.get_tensor(interpreter.get_output_details()[0]['index'])

    # Collect predictions
    y_true.append(label.numpy()[0])
    y_pred.append(np.argmax(output))

# %%
accuracy = accuracy_score(y_true, y_pred)
print(f'Accuracy is {int(accuracy*100)}%')
# Out:
# Accuracy is 15%

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 4))
sns.heatmap(confusion_mtx,
            xticklabels=label_names,
            yticklabels=label_names,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %%
convert_bytes(get_file_size("model3.tflite"), "MB")
# Out:
# File size: 6.204 Megabytes

# %% [markdown]
# ## Quntized model

# %%
# Convert the model to TensorFlow Lite format
converter = tf.lite.TFLiteConverter.from_keras_model(model3)
tflite_model = converter.convert()

# Save the TensorFlow Lite model
with open('model3.tflite', 'wb') as f:
    f.write(tflite_model)

# Quantize the TensorFlow Lite model
converter.optimizations = [tf.lite.Optimize.DEFAULT]
quantized_tflite_model = converter.convert()

# Save the quantized TensorFlow Lite model
with open('quantized_model.tflite', 'wb') as f:
    f.write(quantized_tflite_model)
# Out:
# 2024-02-26 08:33:23.350859: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2024-02-26 08:33:23.350892: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2024-02-26 08:33:23.351104: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpgff2lpca
# 2024-02-26 08:33:23.352803: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2024-02-26 08:33:23.352818: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmpgff2lpca
# 2024-02-26 08:33:23.357310: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2024-02-26 08:33:23.418375: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmpgff2lpca
# 2024-02-26 08:33:23.434639: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 83534 microseconds.
# Summary on the non-converted ops:
# ---------------------------------
#  * Accepted dialects: tfl, builtin, func
#  * Non-Converted Ops: 10, Total Ops 20, % non-converted = 50.00 %
#  * 10 ARITH ops
#
# - arith.constant:   10 occurrences  (f32: 8, i32: 2)
#
#
#
#   (f32: 2)
#   (f32: 2)
#   (f32: 1)
#   (f32: 1)
#   (f32: 1)
# 2024-02-26 08:33:26.705828: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2024-02-26 08:33:26.705863: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2024-02-26 08:33:26.706068: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmp4xsgxdpq
# 2024-02-26 08:33:26.707655: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2024-02-26 08:33:26.707668: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmp4xsgxdpq
# 2024-02-26 08:33:26.711496: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2024-02-26 08:33:26.768196: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmp4xsgxdpq
# 2024-02-26 08:33:26.781216: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 75148 microseconds.
# Summary on the non-converted ops:
# ---------------------------------
#  * Accepted dialects: tfl, builtin, func
#  * Non-Converted Ops: 8, Total Ops 20, % non-converted = 40.00 %
#  * 8 ARITH ops
#
# - arith.constant:    8 occurrences  (f32: 6, i32: 2)
#
#
#
#   (f32: 2)
#   (f32: 2)
#   (f32: 1)
#   (uq_8: 2)
#   (f32: 1)
#   (f32: 1)

# %%
convert_bytes(get_file_size("quantized_model.tflite"), "KB")
# Out:
# File size: 1595.375 Kilobytes

# %%
# Evaluate the model on the test dataset
correct = 0
total = 0
for spectrogram, label in test_spectrogram_ds:
    interpreter.set_tensor(input_details[0]['index'], spectrogram)
    interpreter.invoke()
    output = interpreter.get_tensor(output_details[0]['index'])
    predicted_label = np.argmax(output)
    correct += bool(predicted_label == label)  # Convert to boolean
    total += 1

accuracy = correct / total
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.15625

# %%
# Evaluate the model on the test dataset
y_true = []
y_pred = []

for spectrogram, label in test_spectrogram_ds:
    interpreter.set_tensor(input_details[0]['index'], spectrogram)
    interpreter.invoke()
    output = interpreter.get_tensor(output_details[0]['index'])
    predicted_label = np.argmax(output)
    y_true.append(label)
    y_pred.append(predicted_label)


confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_mtx,
            xticklabels=label_names,
            yticklabels=label_names,
            annot=True, fmt='g')
plt.title('Confusion Matrix')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %%
accuracy = accuracy_score(y_true, y_pred)
print(f'Accuracy is {int(accuracy*100)}%')
# Out:
# Accuracy is 15%
