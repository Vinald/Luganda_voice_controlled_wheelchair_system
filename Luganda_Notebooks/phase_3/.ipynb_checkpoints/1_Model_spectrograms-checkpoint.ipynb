# %% [markdown]
# # Work FLow
# - `Packages and Libraries`
# -  `Load raw audio data` from files in .WAV format that can be processed
# -  `EDA`
# -  `Spectral Representations` Convert the audio signal into a frequency domain representation, such as a spectrogram or mel spectrogram.
# -  `Conversion to TensorFlow` Convert the preprocessed data into a format suitable for the deep learning framework.
# -  `Data Splitting` Split the dataset into training, validation, and testing sets.
# -  `Model Building` Build your machine learning model using the preprocessed data.
# -  `Converting to TFLite model`

# %% [markdown]
# # Packages and Libraries

# %%
import os
import pathlib
import wave
import shutil

import librosa

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import soundfile as sf

import IPython.display as display

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models

from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split
# Out:
# 2024-03-08 13:30:12.840419: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-03-08 13:30:12.876481: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-08 13:30:12.876513: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-08 13:30:12.877437: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-08 13:30:12.882539: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-03-08 13:30:12.882987: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-08 13:30:13.784211: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
SAMPLE_RATE = 16000

# %% [markdown]
# # Loading Raw Audio Data File Paths
#
# The dataset's audio clips are of 6 classes and stored in six folders corresponding to each speech command:
# - `ddyo`
# - `kkono`
# - `mu maaso`
# - `emabega`
# - `yimirira`
# - `gaali`

# %%
TRAIN_DATASET_PATH = 'Dataset/Train'
TEST_DATASET_PATH = 'Dataset/Test'

PROCESS_TRAIN_DATASET_PATH = 'Dataset/Process_train'
PROCESS_TEST_DATASET_PATH = 'Dataset/Process_test'


train_data_dir = pathlib.Path(TRAIN_DATASET_PATH)
test_data_dir = pathlib.Path(TEST_DATASET_PATH)

process_train_data_dir = pathlib.Path(PROCESS_TRAIN_DATASET_PATH)
process_test_data_dir = pathlib.Path(PROCESS_TEST_DATASET_PATH)

# %% [markdown]
# # Functions

# %% [markdown]
# ## 1. Duration(2s), and channel (mono) check function

# %%
def move_audio_files(data_dir, process_folder):
    if not os.path.exists(process_folder):
        os.makedirs(process_folder)

    for subfolder in os.listdir(data_dir):
        subfolder_path = os.path.join(data_dir, subfolder)
        if os.path.isdir(subfolder_path):
            for audio_file in os.listdir(subfolder_path):
                audio_path = os.path.join(subfolder_path, audio_file)
                try:
                    # Get audio length and number of channels
                    with wave.open(audio_path, 'r') as wav_file:
                        audio_length = wav_file.getnframes() / wav_file.getframerate()
                        num_channels = wav_file.getnchannels()

                    if audio_length > 2.0 or num_channels != 1:
                        # Move the audio file to the process folder
                        shutil.move(audio_path, os.path.join(process_folder, audio_file))
                except Exception as e:
                    print(f"Error processing {audio_path}: {e}")


move_audio_files(train_data_dir, process_train_data_dir)
move_audio_files(test_data_dir, process_test_data_dir)

# %% [markdown]
# ## 2. Count audio files function

# %%
def count_audio_files_in_subfolders(data_dir):
    counts = {}
    for subfolder in os.listdir(data_dir):
        subfolder_path = os.path.join(data_dir, subfolder)
        if os.path.isdir(subfolder_path):
            audio_files_count = len([f for f in os.listdir(subfolder_path) if f.endswith('.wav')])
            counts[subfolder] = audio_files_count
    return counts

# %% [markdown]
# ## 3. Function to determine the size of the model

# %%
def get_file_size(file_path):
    size = os.path.getsize(file_path)
    return size

def convert_bytes(size, unit=None):
    if unit == "KB":
        return print('File size: ' + str(round(size / 1024, 3)) + ' Kilobytes')
    elif unit == "MB":
        return print('File size: ' + str(round(size / (1024 * 1024), 3)) + ' Megabytes')
    else:
        return print('File size: ' + str(size) + ' bytes')

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Labels (Train and Test Directories)

# %%
commands = np.array(tf.io.gfile.listdir(str(train_data_dir)))
print(f'Train commands labels: {commands}')

commands = np.array(tf.io.gfile.listdir(str(test_data_dir)))
print(f'Test commands labels:  {commands}')
# Out:
# Train commands labels: ['mu masso' 'ddyo' 'kkono' 'gaali' 'yimirira' 'emabega']
# Test commands labels:  ['mu masso' 'ddyo' 'kkono' 'gaali' 'yimirira' 'emabega']

# %% [markdown]
# ## Number of audio files

# %% [markdown]
# ### 1. Training dataset

# %%
counts = count_audio_files_in_subfolders(train_data_dir)
print(f'Train \n{counts}')
print()
# Out:
# Train
# {'mu masso': 1565, 'ddyo': 1564, 'kkono': 1595, 'gaali': 1437, 'yimirira': 1504, 'emabega': 1539}

# %%
plt.figure(figsize=(12, 5))
plt.bar(list(counts.keys()), list(counts.values()), color='green')
plt.xlabel('Number of Audio Files')
plt.ylabel('Command labels')
plt.title('Number of Audio Files For Training for Each Command')
plt.show()

# %% [markdown]
# ### 2. Test dataset

# %%
counts = count_audio_files_in_subfolders(test_data_dir)
print(f'Test \n{counts}')
print()
# Out:
# Test
# {'mu masso': 306, 'ddyo': 302, 'kkono': 310, 'gaali': 307, 'yimirira': 305, 'emabega': 302}

# %%
plt.figure(figsize=(12, 5))
plt.bar(list(counts.keys()), list(counts.values()), color='green')
plt.xlabel('Number of Audio Files')
plt.ylabel('Command labels')
plt.title('Number of Audio Files For Training for Each Command')
plt.show()

# %% [markdown]
# ## Audio Properties and Parameters
# - using one audio file

# %%
example_audio_path = os.path.join(TRAIN_DATASET_PATH, 'ddyo', 'ddyo #107.wav')
audio_signal, sample_rate = librosa.load(example_audio_path, sr=SAMPLE_RATE)
audio = wave.open(example_audio_path, 'rb')

# %%
num_channels = audio.getnchannels()
sample_width = audio.getsampwidth()
frame_rate = audio.getframerate()
num_frames = audio.getnframes()
duration = num_frames / float(frame_rate)

# %%
print('Audio Properties for a ddyo audio file')
print(f"Number of channels:   {num_channels}")
print(f"Sample width (bytes): {sample_width}")
print(f"Frame rate (Hz):      {frame_rate}")
print(f"Number of frames:     {num_frames}")
print(f"Duration (s):         {duration}")
# print("Parameters:            ", audio.getparams())
audio.close()
# Out:
# Audio Properties for a ddyo audio file
# Number of channels:   1
# Sample width (bytes): 2
# Frame rate (Hz):      16000
# Number of frames:     21440
# Duration (s):         1.34

# %% [markdown]
# ## Visualize the audio waveform

# %%
ddyo_file_path = os.path.join(TRAIN_DATASET_PATH, 'ddyo', 'ddyo #107.wav')
kkono_file_path = os.path.join(TRAIN_DATASET_PATH, 'kkono', 'kkono #67.wav')
emabega_file_path = os.path.join(TRAIN_DATASET_PATH, 'emabega', 'emabega #225.wav')
mumasso_file_path = os.path.join(TRAIN_DATASET_PATH, 'mu masso', 'mu masso #140.wav')
yimirira_file_path = os.path.join(TRAIN_DATASET_PATH, 'yimirira', 'yimirira-3 #58-05.wav')
gaali_file_path = os.path.join(TRAIN_DATASET_PATH, 'gaali', 'gaali #371.wav')

# %%
audio_files = [
    ddyo_file_path,
    kkono_file_path,
    emabega_file_path,
    mumasso_file_path,
    yimirira_file_path,
    gaali_file_path
]

label_names_slice = ['Ddyo', 'Kkono', 'Emabega', 'Mu masso', 'Yimirira', 'Gaali']

plt.figure(figsize=(16, 10))
rows = 2
cols = 3
n = rows * cols
for i in range(n):
    plt.subplot(rows, cols, i+1)
    audio_path = audio_files[i]  # Get the path to the audio file
    audio_signal, _ = librosa.load(audio_path, sr=SAMPLE_RATE)
    time = librosa.times_like(audio_signal, sr=SAMPLE_RATE)
    plt.plot(time, audio_signal)
    plt.title(label_names_slice[i])
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')
    plt.ylim([-1.1, 1.1])
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Play audio file

# %% [markdown]
# Ddyo

# %%
display.Audio(ddyo_file_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Kkono

# %%
display.Audio(kkono_file_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Emabega

# %%
display.Audio(emabega_file_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Mu masso

# %%
display.Audio(mumasso_file_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Yimirira

# %%
display.Audio(yimirira_file_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Gaali

# %%
display.Audio(gaali_file_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Dataset Preparaption

# %% [markdown]
# ## 1. Train and validation Datasets

# %%
train_ds, val_ds = tf.keras.utils.audio_dataset_from_directory(
    directory=train_data_dir,
    batch_size=64,
    validation_split=0.2,
    seed=0,
    output_sequence_length=SAMPLE_RATE,
    subset='both')

label_names = np.array(train_ds.class_names)
print()
# Out:
# Found 9204 files belonging to 6 classes.
# Using 7364 files for training.
# Using 1840 files for validation.

# %%
element_spec = train_ds.element_spec
print(element_spec)
print()
# Out:
# (TensorSpec(shape=(None, 16000, None), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))

# %%
def squeeze(audio, labels):
  audio = tf.squeeze(audio, axis=-1)
  return audio, labels

train_ds = train_ds.map(squeeze, tf.data.AUTOTUNE)
val_ds = val_ds.map(squeeze, tf.data.AUTOTUNE)

# %%
# test_ds = val_ds.shard(num_shards=2, index=0)
# val_ds = val_ds.shard(num_shards=2, index=1)

# %%
# Inspecting the shape of the audio and label

for example_audio, example_labels in train_ds.take(1):
  print(example_audio.shape)
  print(example_labels.shape)
# Out:
# (64, 16000)
# (64,)

# %% [markdown]
# ## 2. Test dataset

# %%
test_ds = tf.keras.utils.audio_dataset_from_directory(
    directory=test_data_dir,
    batch_size=64,
    validation_split=None,  # No need to split the test dataset
    seed=0,
    output_sequence_length=SAMPLE_RATE,
    shuffle=False  # Disable shuffling for the test dataset
)

test_ds = test_ds.map(squeeze, tf.data.AUTOTUNE)
# Out:
# Found 1832 files belonging to 6 classes.

# %%
for example_audio, example_labels in test_ds.take(1):
  print(example_audio.shape)
  print(example_labels.shape)
print()
# Out:
# (64, 16000)
# (64,)

# %% [markdown]
# # Feature Extraction

# %%
def get_spectrogram(waveform):
  spectrogram = tf.signal.stft(
      waveform, frame_length=255, frame_step=128)
  spectrogram = tf.abs(spectrogram)
  spectrogram = spectrogram[..., tf.newaxis]
  return spectrogram

# %% [markdown]
# ## Tensorized waveform
# The shapes of a tensorized waveform and the corresponding spectrogram, and play the original audio.

# %%
for i in range(6):
  label = label_names[example_labels[i]]
  waveform = example_audio[i]
  spectrogram = get_spectrogram(waveform)

  print('Label:', label)
  print('Waveform shape:', waveform.shape)
  print('Spectrogram shape:', spectrogram.shape)
  print('Audio playback')
  display.display(display.Audio(waveform, rate=16000))
# Out:
# Label: ddyo
# Waveform shape: (16000,)
# Spectrogram shape: (124, 129, 1)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Label: ddyo
# Waveform shape: (16000,)
# Spectrogram shape: (124, 129, 1)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Label: ddyo
# Waveform shape: (16000,)
# Spectrogram shape: (124, 129, 1)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Label: ddyo
# Waveform shape: (16000,)
# Spectrogram shape: (124, 129, 1)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Label: ddyo
# Waveform shape: (16000,)
# Spectrogram shape: (124, 129, 1)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Label: ddyo
# Waveform shape: (16000,)
# Spectrogram shape: (124, 129, 1)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Visualization of spectrogram

# %%
def plot_spectrogram(spectrogram, ax):
  if len(spectrogram.shape) > 2:
    assert len(spectrogram.shape) == 3
    spectrogram = np.squeeze(spectrogram, axis=-1)
      
  log_spec = np.log(spectrogram.T + np.finfo(float).eps)
  height = log_spec.shape[0]
  width = log_spec.shape[1]
  X = np.linspace(0, np.size(spectrogram), num=width, dtype=int)
  Y = range(height)
  ax.pcolormesh(X, Y, log_spec)

# %% [markdown]
# ### Plot of waveform and spectrogram.

# %%
fig, axes = plt.subplots(2, figsize=(12, 8))
timescale = np.arange(waveform.shape[0])
axes[0].plot(timescale, waveform.numpy())
axes[0].set_title('Waveform')
axes[0].set_xlim([0, 16000])

plot_spectrogram(spectrogram.numpy(), axes[1])
axes[1].set_title('Spectrogram')
plt.suptitle(label.title())
plt.show()

# %% [markdown]
# ## Create spectrogram datasets

# %%
def make_spec_ds(ds):
  return ds.map(
      map_func=lambda audio,label: (get_spectrogram(audio), label),
      num_parallel_calls=tf.data.AUTOTUNE)

# %%
train_spectrogram_ds = make_spec_ds(train_ds)
val_spectrogram_ds = make_spec_ds(val_ds)
test_spectrogram_ds = make_spec_ds(test_ds)

# %%
train_spectrogram_ds = train_spectrogram_ds.cache().shuffle(10000).prefetch(tf.data.AUTOTUNE)
val_spectrogram_ds = val_spectrogram_ds.cache().prefetch(tf.data.AUTOTUNE)
test_spectrogram_ds = test_spectrogram_ds.cache().prefetch(tf.data.AUTOTUNE)

# %%
train_spectrogram_ds
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 124, 129, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
val_spectrogram_ds
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 124, 129, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
test_spectrogram_ds
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 124, 129, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %% [markdown]
# ## Visualization of the spectrograms

# %%
for example_spectrograms, example_spect_labels in train_spectrogram_ds.take(1):
  break

# %%
rows = 2
cols = 3
n = rows*cols
fig, axes = plt.subplots(rows, cols, figsize=(16, 9))

for i in range(n):
    r = i // cols
    c = i % cols
    ax = axes[r][c]
    plot_spectrogram(example_spectrograms[i].numpy(), ax)
    ax.set_title(label_names[example_spect_labels[i].numpy()])

plt.show()

# %% [markdown]
# ## Model 1

# %%
input_shape = example_spectrograms.shape[1:]
print('Input shape:', input_shape)
num_labels = len(label_names)

norm_layer = layers.Normalization()
norm_layer.adapt(data=train_spectrogram_ds.map(map_func=lambda spec, label: spec))
# Out:
# Input shape: (124, 129, 1)

# %%
model = models.Sequential([
    layers.Input(shape=input_shape),
    # Downsample the input.
    layers.Resizing(32, 32),
    # Normalize.
    norm_layer,
    layers.Conv2D(32, 3, activation='relu'),
    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Dropout(0.25),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(num_labels),
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resizing (Resizing)         (None, 32, 32, 1)         0
#
#  normalization (Normalizati  (None, 32, 32, 1)         3
#  on)
#
#  conv2d (Conv2D)             (None, 30, 30, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 64)        18496
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 14, 14, 64)        0
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 128)               1605760
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 1625353 (6.20 MB)
# Trainable params: 1625350 (6.20 MB)
# Non-trainable params: 3 (16.00 Byte)
# _________________________________________________________________

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)

# %% [markdown]
# ### Train the model

# %%
EPOCHS = 20
history = model.fit(
    train_spectrogram_ds,
    validation_data=val_spectrogram_ds,
    epochs=EPOCHS,
    callbacks=tf.keras.callbacks.EarlyStopping(verbose=1, patience=2),
)
# Out:
# Epoch 1/20
# 116/116 [==============================] - 15s 128ms/step - loss: 1.1495 - accuracy: 0.5714 - val_loss: 0.8120 - val_accuracy: 0.7495
# Epoch 2/20
# 116/116 [==============================] - 18s 154ms/step - loss: 0.7823 - accuracy: 0.7265 - val_loss: 0.6670 - val_accuracy: 0.7908
# Epoch 3/20
# 116/116 [==============================] - 16s 136ms/step - loss: 0.6414 - accuracy: 0.7788 - val_loss: 0.6078 - val_accuracy: 0.8098
# Epoch 4/20
# 116/116 [==============================] - 16s 138ms/step - loss: 0.5528 - accuracy: 0.8057 - val_loss: 0.5366 - val_accuracy: 0.8380
# Epoch 5/20
# 116/116 [==============================] - 16s 137ms/step - loss: 0.4818 - accuracy: 0.8361 - val_loss: 0.5074 - val_accuracy: 0.8424
# Epoch 6/20
# 116/116 [==============================] - 16s 137ms/step - loss: 0.4201 - accuracy: 0.8547 - val_loss: 0.4622 - val_accuracy: 0.8658
# Epoch 7/20
# 116/116 [==============================] - 16s 136ms/step - loss: 0.3605 - accuracy: 0.8737 - val_loss: 0.4512 - val_accuracy: 0.8582
# Epoch 8/20
# 116/116 [==============================] - 16s 136ms/step - loss: 0.3185 - accuracy: 0.8895 - val_loss: 0.4427 - val_accuracy: 0.8658
# Epoch 9/20
# 116/116 [==============================] - 15s 129ms/step - loss: 0.2912 - accuracy: 0.8980 - val_loss: 0.4268 - val_accuracy: 0.8772
# Epoch 10/20
# 116/116 [==============================] - 19s 167ms/step - loss: 0.2650 - accuracy: 0.9098 - val_loss: 0.4289 - val_accuracy: 0.8728
# Epoch 11/20
# 116/116 [==============================] - 20s 170ms/step - loss: 0.2466 - accuracy: 0.9113 - val_loss: 0.3947 - val_accuracy: 0.8891
# Epoch 12/20
# 116/116 [==============================] - 23s 201ms/step - loss: 0.2049 - accuracy: 0.9288 - val_loss: 0.4036 - val_accuracy: 0.8897
# Epoch 13/20
# 116/116 [==============================] - 22s 193ms/step - loss: 0.1851 - accuracy: 0.9367 - val_loss: 0.4297 - val_accuracy: 0.8875
# Epoch 13: early stopping

# %% [markdown]
# ### Plot the training and validation loss curves to check how your model has improved during training:

# %%
metrics = history.history
plt.figure(figsize=(14,5))
plt.subplot(1,2,1)
plt.plot(history.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.ylim([0, max(plt.ylim())])
plt.xlabel('Epoch')
plt.ylabel('Loss [CrossEntropy]')

plt.subplot(1,2,2)
plt.plot(history.epoch, 100*np.array(metrics['accuracy']), 100*np.array(metrics['val_accuracy']))
plt.legend(['accuracy', 'val_accuracy'])
plt.ylim([0, 100])
plt.xlabel('Epoch')
plt.ylabel('Accuracy [%]')
# Out:
# Text(0, 0.5, 'Accuracy [%]')

# %% [markdown]
# ### Evaluate the model performance
#
# Run the model on the test set and check the model's performance:

# %%
model.evaluate(test_spectrogram_ds, return_dict=True)
# Out:
# 29/29 [==============================] - 1s 22ms/step - loss: 0.5183 - accuracy: 0.8526
# {'loss': 0.5183120369911194, 'accuracy': 0.8526200652122498}

# %% [markdown]
# ### Display a confusion matrix

# %%
y_pred = model.predict(test_spectrogram_ds)
# Out:
# 29/29 [==============================] - 1s 14ms/step

# %%
y_pred = tf.argmax(y_pred, axis=1)

# %%
y_true = tf.concat(list(test_spectrogram_ds.map(lambda s,lab: lab)), axis=0)

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_mtx,
            xticklabels=label_names,
            yticklabels=label_names,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %% [markdown]
# ### Export the model with preprocessing

# %%
class ExportModel(tf.Module):
  def __init__(self, model):
    self.model = model

    # Accept either a string-filename or a batch of waveforms.
    # YOu could add additional signatures for a single wave, or a ragged-batch.
    self.__call__.get_concrete_function(
        x=tf.TensorSpec(shape=(), dtype=tf.string))
    self.__call__.get_concrete_function(
       x=tf.TensorSpec(shape=[None, 16000], dtype=tf.float32))


  @tf.function
  def __call__(self, x):
    # If they pass a string, load the file and decode it.
    if x.dtype == tf.string:
      x = tf.io.read_file(x)
      x, _ = tf.audio.decode_wav(x, desired_channels=1, desired_samples=16000,)
      x = tf.squeeze(x, axis=-1)
      x = x[tf.newaxis, :]

    x = get_spectrogram(x)
    result = self.model(x, training=False)

    class_ids = tf.argmax(result, axis=-1)
    class_names = tf.gather(label_names, class_ids)
    return {'predictions':result,
            'class_ids': class_ids,
            'class_names': class_names}

# %% [markdown]
# ## Model 3

# %%
model3 = models.Sequential([
    layers.Input(shape=input_shape),
    layers.Conv2D(32, 3, activation='relu', dilation_rate=(2, 2)),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, activation='relu', dilation_rate=(2, 2)),
    layers.MaxPooling2D(),
    layers.Conv2D(128, 3, activation='relu', dilation_rate=(2, 2)),
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(num_labels),
])

# %%
model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 120, 125, 32)      320
#
#  max_pooling2d_3 (MaxPoolin  (None, 60, 62, 32)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 56, 58, 64)        18496
#
#  max_pooling2d_4 (MaxPoolin  (None, 28, 29, 64)        0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 24, 25, 128)       73856
#
#  global_average_pooling2d (  (None, 128)               0
#  GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 128)               16512
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 109958 (429.52 KB)
# Trainable params: 109958 (429.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model3.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)

# %%
EPOCHS = 20
history = model3.fit(
    train_spectrogram_ds,
    validation_data=val_spectrogram_ds,
    epochs=EPOCHS,
    callbacks=tf.keras.callbacks.EarlyStopping(verbose=1, patience=2),
)
# Out:
# Epoch 1/10
# 2024-03-08 13:38:57.365291: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 123863040 exceeds 10% of free system memory.
# 2024-03-08 13:38:57.384626: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 122880000 exceeds 10% of free system memory.
#   1/116 [..............................] - ETA: 2:38 - loss: 1.8001 - accuracy: 0.1719
# 2024-03-08 13:38:57.804510: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 122880000 exceeds 10% of free system memory.
# 2024-03-08 13:38:57.904047: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 123863040 exceeds 10% of free system memory.
# 2024-03-08 13:38:58.009570: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 123863040 exceeds 10% of free system memory.
# 116/116 [==============================] - 125s 1s/step - loss: 1.5415 - accuracy: 0.3516 - val_loss: 1.2293 - val_accuracy: 0.5484
# Epoch 2/10
# 116/116 [==============================] - 131s 1s/step - loss: 1.1212 - accuracy: 0.5868 - val_loss: 0.9314 - val_accuracy: 0.6668
# Epoch 3/10
# 116/116 [==============================] - 135s 1s/step - loss: 0.9237 - accuracy: 0.6704 - val_loss: 0.7860 - val_accuracy: 0.7250
# Epoch 4/10
# 116/116 [==============================] - 93s 800ms/step - loss: 0.8028 - accuracy: 0.7207 - val_loss: 0.7036 - val_accuracy: 0.7717
# Epoch 5/10
# 116/116 [==============================] - 93s 803ms/step - loss: 0.7312 - accuracy: 0.7490 - val_loss: 0.6438 - val_accuracy: 0.7891
# Epoch 6/10
# 116/116 [==============================] - 94s 815ms/step - loss: 0.6580 - accuracy: 0.7755 - val_loss: 0.6076 - val_accuracy: 0.7978
# Epoch 7/10
# 116/116 [==============================] - 94s 810ms/step - loss: 0.6176 - accuracy: 0.7914 - val_loss: 0.5695 - val_accuracy: 0.8212
# Epoch 8/10
# 116/116 [==============================] - 95s 823ms/step - loss: 0.5614 - accuracy: 0.8137 - val_loss: 0.5416 - val_accuracy: 0.8245
# Epoch 9/10
# 116/116 [==============================] - 94s 807ms/step - loss: 0.5491 - accuracy: 0.8161 - val_loss: 0.5400 - val_accuracy: 0.8310
# Epoch 10/10
# 116/116 [==============================] - 86s 739ms/step - loss: 0.5085 - accuracy: 0.8274 - val_loss: 0.4864 - val_accuracy: 0.8391

# %%
metrics = history.history
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
plt.plot(history.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.ylim([0, max(plt.ylim())])
plt.xlabel('Epoch')
plt.ylabel('Loss [CrossEntropy]')

plt.subplot(1,2,2)
plt.plot(history.epoch, 100*np.array(metrics['accuracy']), 100*np.array(metrics['val_accuracy']))
plt.legend(['accuracy', 'val_accuracy'])
plt.ylim([0, 100])
plt.xlabel('Epoch')
plt.ylabel('Accuracy [%]')
# Out:
# Text(0, 0.5, 'Accuracy [%]')

# %% [markdown]
# ### Evaluate the model

# %%
model3.evaluate(test_spectrogram_ds, return_dict=True)
# Out:
# 29/29 [==============================] - 8s 258ms/step - loss: 0.4965 - accuracy: 0.8352
# {'loss': 0.4964800775051117, 'accuracy': 0.8351528644561768}

# %%
y_pred = model3.predict(test_spectrogram_ds)
y_pred = tf.argmax(y_pred, axis=1)
# Out:
# 29/29 [==============================] - 7s 238ms/step

# %%
y_true = tf.concat(list(test_spectrogram_ds.map(lambda s,lab: lab)), axis=0)

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_mtx,
            xticklabels=label_names,
            yticklabels=label_names,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %% [markdown]
# ## Model 4

# %%
train_spectrogram_ds = train_spectrogram_ds.map(lambda x, y: (tf.image.grayscale_to_rgb(x), y))
val_spectrogram_ds = val_spectrogram_ds.map(lambda x, y: (tf.image.grayscale_to_rgb(x), y))

# %%
input_shape = (124, 129, 3) 
base_model = tf.keras.applications.MobileNetV2(
    input_shape=input_shape, include_top=False, weights='imagenet')
base_model.trainable = False

model4 = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(num_labels),
])
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 23s 2us/step

# %%
model4.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Func  (None, 4, 5, 1280)        2257984
#  tional)
#
#  global_average_pooling2d_1  (None, 1280)              0
#   (GlobalAveragePooling2D)
#
#  dense_6 (Dense)             (None, 128)               163968
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 2422726 (9.24 MB)
# Trainable params: 164742 (643.52 KB)
# Non-trainable params: 2257984 (8.61 MB)
# _________________________________________________________________

# %%
model4.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)

# %%
EPOCHS = 10
history = model4.fit(
    train_spectrogram_ds,
    validation_data=val_spectrogram_ds,
    epochs=EPOCHS,
    callbacks=tf.keras.callbacks.EarlyStopping(verbose=1, patience=2),
)
# Out:
# Epoch 1/10
# 116/116 [==============================] - 33s 270ms/step - loss: 1.3063 - accuracy: 0.5031 - val_loss: 0.9236 - val_accuracy: 0.6750
# Epoch 2/10
# 116/116 [==============================] - 37s 316ms/step - loss: 0.9475 - accuracy: 0.6441 - val_loss: 0.8286 - val_accuracy: 0.7022
# Epoch 3/10
# 116/116 [==============================] - 35s 306ms/step - loss: 0.8474 - accuracy: 0.6942 - val_loss: 0.7596 - val_accuracy: 0.7277
# Epoch 4/10
# 116/116 [==============================] - 36s 312ms/step - loss: 0.7890 - accuracy: 0.7116 - val_loss: 0.7323 - val_accuracy: 0.7315
# Epoch 5/10
# 116/116 [==============================] - 36s 308ms/step - loss: 0.7330 - accuracy: 0.7283 - val_loss: 0.7171 - val_accuracy: 0.7418
# Epoch 6/10
# 116/116 [==============================] - 36s 308ms/step - loss: 0.6918 - accuracy: 0.7435 - val_loss: 0.6829 - val_accuracy: 0.7549
# Epoch 7/10
# 116/116 [==============================] - 35s 303ms/step - loss: 0.6733 - accuracy: 0.7533 - val_loss: 0.6810 - val_accuracy: 0.7511
# Epoch 8/10
# 116/116 [==============================] - 36s 307ms/step - loss: 0.6368 - accuracy: 0.7637 - val_loss: 0.6713 - val_accuracy: 0.7527
# Epoch 9/10
# 116/116 [==============================] - 36s 313ms/step - loss: 0.6040 - accuracy: 0.7831 - val_loss: 0.6777 - val_accuracy: 0.7484
# Epoch 10/10
# 116/116 [==============================] - 37s 316ms/step - loss: 0.5875 - accuracy: 0.7833 - val_loss: 0.6758 - val_accuracy: 0.7554
# Epoch 10: early stopping

# %%
metrics = history.history
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
plt.plot(history.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.ylim([0, max(plt.ylim())])
plt.xlabel('Epoch')
plt.ylabel('Loss [CrossEntropy]')

plt.subplot(1,2,2)
plt.plot(history.epoch, 100*np.array(metrics['accuracy']), 100*np.array(metrics['val_accuracy']))
plt.legend(['accuracy', 'val_accuracy'])
plt.ylim([0, 100])
plt.xlabel('Epoch')
plt.ylabel('Accuracy [%]')
# Out:
# Text(0, 0.5, 'Accuracy [%]')

# %% [markdown]
# ### Evaluate the model

# %%
model4.evaluate(val_spectrogram_ds, return_dict=True)
# Out:
# 29/29 [==============================] - 6s 215ms/step - loss: 0.6758 - accuracy: 0.7554
# {'loss': 0.6758280396461487, 'accuracy': 0.7554348111152649}

# %%
y_pred = model4.predict(val_spectrogram_ds)
y_pred = tf.argmax(y_pred, axis=1)
# Out:
# 29/29 [==============================] - 6s 220ms/step

# %%
y_true = tf.concat(list(val_spectrogram_ds.map(lambda s,lab: lab)), axis=0)

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_mtx,
            xticklabels=label_names,
            yticklabels=label_names,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %% [markdown]
# # Exporting a model

# %% [markdown]
# ## Export the model with preprocessing

# %%
class ExportModel(tf.Module):
  def __init__(self, model):
    self.model = model

    # Accept either a string-filename or a batch of waveforms.
    # YOu could add additional signatures for a single wave, or a ragged-batch.
    self.__call__.get_concrete_function(
        x=tf.TensorSpec(shape=(), dtype=tf.string))
    self.__call__.get_concrete_function(
       x=tf.TensorSpec(shape=[None, 16000], dtype=tf.float32))


  @tf.function
  def __call__(self, x):
    # If they pass a string, load the file and decode it.
    if x.dtype == tf.string:
      x = tf.io.read_file(x)
      x, _ = tf.audio.decode_wav(x, desired_channels=1, desired_samples=16000,)
      x = tf.squeeze(x, axis=-1)
      x = x[tf.newaxis, :]

    x = get_spectrogram(x)
    result = self.model(x, training=False)

    class_ids = tf.argmax(result, axis=-1)
    class_names = tf.gather(label_names, class_ids)
    return {'predictions':result,
            'class_ids': class_ids,
            'class_names': class_names}

# %%
export = ExportModel(model)
export(tf.constant(str(ddyo_file_path)))
# Out:
# {'predictions': <tf.Tensor: shape=(1, 6), dtype=float32, numpy=
#  array([[ 7.049487 , -1.9053268, -7.6982565,  2.9652205, -2.7367606,
#          -5.1518655]], dtype=float32)>,
#  'class_ids': <tf.Tensor: shape=(1,), dtype=int64, numpy=array([0])>,
#  'class_names': <tf.Tensor: shape=(1,), dtype=string, numpy=array([b'ddyo'], dtype=object)>}

# %%
export(tf.constant(str(kkono_file_path)))
# Out:
# {'predictions': <tf.Tensor: shape=(1, 6), dtype=float32, numpy=
#  array([[-0.7612182 , -0.41289377, -3.7462218 ,  3.9213636 , -0.85588217,
#          -2.5732143 ]], dtype=float32)>,
#  'class_ids': <tf.Tensor: shape=(1,), dtype=int64, numpy=array([3])>,
#  'class_names': <tf.Tensor: shape=(1,), dtype=string, numpy=array([b'kkono'], dtype=object)>}

# %%
export(tf.constant(str(emabega_file_path)))
# Out:
# {'predictions': <tf.Tensor: shape=(1, 6), dtype=float32, numpy=
#  array([[-2.8216405,  3.4339929, -4.485298 , -4.475095 ,  0.3135848,
#          -1.4049379]], dtype=float32)>,
#  'class_ids': <tf.Tensor: shape=(1,), dtype=int64, numpy=array([1])>,
#  'class_names': <tf.Tensor: shape=(1,), dtype=string, numpy=array([b'emabega'], dtype=object)>}

# %%
export(tf.constant(str(mumasso_file_path)))
# Out:
# {'predictions': <tf.Tensor: shape=(1, 6), dtype=float32, numpy=
#  array([[-3.4228063, -4.564629 , -5.7299614, -3.6699378,  9.866888 ,
#          -2.6753678]], dtype=float32)>,
#  'class_ids': <tf.Tensor: shape=(1,), dtype=int64, numpy=array([4])>,
#  'class_names': <tf.Tensor: shape=(1,), dtype=string, numpy=array([b'mu masso'], dtype=object)>}

# %%
export(tf.constant(str(yimirira_file_path)))
# Out:
# {'predictions': <tf.Tensor: shape=(1, 6), dtype=float32, numpy=
#  array([[-2.7642004 , -0.05474186, -1.8460809 , -4.7786045 , -0.19205536,
#           4.3060837 ]], dtype=float32)>,
#  'class_ids': <tf.Tensor: shape=(1,), dtype=int64, numpy=array([5])>,
#  'class_names': <tf.Tensor: shape=(1,), dtype=string, numpy=array([b'yimirira'], dtype=object)>}

# %%
export(tf.constant(str(gaali_file_path)))
# Out:
# {'predictions': <tf.Tensor: shape=(1, 6), dtype=float32, numpy=
#  array([[-4.5379167, -2.5053985,  8.742999 , -4.679647 , -2.7684364,
#          -5.4286866]], dtype=float32)>,
#  'class_ids': <tf.Tensor: shape=(1,), dtype=int64, numpy=array([2])>,
#  'class_names': <tf.Tensor: shape=(1,), dtype=string, numpy=array([b'gaali'], dtype=object)>}

# %% [markdown]
# Save and reload the model, the reloaded model gives identical output:

# %%
tf.saved_model.save(export, "saved")
imported = tf.saved_model.load("saved")
imported(waveform[tf.newaxis, :])
# Out:
# INFO:tensorflow:Assets written to: saved/assets
# INFO:tensorflow:Assets written to: saved/assets
# {'class_ids': <tf.Tensor: shape=(1,), dtype=int64, numpy=array([4])>,
#  'class_names': <tf.Tensor: shape=(1,), dtype=string, numpy=array([b'mu masso'], dtype=object)>,
#  'predictions': <tf.Tensor: shape=(1, 6), dtype=float32, numpy=
#  array([[ 4.420555 , -1.4559594, -3.4492943, -3.8232296,  4.9275613,
#          -3.8190074]], dtype=float32)>}
