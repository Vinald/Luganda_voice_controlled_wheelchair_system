# %% [markdown]
# # Work FLow
# - `Packages and Libraries`
# -  `Load raw audio data` from files in .WAV format that can be processed
# -  `EDA`
# -  `Spectral Representations` Convert the audio signal into a frequency domain representation, such as a spectrogram or mel spectrogram.
# -  `Conversion to TensorFlow` Convert the preprocessed data into a format suitable for the deep learning framework.
# -  `Data Splitting` Split the dataset into training, validation, and testing sets.
# -  `Model Building` Build your machine learning model using the preprocessed data.
# -  `Converting to TFLite model`

# %% [markdown]
# # Packages and Libraries

# %%
import os
import json
import math
import wave
import h5py
import librosa
import pathlib
import logging
import numpy as np
import pandas as pd
import seaborn as sns
import soundfile as sf
import tensorflow as tf 
from sys import getsizeof
from tensorflow import keras
import matplotlib.pyplot as plt
import IPython.display as display
from IPython.display import Audio
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score

# %% [markdown]
# # Loading Raw Audio Data
#
# The dataset's audio clips are of 6 classes and stored in six folders corresponding to each speech command:
# - `ddyo`
# - `kkono`
# - `mu maaso`
# - `emabega`
# - `yimirira`
# - `gaali`

# %% [markdown]
# ## Mount google drive
# adisamproject@gmail.com

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# DATASET_PATH = "/content/drive/My Drive/2_Luganda/dataset"
# data_dir = pathlib.Path(DATASET_PATH)

# %% [markdown]
# ## Dataset path

# %%
TRAIN_DATASET_PATH = 'Dataset/Train'
TEST_DATASET_PATH = 'Dataset/Test'

train_data_dir = pathlib.Path(TRAIN_DATASET_PATH)
test_data_dir = pathlib.Path(TEST_DATASET_PATH)

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Labels (Train and Test Directories)

# %%
commands = np.array(tf.io.gfile.listdir(str(train_data_dir)))
print('Train commands labels:\n', commands)
# Out:
# Train commands labels:
#  ['emabega' 'ddyo' 'gaali' 'kkono' 'mu masso' 'yimirira']

# %%
commands = np.array(tf.io.gfile.listdir(str(test_data_dir)))
print('Test commands labels:\n', commands)
# Out:
# Test commands labels:
#  ['emabega' 'ddyo' 'gaali' 'kkono' 'mu masso' 'yimirira']

# %% [markdown]
# ## Number of audio files

# %%
def count_audio_files_in_subfolders(data_dir):
    counts = {}
    for subfolder in os.listdir(data_dir):
        subfolder_path = os.path.join(data_dir, subfolder)

        if os.path.isdir(subfolder_path):
            audio_files_count = len([f for f in os.listdir(subfolder_path) if f.endswith('.wav')])
            counts[subfolder] = audio_files_count

    return counts

# %% [markdown]
# ### Training dataset

# %%
counts = count_audio_files_in_subfolders(train_data_dir)

# %%
plt.figure(figsize=(12, 5))
plt.barh(list(counts.keys()), list(counts.values()), color='green')
plt.xlabel('Number of Audio Files')
plt.ylabel('Command labels')
plt.title('Number of Audio Files For Training for Each Command')
plt.show()

# %% [markdown]
# ### Test dataset

# %%
counts = count_audio_files_in_subfolders(test_data_dir)

# %%
plt.figure(figsize=(12, 5))
plt.barh(list(counts.keys()), list(counts.values()), color='green')
plt.xlabel('Number of Audio Files')
plt.ylabel('Command labels')
plt.title('Number of Audio Files For Testing for Each Command')
plt.show()

# %% [markdown]
# ## Audio Properties and Parameters
# - using one audio file

# %%
SAMPLE_RATE = 16000
DURATION = 2  # in seconds
SAMPLES_PER_AUDIO = SAMPLE_RATE * DURATION

# %%
example_audio_path = os.path.join(TRAIN_DATASET_PATH, 'emabega', 'audio #4251.wav')
audio_signal, sample_rate = librosa.load(example_audio_path, sr=SAMPLE_RATE)
audio = wave.open(example_audio_path, 'rb')

# %%
num_channels = audio.getnchannels()
sample_width = audio.getsampwidth()
frame_rate = audio.getframerate()
num_frames = audio.getnframes()
duration = num_frames / float(frame_rate)

# %%
print("Number of channels:    ", num_channels)
print("Sample width (bytes):  ", sample_width)
print("Frame rate (Hz):       ", frame_rate)
print("Number of frames:      ", num_frames)
print("Duration (s):          ", duration)
print("Parameters:            ", audio.getparams())
# Out:
# Number of channels:     1
# Sample width (bytes):   2
# Frame rate (Hz):        16000
# Number of frames:       20160
# Duration (s):           1.26
# Parameters:             _wave_params(nchannels=1, sampwidth=2, framerate=16000, nframes=20160, comptype='NONE', compname='not compressed')

# %%
audio.close()

# %% [markdown]
# ### Visualize the audio waveform

# %%
time = librosa.times_like(audio_signal, sr=SAMPLE_RATE)

plt.figure(figsize=(12, 5))
plt.plot(time, audio_signal)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Audio Signal Waveform')
plt.show()

# %% [markdown]
# ### Amplitude Distribution

# %%
# Calculate statistical summary information
mean_amplitude = np.mean(audio_signal)
std_deviation = np.std(audio_signal)
max_amplitude = np.max(audio_signal)
min_amplitude = np.min(audio_signal)
median_amplitude = np.median(audio_signal)

# Plot the histogram with additional features
plt.figure(figsize=(12, 5))

# Plot the histogram
sns.histplot(audio_signal, bins=50, kde=True)

# Add vertical lines for statistical summary information
plt.axvline(mean_amplitude, color='r', linestyle='--', label=f'Mean: {mean_amplitude:.2f}')
plt.axvline(mean_amplitude + std_deviation, color='g', linestyle='--', label=f'Std Dev: {std_deviation:.2f}')
plt.axvline(mean_amplitude - std_deviation, color='g', linestyle='--')
plt.axvline(median_amplitude, color='b', linestyle='--', label=f'Median: {median_amplitude:.2f}')
plt.axvline(max_amplitude, color='m', linestyle='--', label=f'Max: {max_amplitude:.2f}')
plt.axvline(min_amplitude, color='m', linestyle='--', label=f'Min: {min_amplitude:.2f}')

# Set plot title and labels
plt.title('Amplitude Distribution')
plt.xlabel('Amplitude')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# ### Play audio file

# %%
Audio(example_audio_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Preprocess the data

# %%
def extract_mfcc(dataset_path, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=5):

    # dictionary to store mapping, labels, and MFCCs
    data = {
        "mapping": [],
        "labels": [],
        "mfcc": []
    }

    samples_per_segment = int(SAMPLES_PER_AUDIO / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

    # loop through all sub-folders
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):

        # ensure we're processing the sub-folder level
        if dirpath is not dataset_path:

            # save genre label (i.e., sub-folder name) in the mapping
            semantic_label = dirpath.split("/")[-1]
            data["mapping"].append(semantic_label)
            print(f"\nProcessing: {semantic_label}")

            # process all audio files in genre sub-dir
            for f in filenames:

                # load audio file
                file_path = os.path.join(dirpath, f)
                signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)

                # process all segments of audio file
                for d in range(num_segments):

                    # calculate start and finish sample for the current segment
                    start = samples_per_segment * d
                    finish = start + samples_per_segment

                    # extract mfcc
                    mfcc = librosa.feature.mfcc(y=signal[start:finish],
                                                sr=sample_rate,
                                                n_mfcc=num_mfcc,
                                                n_fft=n_fft,
                                                hop_length=hop_length)

                    mfcc = mfcc.T

                    # store only mfcc feature with the expected number of vectors
                    if len(mfcc) == num_mfcc_vectors_per_segment:
                        data["mfcc"].append(mfcc.tolist())
                        data["labels"].append(i-1)
                        print(f"{file_path}, segment:{d+1}")

    return data

# %%
num_mfcc = 13
n_fft = 2048
hop_length = 512
num_segments = 5

data = extract_mfcc(train_data_dir, num_mfcc, n_fft, hop_length, num_segments)
# Out:
# Processing: Train
#
# Processing: emabega
# Dataset/Train/emabega/audio #5069.wav, segment:1
# Dataset/Train/emabega/audio #5069.wav, segment:2
# Dataset/Train/emabega/audio #5069.wav, segment:3
# Dataset/Train/emabega/audio #5069.wav, segment:4
# Dataset/Train/emabega/audio #4336.wav, segment:1
# Dataset/Train/emabega/audio #4336.wav, segment:2
# Dataset/Train/emabega/audio #4336.wav, segment:3
# Dataset/Train/emabega/audio #4843.wav, segment:1
# Dataset/Train/emabega/audio #4843.wav, segment:2
# Dataset/Train/emabega/audio #4843.wav, segment:3
# Dataset/Train/emabega/audio #4685.wav, segment:1
# Dataset/Train/emabega/audio #4685.wav, segment:2
# Dataset/Train/emabega/audio #4685.wav, segment:3
# Dataset/Train/emabega/audio #4685.wav, segment:4
# /home/vx/Desktop/allenv/lib/python3.11/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=960
#   warnings.warn(
# /home/vx/Desktop/allenv/lib/python3.11/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=320
#   warnings.warn(
# /home/vx/Desktop/allenv/lib/python3.11/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=0
#   warnings.warn(
# /home/vx/Desktop/allenv/lib/python3.11/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1600
#   warnings.warn(
# Dataset/Train/emabega/audio #4991.wav, segment:1
# Dataset/Train/emabega/audio #4991.wav, segment:2
# Dataset/Train/emabega/audio #4552.wav, segment:1
# Dataset/Train/emabega/audio #4552.wav, segment:2
# Dataset/Train/emabega/audio #4552.wav, segment:3
# Dataset/Train/emabega/audio #4936.wav, segment:1
# Dataset/Train/emabega/audio #4936.wav, segment:2
# Dataset/Train/emabega/audio #4564.wav, segment:1
# Dataset/Train/emabega/audio #4564.wav, segment:2
# Dataset/Train/emabega/audio #4564.wav, segment:3
# Dataset/Train/emabega/audio #4564.wav, segment:4
# Dataset/Train/emabega/audio #4960.wav, segment:1
# Dataset/Train/emabega/audio #4960.wav, segment:2
# Dataset/Train/emabega/audio #4960.wav, segment:3
# Dataset/Train/emabega/audio #4550.wav, segment:1
# /home/vx/Desktop/allenv/lib/python3.11/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1920
#   warnings.warn(
# Dataset/Train/emabega/audio #4550.wav, segment:2
# Dataset/Train/emabega/audio #4550.wav, segment:3
# Dataset/Train/emabega/audio #5048.wav, segment:1
# Dataset/Train/emabega/audio #5048.wav, segment:2
# Dataset/Train/emabega/audio #5048.wav, segment:3
# Dataset/Train/emabega/audio #5048.wav, segment:4
# Dataset/Train/emabega/audio #5029.wav, segment:1
# Dataset/Train/emabega/audio #5029.wav, segment:2
# Dataset/Train/emabega/audio #5029.wav, segment:3
# Dataset/Train/emabega/audio #5029.wav, segment:4
# Dataset/Train/emabega/audio #4884.wav, segment:1
# Dataset/Train/emabega/audio #4884.wav, segment:2
# Dataset/Train/emabega/audio #4884.wav, segment:3
# Dataset/Train/emabega/audio #4672.wav, segment:1
# Dataset/Train/emabega/audio #4672.wav, segment:2
# Dataset/Train/emabega/audio #4672.wav, segment:3
# Dataset/Train/emabega/audio #4672.wav, segment:4
# Dataset/Train/emabega/audio #4976.wav, segment:1
# Dataset/Train/emabega/audio #4976.wav, segment:2
# Dataset/Train/emabega/audio #4976.wav, segment:3
# Dataset/Train/emabega/audio #4320.wav, segment:1
# Dataset/Train/emabega/audio #4320.wav, segment:2
# Dataset/Train/emabega/audio #4978.wav, segment:1
# Dataset/Train/emabega/audio #4978.wav, segment:2
# Dataset/Train/emabega/audio #4978.wav, segment:3
# Dataset/Train/emabega/audio #4995.wav, segment:1
# Dataset/Train/emabega/audio #4995.wav, segment:2
# Dataset/Train/emabega/audio #4995.wav, segment:3
# Dataset/Train/emabega/audio #4606.wav, segment:1
# Dataset/Train/emabega/audio #4606.wav, segment:2
# Dataset/Train/emabega/audio #4606.wav, segment:3
# /home/vx/Desktop/allenv/lib/python3.11/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1280
#   warnings.warn(
# Dataset/Train/emabega/audio #4952.wav, segment:1
# Dataset/Train/emabega/audio #4952.wav, segment:2
# Dataset/Train/emabega/audio #4952.wav, segment:3
# Dataset/Train/emabega/audio #4571.wav, segment:1
# Dataset/Train/emabega/audio #4571.wav, segment:2
# Dataset/Train/emabega/audio #4571.wav, segment:3
# Dataset/Train/emabega/audio #4746.wav, segment:1
# Dataset/Train/emabega/audio #4746.wav, segment:2
# Dataset/Train/emabega/audio #4746.wav, segment:3
# Dataset/Train/emabega/audio #4746.wav, segment:4
# Dataset/Train/emabega/audio #4822.wav, segment:1
# Dataset/Train/emabega/audio #4822.wav, segment:2
# Dataset/Train/emabega/audio #4822.wav, segment:3
# Dataset/Train/emabega/audio #5072.wav, segment:1
# Dataset/Train/emabega/audio #5072.wav, segment:2
# Dataset/Train/emabega/audio #5072.wav, segment:3
# Dataset/Train/emabega/audio #5072.wav, segment:4
# Dataset/Train/emabega/audio #4815.wav, segment:1
# Dataset/Train/emabega/audio #4815.wav, segment:2
# Dataset/Train/emabega/audio #4815.wav, segment:3
# Dataset/Train/emabega/audio #4815.wav, segment:4
# Dataset/Train/emabega/audio #4565.wav, segment:1
# Dataset/Train/emabega/audio #4565.wav, segment:2
# Dataset/Train/emabega/audio #4565.wav, segment:3
# Dataset/Train/emabega/audio #4776.wav, segment:1
# Dataset/Train/emabega/audio #4776.wav, segment:2
# Dataset/Train/emabega/audio #4776.wav, segment:3
# Dataset/Train/emabega/audio #4723.wav, segment:1
# Dataset/Train/emabega/audio #4723.wav, segment:2
# Dataset/Train/emabega/audio #4723.wav, segment:3
# Dataset/Train/emabega/audio #4723.wav, segment:4
# Dataset/Train/emabega/audio #4984.wav, segment:1
# Dataset/Train/emabega/audio #4984.wav, segment:2
# Dataset/Train/emabega/audio #4831.wav, segment:1
# Dataset/Train/emabega/audio #4831.wav, segment:2
# Dataset/Train/emabega/audio #4831.wav, segment:3
# Dataset/Train/emabega/audio #4620.wav, segment:1
# Dataset/Train/emabega/audio #4620.wav, segment:2
# Dataset/Train/emabega/audio #4620.wav, segment:3
# Dataset/Train/emabega/audio #4638.wav, segment:1
# Dataset/Train/emabega/audio #4638.wav, segment:2
# Dataset/Train/emabega/audio #4638.wav, segment:3
# Dataset/Train/emabega/audio #5475.wav, segment:1
# Dataset/Train/emabega/audio #5475.wav, segment:2
# Dataset/Train/emabega/audio #5475.wav, segment:3
# Dataset/Train/emabega/audio #5017.wav, segment:1
# Dataset/Train/emabega/audio #5017.wav, segment:2
# Dataset/Train/emabega/audio #5017.wav, segment:3
# Dataset/Train/emabega/audio #4363.wav, segment:1
# Dataset/Train/emabega/audio #4363.wav, segment:2
# Dataset/Train/emabega/audio #5036.wav, segment:1
# Dataset/Train/emabega/audio #5036.wav, segment:2
# Dataset/Train/emabega/audio #5036.wav, segment:3
# Dataset/Train/emabega/audio #5036.wav, segment:4
# Dataset/Train/emabega/audio #4322.wav, segment:1
# Dataset/Train/emabega/audio #4322.wav, segment:2
# Dataset/Train/emabega/audio #4566.wav, segment:1
# Dataset/Train/emabega/audio #4566.wav, segment:2
# Dataset/Train/emabega/audio #4566.wav, segment:3
# Dataset/Train/emabega/audio #4769.wav, segment:1
# Dataset/Train/emabega/audio #4769.wav, segment:2
# Dataset/Train/emabega/audio #4769.wav, segment:3
# Dataset/Train/emabega/audio #4745.wav, segment:1
# Dataset/Train/emabega/audio #4745.wav, segment:2
# Dataset/Train/emabega/audio #4745.wav, segment:3
# Dataset/Train/emabega/audio #5063.wav, segment:1
# Dataset/Train/emabega/audio #5063.wav, segment:2
# Dataset/Train/emabega/audio #5063.wav, segment:3
# Dataset/Train/emabega/audio #4589.wav, segment:1
# Dataset/Train/emabega/audio #4589.wav, segment:2
# Dataset/Train/emabega/audio #4589.wav, segment:3
# Dataset/Train/emabega/audio #4525.wav, segment:1
# Dataset/Train/emabega/audio #4525.wav, segment:2
# Dataset/Train/emabega/audio #4525.wav, segment:3
# Dataset/Train/emabega/audio #4977.wav, segment:1
# Dataset/Train/emabega/audio #4977.wav, segment:2
# Dataset/Train/emabega/audio #4977.wav, segment:3
# /home/vx/Desktop/allenv/lib/python3.11/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=640
#   warnings.warn(
# Dataset/Train/emabega/audio #4997.wav, segment:1
# Dataset/Train/emabega/audio #4997.wav, segment:2
# Dataset/Train/emabega/audio #4997.wav, segment:3
# Dataset/Train/emabega/audio #4355.wav, segment:1
# Dataset/Train/emabega/audio #4355.wav, segment:2
# Dataset/Train/emabega/audio #4255.wav, segment:1
# Dataset/Train/emabega/audio #4255.wav, segment:2
# Dataset/Train/emabega/audio #4255.wav, segment:3
# Dataset/Train/emabega/audio #4519.wav, segment:1
# Dataset/Train/emabega/audio #4519.wav, segment:2
# Dataset/Train/emabega/audio #4519.wav, segment:3
# Dataset/Train/emabega/audio #4350.wav, segment:1
# Dataset/Train/emabega/audio #4350.wav, segment:2
# Dataset/Train/emabega/audio #4845.wav, segment:1
# Dataset/Train/emabega/audio #4845.wav, segment:2
# Dataset/Train/emabega/audio #4845.wav, segment:3
# Dataset/Train/emabega/audio #4869.wav, segment:1
# Dataset/Train/emabega/audio #4869.wav, segment:2
# Dataset/Train/emabega/audio #4989.wav, segment:1
# Dataset/Train/emabega/audio #4989.wav, segment:2
# Dataset/Train/emabega/audio #4989.wav, segment:3
# Dataset/Train/emabega/audio #4856.wav, segment:1
# Dataset/Train/emabega/audio #4856.wav, segment:2
# Dataset/Train/emabega/audio #4856.wav, segment:3
# Dataset/Train/emabega/audio #4944.wav, segment:1
# Dataset/Train/emabega/audio #4944.wav, segment:2
# Dataset/Train/emabega/audio #4944.wav, segment:3
# Dataset/Train/emabega/audio #4786.wav, segment:1
# Dataset/Train/emabega/audio #4786.wav, segment:2
# Dataset/Train/emabega/audio #4786.wav, segment:3
# Dataset/Train/emabega/audio #4786.wav, segment:4
# Dataset/Train/emabega/audio #4768.wav, segment:1
# Dataset/Train/emabega/audio #4768.wav, segment:2
# Dataset/Train/emabega/audio #4768.wav, segment:3
# Dataset/Train/emabega/audio #4768.wav, segment:4
# Dataset/Train/emabega/audio #4829.wav, segment:1
# Dataset/Train/emabega/audio #4829.wav, segment:2
# Dataset/Train/emabega/audio #4829.wav, segment:3
# Dataset/Train/emabega/audio #4340.wav, segment:1
# Dataset/Train/emabega/audio #4340.wav, segment:2
# Dataset/Train/emabega/audio #4340.wav, segment:3
# Dataset/Train/emabega/audio #5034.wav, segment:1
# Dataset/Train/emabega/audio #5034.wav, segment:2
# Dataset/Train/emabega/audio #5034.wav, segment:3
# Dataset/Train/emabega/audio #5013.wav, segment:1
# Dataset/Train/emabega/audio #5013.wav, segment:2
# Dataset/Train/emabega/audio #5013.wav, segment:3
# Dataset/Train/emabega/audio #5013.wav, segment:4
# Dataset/Train/emabega/audio #4718.wav, segment:1
# Dataset/Train/emabega/audio #4718.wav, segment:2
# Dataset/Train/emabega/audio #4718.wav, segment:3
# Dataset/Train/emabega/audio #4868.wav, segment:1
# Dataset/Train/emabega/audio #4868.wav, segment:2
# Dataset/Train/emabega/audio #4868.wav, segment:3
# Dataset/Train/emabega/audio #5031.wav, segment:1
# Dataset/Train/emabega/audio #5031.wav, segment:2
# Dataset/Train/emabega/audio #5031.wav, segment:3
# Dataset/Train/emabega/audio #5031.wav, segment:4
# Dataset/Train/emabega/audio #4596.wav, segment:1
# Dataset/Train/emabega/audio #4596.wav, segment:2
# Dataset/Train/emabega/audio #4596.wav, segment:3
# Dataset/Train/emabega/audio #4763.wav, segment:1
# Dataset/Train/emabega/audio #4763.wav, segment:2
# Dataset/Train/emabega/audio #4763.wav, segment:3
# Dataset/Train/emabega/audio #4763.wav, segment:4
# Dataset/Train/emabega/audio #4966.wav, segment:1
# Dataset/Train/emabega/audio #4966.wav, segment:2
# Dataset/Train/emabega/audio #4966.wav, segment:3
# Dataset/Train/emabega/audio #4890.wav, segment:1
# Dataset/Train/emabega/audio #4890.wav, segment:2
# Dataset/Train/emabega/audio #4890.wav, segment:3
# Dataset/Train/emabega/audio #4893.wav, segment:1
# Dataset/Train/emabega/audio #4893.wav, segment:2
# Dataset/Train/emabega/audio #4893.wav, segment:3
# Dataset/Train/emabega/audio #4572.wav, segment:1
# Dataset/Train/emabega/audio #4572.wav, segment:2
# Dataset/Train/emabega/audio #4572.wav, segment:3
# Dataset/Train/emabega/audio #4623.wav, segment:1
# Dataset/Train/emabega/audio #4623.wav, segment:2
# Dataset/Train/emabega/audio #4623.wav, segment:3
# Dataset/Train/emabega/audio #4623.wav, segment:4
# Dataset/Train/emabega/audio #4772.wav, segment:1
# Dataset/Train/emabega/audio #4772.wav, segment:2
# Dataset/Train/emabega/audio #4772.wav, segment:3
# Dataset/Train/emabega/audio #4319.wav, segment:1
# Dataset/Train/emabega/audio #4319.wav, segment:2
# Dataset/Train/emabega/audio #4690.wav, segment:1
# Dataset/Train/emabega/audio #4690.wav, segment:2
# Dataset/Train/emabega/audio #4690.wav, segment:3
# Dataset/Train/emabega/audio #4690.wav, segment:4
# Dataset/Train/emabega/audio #5473.wav, segment:1
# Dataset/Train/emabega/audio #5473.wav, segment:2
# Dataset/Train/emabega/audio #5473.wav, segment:3
# Dataset/Train/emabega/audio #4910.wav, segment:1
# Dataset/Train/emabega/audio #4910.wav, segment:2
# Dataset/Train/emabega/audio #4910.wav, segment:3
# Dataset/Train/emabega/audio #5474.wav, segment:1
# Dataset/Train/emabega/audio #5474.wav, segment:2
# Dataset/Train/emabega/audio #5474.wav, segment:3
# Dataset/Train/emabega/audio #4916.wav, segment:1
# Dataset/Train/emabega/audio #4916.wav, segment:2
# Dataset/Train/emabega/audio #4916.wav, segment:3
# Dataset/Train/emabega/audio #4928.wav, segment:1
# Dataset/Train/emabega/audio #4928.wav, segment:2
# Dataset/Train/emabega/audio #4928.wav, segment:3
# Dataset/Train/emabega/audio #4860.wav, segment:1
# Dataset/Train/emabega/audio #4860.wav, segment:2
# Dataset/Train/emabega/audio #4860.wav, segment:3
# Dataset/Train/emabega/audio #4967.wav, segment:1
# Dataset/Train/emabega/audio #4967.wav, segment:2
# Dataset/Train/emabega/audio #4967.wav, segment:3
# Dataset/Train/emabega/audio #4562.wav, segment:1
# Dataset/Train/emabega/audio #4562.wav, segment:2
# Dataset/Train/emabega/audio #4562.wav, segment:3
# Dataset/Train/emabega/audio #4636.wav, segment:1
# Dataset/Train/emabega/audio #4636.wav, segment:2
# Dataset/Train/emabega/audio #4636.wav, segment:3
# Dataset/Train/emabega/audio #4593.wav, segment:1
# Dataset/Train/emabega/audio #4593.wav, segment:2
# Dataset/Train/emabega/audio #4593.wav, segment:3
# Dataset/Train/emabega/audio #4324.wav, segment:1
# Dataset/Train/emabega/audio #4324.wav, segment:2
# Dataset/Train/emabega/audio #4616.wav, segment:1
# Dataset/Train/emabega/audio #4616.wav, segment:2
# Dataset/Train/emabega/audio #4616.wav, segment:3
# Dataset/Train/emabega/audio #4616.wav, segment:4
# Dataset/Train/emabega/audio #4616.wav, segment:5
# Dataset/Train/emabega/audio #4601.wav, segment:1
# Dataset/Train/emabega/audio #4601.wav, segment:2
# Dataset/Train/emabega/audio #4601.wav, segment:3
# Dataset/Train/emabega/audio #4774.wav, segment:1
# Dataset/Train/emabega/audio #4774.wav, segment:2
# Dataset/Train/emabega/audio #4774.wav, segment:3
# Dataset/Train/emabega/audio #5478.wav, segment:1
# Dataset/Train/emabega/audio #5478.wav, segment:2
# Dataset/Train/emabega/audio #5478.wav, segment:3
# Dataset/Train/emabega/audio #4705.wav, segment:1
# Dataset/Train/emabega/audio #4705.wav, segment:2
# Dataset/Train/emabega/audio #4705.wav, segment:3
# Dataset/Train/emabega/audio #4705.wav, segment:4
# Dataset/Train/emabega/audio #4841.wav, segment:1
# Dataset/Train/emabega/audio #4841.wav, segment:2
# Dataset/Train/emabega/audio #4841.wav, segment:3
# Dataset/Train/emabega/audio #4628.wav, segment:1
# Dataset/Train/emabega/audio #4628.wav, segment:2
# Dataset/Train/emabega/audio #4628.wav, segment:3
# Dataset/Train/emabega/audio #4628.wav, segment:4
# Dataset/Train/emabega/audio #4911.wav, segment:1
# Dataset/Train/emabega/audio #4911.wav, segment:2
# Dataset/Train/emabega/audio #4335.wav, segment:1
# Dataset/Train/emabega/audio #4335.wav, segment:2
# Dataset/Train/emabega/audio #4335.wav, segment:3
# Dataset/Train/emabega/audio #5480.wav, segment:1
# Dataset/Train/emabega/audio #5480.wav, segment:2
# Dataset/Train/emabega/audio #5480.wav, segment:3
# Dataset/Train/emabega/audio #4603.wav, segment:1
# Dataset/Train/emabega/audio #4603.wav, segment:2
# Dataset/Train/emabega/audio #4603.wav, segment:3
# Dataset/Train/emabega/audio #4603.wav, segment:4
# Dataset/Train/emabega/audio #4603.wav, segment:5
# Dataset/Train/emabega/audio #4800.wav, segment:1
# Dataset/Train/emabega/audio #4800.wav, segment:2
# Dataset/Train/emabega/audio #4800.wav, segment:3
# Dataset/Train/emabega/audio #4800.wav, segment:4
# Dataset/Train/emabega/audio #4682.wav, segment:1
# Dataset/Train/emabega/audio #4682.wav, segment:2
# Dataset/Train/emabega/audio #4682.wav, segment:3
# Dataset/Train/emabega/audio #4682.wav, segment:4
# Dataset/Train/emabega/audio #5074.wav, segment:1
# Dataset/Train/emabega/audio #5074.wav, segment:2
# Dataset/Train/emabega/audio #5074.wav, segment:3
# Dataset/Train/emabega/audio #5074.wav, segment:4
# Dataset/Train/emabega/audio #4938.wav, segment:1
# Dataset/Train/emabega/audio #4938.wav, segment:2
# Dataset/Train/emabega/audio #4537.wav, segment:1
# Dataset/Train/emabega/audio #4537.wav, segment:2
# Dataset/Train/emabega/audio #4537.wav, segment:3
# Dataset/Train/emabega/audio #4545.wav, segment:1
# Dataset/Train/emabega/audio #4545.wav, segment:2
# Dataset/Train/emabega/audio #4545.wav, segment:3
# Dataset/Train/emabega/audio #4526.wav, segment:1
# Dataset/Train/emabega/audio #4526.wav, segment:2
# Dataset/Train/emabega/audio #4526.wav, segment:3
# Dataset/Train/emabega/audio #4874.wav, segment:1
# Dataset/Train/emabega/audio #4874.wav, segment:2
# Dataset/Train/emabega/audio #4874.wav, segment:3
# Dataset/Train/emabega/audio #4771.wav, segment:1
# Dataset/Train/emabega/audio #4771.wav, segment:2
# Dataset/Train/emabega/audio #4771.wav, segment:3
# Dataset/Train/emabega/audio #4635.wav, segment:1
# Dataset/Train/emabega/audio #4635.wav, segment:2
# Dataset/Train/emabega/audio #4635.wav, segment:3
# Dataset/Train/emabega/audio #4584.wav, segment:1
# Dataset/Train/emabega/audio #4584.wav, segment:2
# Dataset/Train/emabega/audio #4584.wav, segment:3
# Dataset/Train/emabega/audio #4732.wav, segment:1
# Dataset/Train/emabega/audio #4732.wav, segment:2
# Dataset/Train/emabega/audio #4732.wav, segment:3
# Dataset/Train/emabega/audio #4708.wav, segment:1
# Dataset/Train/emabega/audio #4708.wav, segment:2
# Dataset/Train/emabega/audio #4708.wav, segment:3
# Dataset/Train/emabega/audio #4539.wav, segment:1
# Dataset/Train/emabega/audio #4539.wav, segment:2
# Dataset/Train/emabega/audio #4539.wav, segment:3
# Dataset/Train/emabega/audio #4539.wav, segment:4
# Dataset/Train/emabega/audio #4962.wav, segment:1
# Dataset/Train/emabega/audio #4962.wav, segment:2
# Dataset/Train/emabega/audio #4962.wav, segment:3
# Dataset/Train/emabega/audio #4694.wav, segment:1
# Dataset/Train/emabega/audio #4694.wav, segment:2
# Dataset/Train/emabega/audio #4694.wav, segment:3
# Dataset/Train/emabega/audio #4694.wav, segment:4
# Dataset/Train/emabega/audio #4686.wav, segment:1
# Dataset/Train/emabega/audio #4686.wav, segment:2
# Dataset/Train/emabega/audio #4686.wav, segment:3
# Dataset/Train/emabega/audio #4896.wav, segment:1
# Dataset/Train/emabega/audio #4896.wav, segment:2
# Dataset/Train/emabega/audio #4896.wav, segment:3
# Dataset/Train/emabega/audio #4569.wav, segment:1
# Dataset/Train/emabega/audio #4569.wav, segment:2
# Dataset/Train/emabega/audio #4569.wav, segment:3
# Dataset/Train/emabega/audio #4569.wav, segment:4
# Dataset/Train/emabega/audio #4360.wav, segment:1
# Dataset/Train/emabega/audio #4360.wav, segment:2
# Dataset/Train/emabega/audio #4785.wav, segment:1
# Dataset/Train/emabega/audio #4785.wav, segment:2
# Dataset/Train/emabega/audio #4785.wav, segment:3
# Dataset/Train/emabega/audio #4785.wav, segment:4
# Dataset/Train/emabega/audio #4352.wav, segment:1
# Dataset/Train/emabega/audio #4352.wav, segment:2
# Dataset/Train/emabega/audio #4792.wav, segment:1
# Dataset/Train/emabega/audio #4792.wav, segment:2
# Dataset/Train/emabega/audio #4792.wav, segment:3
# Dataset/Train/emabega/audio #4792.wav, segment:4
# Dataset/Train/emabega/audio #4882.wav, segment:1
# Dataset/Train/emabega/audio #4882.wav, segment:2
# Dataset/Train/emabega/audio #4882.wav, segment:3
# Dataset/Train/emabega/audio #4854.wav, segment:1
# Dataset/Train/emabega/audio #4854.wav, segment:2
# Dataset/Train/emabega/audio #4854.wav, segment:3
# Dataset/Train/emabega/audio #4356.wav, segment:1
# Dataset/Train/emabega/audio #4356.wav, segment:2
# Dataset/Train/emabega/audio #5045.wav, segment:1
# Dataset/Train/emabega/audio #5045.wav, segment:2
# Dataset/Train/emabega/audio #5045.wav, segment:3
# Dataset/Train/emabega/audio #5045.wav, segment:4
# Dataset/Train/emabega/audio #4540.wav, segment:1
# Dataset/Train/emabega/audio #4540.wav, segment:2
# Dataset/Train/emabega/audio #4540.wav, segment:3
# Dataset/Train/emabega/audio #4540.wav, segment:4
# Dataset/Train/emabega/audio #4523.wav, segment:1
# Dataset/Train/emabega/audio #4523.wav, segment:2
# Dataset/Train/emabega/audio #4523.wav, segment:3
# Dataset/Train/emabega/audio #4865.wav, segment:1
# Dataset/Train/emabega/audio #4865.wav, segment:2
# Dataset/Train/emabega/audio #4865.wav, segment:3
# Dataset/Train/emabega/audio #5005.wav, segment:1
# Dataset/Train/emabega/audio #5005.wav, segment:2
# Dataset/Train/emabega/audio #5005.wav, segment:3
# Dataset/Train/emabega/audio #5005.wav, segment:4
# Dataset/Train/emabega/audio #4999.wav, segment:1
# Dataset/Train/emabega/audio #4999.wav, segment:2
# Dataset/Train/emabega/audio #4999.wav, segment:3
# Dataset/Train/emabega/audio #4737.wav, segment:1
# Dataset/Train/emabega/audio #4737.wav, segment:2
# Dataset/Train/emabega/audio #4737.wav, segment:3
# Dataset/Train/emabega/audio #4737.wav, segment:4
# Dataset/Train/emabega/audio #4734.wav, segment:1
# Dataset/Train/emabega/audio #4734.wav, segment:2
# Dataset/Train/emabega/audio #4734.wav, segment:3
# Dataset/Train/emabega/audio #4734.wav, segment:4
# Dataset/Train/emabega/audio #4667.wav, segment:1
# Dataset/Train/emabega/audio #4667.wav, segment:2
# Dataset/Train/emabega/audio #4667.wav, segment:3
# Dataset/Train/emabega/audio #4667.wav, segment:4
# Dataset/Train/emabega/audio #4349.wav, segment:1
# Dataset/Train/emabega/audio #4349.wav, segment:2
# Dataset/Train/emabega/audio #4981.wav, segment:1
# Dataset/Train/emabega/audio #4981.wav, segment:2
# Dataset/Train/emabega/audio #4981.wav, segment:3
# Dataset/Train/emabega/audio #4816.wav, segment:1
# Dataset/Train/emabega/audio #4816.wav, segment:2
# Dataset/Train/emabega/audio #4816.wav, segment:3
# Dataset/Train/emabega/audio #4738.wav, segment:1
# Dataset/Train/emabega/audio #4738.wav, segment:2
# Dataset/Train/emabega/audio #4738.wav, segment:3
# Dataset/Train/emabega/audio #4834.wav, segment:1
# Dataset/Train/emabega/audio #4834.wav, segment:2
# Dataset/Train/emabega/audio #5484.wav, segment:1
# Dataset/Train/emabega/audio #5484.wav, segment:2
# Dataset/Train/emabega/audio #4862.wav, segment:1
# Dataset/Train/emabega/audio #4862.wav, segment:2
# Dataset/Train/emabega/audio #4681.wav, segment:1
# Dataset/Train/emabega/audio #4681.wav, segment:2
# Dataset/Train/emabega/audio #4681.wav, segment:3
# Dataset/Train/emabega/audio #4681.wav, segment:4
# Dataset/Train/emabega/audio #4955.wav, segment:1
# Dataset/Train/emabega/audio #4955.wav, segment:2
# Dataset/Train/emabega/audio #4955.wav, segment:3
# Dataset/Train/emabega/audio #4712.wav, segment:1
# Dataset/Train/emabega/audio #4712.wav, segment:2
# Dataset/Train/emabega/audio #4712.wav, segment:3
# Dataset/Train/emabega/audio #4867.wav, segment:1
# Dataset/Train/emabega/audio #4867.wav, segment:2
# Dataset/Train/emabega/audio #4867.wav, segment:3
# Dataset/Train/emabega/audio #4693.wav, segment:1
# Dataset/Train/emabega/audio #4693.wav, segment:2
# Dataset/Train/emabega/audio #4693.wav, segment:3
# Dataset/Train/emabega/audio #4950.wav, segment:1
# Dataset/Train/emabega/audio #4950.wav, segment:2
# Dataset/Train/emabega/audio #4950.wav, segment:3
# Dataset/Train/emabega/audio #4338.wav, segment:1
# Dataset/Train/emabega/audio #4338.wav, segment:2
# Dataset/Train/emabega/audio #4332.wav, segment:1
# Dataset/Train/emabega/audio #4332.wav, segment:2
# Dataset/Train/emabega/audio #4996.wav, segment:1
# Dataset/Train/emabega/audio #4996.wav, segment:2
# Dataset/Train/emabega/audio #4996.wav, segment:3
# Dataset/Train/emabega/audio #4947.wav, segment:1
# Dataset/Train/emabega/audio #4947.wav, segment:2
# Dataset/Train/emabega/audio #4947.wav, segment:3
# Dataset/Train/emabega/audio #4947.wav, segment:4
# Dataset/Train/emabega/audio #4863.wav, segment:1
# Dataset/Train/emabega/audio #4863.wav, segment:2
# Dataset/Train/emabega/audio #4863.wav, segment:3
# Dataset/Train/emabega/audio #4591.wav, segment:1
# Dataset/Train/emabega/audio #4591.wav, segment:2
# Dataset/Train/emabega/audio #4591.wav, segment:3
# Dataset/Train/emabega/audio #4918.wav, segment:1
# Dataset/Train/emabega/audio #4918.wav, segment:2
# Dataset/Train/emabega/audio #4604.wav, segment:1
# Dataset/Train/emabega/audio #4604.wav, segment:2
# Dataset/Train/emabega/audio #4604.wav, segment:3
# Dataset/Train/emabega/audio #4835.wav, segment:1
# Dataset/Train/emabega/audio #4835.wav, segment:2
# Dataset/Train/emabega/audio #4835.wav, segment:3
# Dataset/Train/emabega/audio #4773.wav, segment:1
# Dataset/Train/emabega/audio #4773.wav, segment:2
# Dataset/Train/emabega/audio #4773.wav, segment:3
# Dataset/Train/emabega/audio #4956.wav, segment:1
# Dataset/Train/emabega/audio #4956.wav, segment:2
# Dataset/Train/emabega/audio #4597.wav, segment:1
# Dataset/Train/emabega/audio #4597.wav, segment:2
# Dataset/Train/emabega/audio #4597.wav, segment:3
# Dataset/Train/emabega/audio #4933.wav, segment:1
# Dataset/Train/emabega/audio #4933.wav, segment:2
# Dataset/Train/emabega/audio #4933.wav, segment:3
# Dataset/Train/emabega/audio #4765.wav, segment:1
# Dataset/Train/emabega/audio #4765.wav, segment:2
# Dataset/Train/emabega/audio #4765.wav, segment:3
# Dataset/Train/emabega/audio #4765.wav, segment:4
# Dataset/Train/emabega/audio #4880.wav, segment:1
# Dataset/Train/emabega/audio #4880.wav, segment:2
# Dataset/Train/emabega/audio #4880.wav, segment:3
# Dataset/Train/emabega/audio #4252.wav, segment:1
# Dataset/Train/emabega/audio #4252.wav, segment:2
# Dataset/Train/emabega/audio #4252.wav, segment:3
# Dataset/Train/emabega/audio #4760.wav, segment:1
# Dataset/Train/emabega/audio #4760.wav, segment:2
# Dataset/Train/emabega/audio #4760.wav, segment:3
# Dataset/Train/emabega/audio #4760.wav, segment:4
# Dataset/Train/emabega/audio #4907.wav, segment:1
# Dataset/Train/emabega/audio #4907.wav, segment:2
# Dataset/Train/emabega/audio #4907.wav, segment:3
# Dataset/Train/emabega/audio #4592.wav, segment:1
# Dataset/Train/emabega/audio #4592.wav, segment:2
# Dataset/Train/emabega/audio #4592.wav, segment:3
# Dataset/Train/emabega/audio #4713.wav, segment:1
# Dataset/Train/emabega/audio #4713.wav, segment:2
# Dataset/Train/emabega/audio #4713.wav, segment:3
# Dataset/Train/emabega/audio #4713.wav, segment:4
# Dataset/Train/emabega/audio #4531.wav, segment:1
# Dataset/Train/emabega/audio #4531.wav, segment:2
# Dataset/Train/emabega/audio #4531.wav, segment:3
# Dataset/Train/emabega/audio #4570.wav, segment:1
# Dataset/Train/emabega/audio #4570.wav, segment:2
# Dataset/Train/emabega/audio #4570.wav, segment:3
# Dataset/Train/emabega/audio #4551.wav, segment:1
# Dataset/Train/emabega/audio #4551.wav, segment:2
# Dataset/Train/emabega/audio #4551.wav, segment:3
# Dataset/Train/emabega/audio #4754.wav, segment:1
# Dataset/Train/emabega/audio #4754.wav, segment:2
# Dataset/Train/emabega/audio #4754.wav, segment:3
# Dataset/Train/emabega/audio #4754.wav, segment:4
# Dataset/Train/emabega/audio #4754.wav, segment:5
# Dataset/Train/emabega/audio #5004.wav, segment:1
# Dataset/Train/emabega/audio #5004.wav, segment:2
# Dataset/Train/emabega/audio #5004.wav, segment:3
# Dataset/Train/emabega/audio #4599.wav, segment:1
# Dataset/Train/emabega/audio #4599.wav, segment:2
# Dataset/Train/emabega/audio #4599.wav, segment:3
# Dataset/Train/emabega/audio #4864.wav, segment:1
# Dataset/Train/emabega/audio #4864.wav, segment:2
# Dataset/Train/emabega/audio #4864.wav, segment:3
# Dataset/Train/emabega/audio #4814.wav, segment:1
# Dataset/Train/emabega/audio #4814.wav, segment:2
# Dataset/Train/emabega/audio #4814.wav, segment:3
# Dataset/Train/emabega/audio #4351.wav, segment:1
# Dataset/Train/emabega/audio #4351.wav, segment:2
# Dataset/Train/emabega/audio #4957.wav, segment:1
# Dataset/Train/emabega/audio #4957.wav, segment:2
# Dataset/Train/emabega/audio #4957.wav, segment:3
# Dataset/Train/emabega/audio #4666.wav, segment:1
# Dataset/Train/emabega/audio #4666.wav, segment:2
# Dataset/Train/emabega/audio #4666.wav, segment:3
# Dataset/Train/emabega/audio #4666.wav, segment:4
# Dataset/Train/emabega/audio #4807.wav, segment:1
# Dataset/Train/emabega/audio #4807.wav, segment:2
# Dataset/Train/emabega/audio #4807.wav, segment:3
# Dataset/Train/emabega/audio #4807.wav, segment:4
# Dataset/Train/emabega/audio #4807.wav, segment:5
# Dataset/Train/emabega/audio #4687.wav, segment:1
# Dataset/Train/emabega/audio #4687.wav, segment:2
# Dataset/Train/emabega/audio #4687.wav, segment:3
# Dataset/Train/emabega/audio #4687.wav, segment:4
# Dataset/Train/emabega/audio #4610.wav, segment:1
# Dataset/Train/emabega/audio #4610.wav, segment:2
# Dataset/Train/emabega/audio #4610.wav, segment:3
# Dataset/Train/emabega/audio #4605.wav, segment:1
# Dataset/Train/emabega/audio #4605.wav, segment:2
# Dataset/Train/emabega/audio #4605.wav, segment:3
# Dataset/Train/emabega/audio #4521.wav, segment:1
# Dataset/Train/emabega/audio #4521.wav, segment:2
# Dataset/Train/emabega/audio #4788.wav, segment:1
# Dataset/Train/emabega/audio #4788.wav, segment:2
# Dataset/Train/emabega/audio #4788.wav, segment:3
# Dataset/Train/emabega/audio #4788.wav, segment:4
# Dataset/Train/emabega/audio #4986.wav, segment:1
# Dataset/Train/emabega/audio #4986.wav, segment:2
# Dataset/Train/emabega/audio #4986.wav, segment:3
# Dataset/Train/emabega/audio #4846.wav, segment:1
# Dataset/Train/emabega/audio #4846.wav, segment:2
# Dataset/Train/emabega/audio #4846.wav, segment:3
# Dataset/Train/emabega/audio #4833.wav, segment:1
# Dataset/Train/emabega/audio #4833.wav, segment:2
# Dataset/Train/emabega/audio #4348.wav, segment:1
# Dataset/Train/emabega/audio #4348.wav, segment:2
# Dataset/Train/emabega/audio #4982.wav, segment:1
# Dataset/Train/emabega/audio #4982.wav, segment:2
# Dataset/Train/emabega/audio #4982.wav, segment:3
# Dataset/Train/emabega/audio #5049.wav, segment:1
# Dataset/Train/emabega/audio #5049.wav, segment:2
# Dataset/Train/emabega/audio #5049.wav, segment:3
# Dataset/Train/emabega/audio #5049.wav, segment:4
# Dataset/Train/emabega/audio #4961.wav, segment:1
# Dataset/Train/emabega/audio #4961.wav, segment:2
# Dataset/Train/emabega/audio #4961.wav, segment:3
# Dataset/Train/emabega/audio #4781.wav, segment:1
# Dataset/Train/emabega/audio #4781.wav, segment:2
# Dataset/Train/emabega/audio #4781.wav, segment:3
# Dataset/Train/emabega/audio #4781.wav, segment:4
# Dataset/Train/emabega/audio #4849.wav, segment:1
# Dataset/Train/emabega/audio #4849.wav, segment:2
# Dataset/Train/emabega/audio #4849.wav, segment:3
# Dataset/Train/emabega/audio #4714.wav, segment:1
# Dataset/Train/emabega/audio #4714.wav, segment:2
# Dataset/Train/emabega/audio #4714.wav, segment:3
# Dataset/Train/emabega/audio #4714.wav, segment:4
# Dataset/Train/emabega/audio #4366.wav, segment:1
# Dataset/Train/emabega/audio #4366.wav, segment:2
# Dataset/Train/emabega/audio #4675.wav, segment:1
# Dataset/Train/emabega/audio #4675.wav, segment:2
# Dataset/Train/emabega/audio #4675.wav, segment:3
# Dataset/Train/emabega/audio #4675.wav, segment:4
# Dataset/Train/emabega/audio #4969.wav, segment:1
# Dataset/Train/emabega/audio #4969.wav, segment:2
# Dataset/Train/emabega/audio #4969.wav, segment:3
# Dataset/Train/emabega/audio #4790.wav, segment:1
# Dataset/Train/emabega/audio #4790.wav, segment:2
# Dataset/Train/emabega/audio #4790.wav, segment:3
# Dataset/Train/emabega/audio #4739.wav, segment:1
# Dataset/Train/emabega/audio #4739.wav, segment:2
# Dataset/Train/emabega/audio #4739.wav, segment:3
# Dataset/Train/emabega/audio #4543.wav, segment:1
# Dataset/Train/emabega/audio #4543.wav, segment:2
# Dataset/Train/emabega/audio #4543.wav, segment:3
# Dataset/Train/emabega/audio #4717.wav, segment:1
# Dataset/Train/emabega/audio #4717.wav, segment:2
# Dataset/Train/emabega/audio #4717.wav, segment:3
# Dataset/Train/emabega/audio #4359.wav, segment:1
# Dataset/Train/emabega/audio #4359.wav, segment:2
# Dataset/Train/emabega/audio #4941.wav, segment:1
# Dataset/Train/emabega/audio #4941.wav, segment:2
# Dataset/Train/emabega/audio #4941.wav, segment:3
# Dataset/Train/emabega/audio #4330.wav, segment:1
# Dataset/Train/emabega/audio #4330.wav, segment:2
# Dataset/Train/emabega/audio #4899.wav, segment:1
# Dataset/Train/emabega/audio #4899.wav, segment:2
# Dataset/Train/emabega/audio #4899.wav, segment:3
# Dataset/Train/emabega/audio #4367.wav, segment:1
# Dataset/Train/emabega/audio #4367.wav, segment:2
# Dataset/Train/emabega/audio #4946.wav, segment:1
# Dataset/Train/emabega/audio #4946.wav, segment:2
# Dataset/Train/emabega/audio #4946.wav, segment:3
# Dataset/Train/emabega/audio #4914.wav, segment:1
# Dataset/Train/emabega/audio #4914.wav, segment:2
# Dataset/Train/emabega/audio #4914.wav, segment:3
# Dataset/Train/emabega/audio #5070.wav, segment:1
# Dataset/Train/emabega/audio #5070.wav, segment:2
# Dataset/Train/emabega/audio #5070.wav, segment:3
# Dataset/Train/emabega/audio #5070.wav, segment:4
# Dataset/Train/emabega/audio #4965.wav, segment:1
# Dataset/Train/emabega/audio #4965.wav, segment:2
# Dataset/Train/emabega/audio #4965.wav, segment:3
# Dataset/Train/emabega/audio #4770.wav, segment:1
# Dataset/Train/emabega/audio #4770.wav, segment:2
# Dataset/Train/emabega/audio #4770.wav, segment:3
# Dataset/Train/emabega/audio #4770.wav, segment:4
# Dataset/Train/emabega/audio #4329.wav, segment:1
# Dataset/Train/emabega/audio #4329.wav, segment:2
# Dataset/Train/emabega/audio #4813.wav, segment:1
# Dataset/Train/emabega/audio #4813.wav, segment:2
# Dataset/Train/emabega/audio #4813.wav, segment:3
# Dataset/Train/emabega/audio #4357.wav, segment:1
# Dataset/Train/emabega/audio #4357.wav, segment:2
# Dataset/Train/emabega/audio #5483.wav, segment:1
# Dataset/Train/emabega/audio #5483.wav, segment:2
# Dataset/Train/emabega/audio #5483.wav, segment:3
# Dataset/Train/emabega/audio #4787.wav, segment:1
# Dataset/Train/emabega/audio #4787.wav, segment:2
# Dataset/Train/emabega/audio #4787.wav, segment:3
# Dataset/Train/emabega/audio #4787.wav, segment:4
# Dataset/Train/emabega/audio #4669.wav, segment:1
# Dataset/Train/emabega/audio #4669.wav, segment:2
# Dataset/Train/emabega/audio #4669.wav, segment:3
# Dataset/Train/emabega/audio #4810.wav, segment:1
# Dataset/Train/emabega/audio #4810.wav, segment:2
# Dataset/Train/emabega/audio #4810.wav, segment:3
# Dataset/Train/emabega/audio #4810.wav, segment:4
# Dataset/Train/emabega/audio #4810.wav, segment:5
# Dataset/Train/emabega/audio #4812.wav, segment:1
# Dataset/Train/emabega/audio #4812.wav, segment:2
# Dataset/Train/emabega/audio #4812.wav, segment:3
# Dataset/Train/emabega/audio #4632.wav, segment:1
# Dataset/Train/emabega/audio #4632.wav, segment:2
# Dataset/Train/emabega/audio #4632.wav, segment:3
# Dataset/Train/emabega/audio #4559.wav, segment:1
# Dataset/Train/emabega/audio #4559.wav, segment:2
# Dataset/Train/emabega/audio #4559.wav, segment:3
# Dataset/Train/emabega/audio #4559.wav, segment:4
# Dataset/Train/emabega/audio #4557.wav, segment:1
# Dataset/Train/emabega/audio #4557.wav, segment:2
# Dataset/Train/emabega/audio #4557.wav, segment:3
# Dataset/Train/emabega/audio #4756.wav, segment:1
# Dataset/Train/emabega/audio #4756.wav, segment:2
# Dataset/Train/emabega/audio #4756.wav, segment:3
# Dataset/Train/emabega/audio #4756.wav, segment:4
# Dataset/Train/emabega/audio #4579.wav, segment:1
# Dataset/Train/emabega/audio #4579.wav, segment:2
# Dataset/Train/emabega/audio #4579.wav, segment:3
# Dataset/Train/emabega/audio #4579.wav, segment:4
# Dataset/Train/emabega/audio #4530.wav, segment:1
# Dataset/Train/emabega/audio #4530.wav, segment:2
# Dataset/Train/emabega/audio #4331.wav, segment:1
# Dataset/Train/emabega/audio #4331.wav, segment:2
# Dataset/Train/emabega/audio #4541.wav, segment:1
# Dataset/Train/emabega/audio #4541.wav, segment:2
# Dataset/Train/emabega/audio #4541.wav, segment:3
# Dataset/Train/emabega/audio #4560.wav, segment:1
# Dataset/Train/emabega/audio #4560.wav, segment:2
# Dataset/Train/emabega/audio #4560.wav, segment:3
# Dataset/Train/emabega/audio #4940.wav, segment:1
# Dataset/Train/emabega/audio #4940.wav, segment:2
# Dataset/Train/emabega/audio #4940.wav, segment:3
# Dataset/Train/emabega/audio #5035.wav, segment:1
# Dataset/Train/emabega/audio #5035.wav, segment:2
# Dataset/Train/emabega/audio #5035.wav, segment:3
# Dataset/Train/emabega/audio #5035.wav, segment:4
# Dataset/Train/emabega/audio #4318.wav, segment:1
# Dataset/Train/emabega/audio #4318.wav, segment:2
# Dataset/Train/emabega/audio #4711.wav, segment:1
# Dataset/Train/emabega/audio #4711.wav, segment:2
# Dataset/Train/emabega/audio #4711.wav, segment:3
# Dataset/Train/emabega/audio #4711.wav, segment:4
# Dataset/Train/emabega/audio #4794.wav, segment:1
# Dataset/Train/emabega/audio #4794.wav, segment:2
# Dataset/Train/emabega/audio #4794.wav, segment:3
# Dataset/Train/emabega/audio #5018.wav, segment:1
# Dataset/Train/emabega/audio #5018.wav, segment:2
# Dataset/Train/emabega/audio #5018.wav, segment:3
# Dataset/Train/emabega/audio #5018.wav, segment:4
# Dataset/Train/emabega/audio #4838.wav, segment:1
# Dataset/Train/emabega/audio #4838.wav, segment:2
# Dataset/Train/emabega/audio #4838.wav, segment:3
# Dataset/Train/emabega/audio #4341.wav, segment:1
# Dataset/Train/emabega/audio #4341.wav, segment:2
# Dataset/Train/emabega/audio #4341.wav, segment:3
# Dataset/Train/emabega/audio #4341.wav, segment:4
# Dataset/Train/emabega/audio #5000.wav, segment:1
# Dataset/Train/emabega/audio #5000.wav, segment:2
# Dataset/Train/emabega/audio #5000.wav, segment:3
# Dataset/Train/emabega/audio #5006.wav, segment:1
# Dataset/Train/emabega/audio #5006.wav, segment:2
# Dataset/Train/emabega/audio #5006.wav, segment:3
# Dataset/Train/emabega/audio #5073.wav, segment:1
# Dataset/Train/emabega/audio #5073.wav, segment:2
# Dataset/Train/emabega/audio #5073.wav, segment:3
# Dataset/Train/emabega/audio #5073.wav, segment:4
# Dataset/Train/emabega/audio #4742.wav, segment:1
# Dataset/Train/emabega/audio #4742.wav, segment:2
# Dataset/Train/emabega/audio #4742.wav, segment:3
# Dataset/Train/emabega/audio #4742.wav, segment:4
# Dataset/Train/emabega/audio #4554.wav, segment:1
# Dataset/Train/emabega/audio #4554.wav, segment:2
# Dataset/Train/emabega/audio #4554.wav, segment:3
# Dataset/Train/emabega/audio #4779.wav, segment:1
# Dataset/Train/emabega/audio #4779.wav, segment:2
# Dataset/Train/emabega/audio #4779.wav, segment:3
# Dataset/Train/emabega/audio #4954.wav, segment:1
# Dataset/Train/emabega/audio #4954.wav, segment:2
# Dataset/Train/emabega/audio #4954.wav, segment:3
# Dataset/Train/emabega/audio #4805.wav, segment:1
# Dataset/Train/emabega/audio #4805.wav, segment:2
# Dataset/Train/emabega/audio #4805.wav, segment:3
# Dataset/Train/emabega/audio #4805.wav, segment:4
# Dataset/Train/emabega/audio #4702.wav, segment:1
# Dataset/Train/emabega/audio #4702.wav, segment:2
# Dataset/Train/emabega/audio #4702.wav, segment:3
# Dataset/Train/emabega/audio #4832.wav, segment:1
# Dataset/Train/emabega/audio #4832.wav, segment:2
# Dataset/Train/emabega/audio #4832.wav, segment:3
# Dataset/Train/emabega/audio #4878.wav, segment:1
# Dataset/Train/emabega/audio #4878.wav, segment:2
# Dataset/Train/emabega/audio #4578.wav, segment:1
# Dataset/Train/emabega/audio #4578.wav, segment:2
# Dataset/Train/emabega/audio #4578.wav, segment:3
# Dataset/Train/emabega/audio #4578.wav, segment:4
# Dataset/Train/emabega/audio #4802.wav, segment:1
# Dataset/Train/emabega/audio #4802.wav, segment:2
# Dataset/Train/emabega/audio #4802.wav, segment:3
# Dataset/Train/emabega/audio #5061.wav, segment:1
# Dataset/Train/emabega/audio #5061.wav, segment:2
# Dataset/Train/emabega/audio #5061.wav, segment:3
# Dataset/Train/emabega/audio #5025.wav, segment:1
# Dataset/Train/emabega/audio #5025.wav, segment:2
# Dataset/Train/emabega/audio #5025.wav, segment:3
# Dataset/Train/emabega/audio #5025.wav, segment:4
# Dataset/Train/emabega/audio #4767.wav, segment:1
# Dataset/Train/emabega/audio #4767.wav, segment:2
# Dataset/Train/emabega/audio #4767.wav, segment:3
# Dataset/Train/emabega/audio #4968.wav, segment:1
# Dataset/Train/emabega/audio #4968.wav, segment:2
# Dataset/Train/emabega/audio #4968.wav, segment:3
# Dataset/Train/emabega/audio #4533.wav, segment:1
# Dataset/Train/emabega/audio #4533.wav, segment:2
# Dataset/Train/emabega/audio #5044.wav, segment:1
# Dataset/Train/emabega/audio #5044.wav, segment:2
# Dataset/Train/emabega/audio #5044.wav, segment:3
# Dataset/Train/emabega/audio #5044.wav, segment:4
# Dataset/Train/emabega/audio #4761.wav, segment:1
# Dataset/Train/emabega/audio #4761.wav, segment:2
# Dataset/Train/emabega/audio #4761.wav, segment:3
# Dataset/Train/emabega/audio #4761.wav, segment:4
# Dataset/Train/emabega/audio #4948.wav, segment:1
# Dataset/Train/emabega/audio #4948.wav, segment:2
# Dataset/Train/emabega/audio #4948.wav, segment:3
# Dataset/Train/emabega/audio #5001.wav, segment:1
# Dataset/Train/emabega/audio #5001.wav, segment:2
# Dataset/Train/emabega/audio #5001.wav, segment:3
# Dataset/Train/emabega/audio #4915.wav, segment:1
# Dataset/Train/emabega/audio #4915.wav, segment:2
# Dataset/Train/emabega/audio #4915.wav, segment:3
# Dataset/Train/emabega/audio #5067.wav, segment:1
# Dataset/Train/emabega/audio #5067.wav, segment:2
# Dataset/Train/emabega/audio #5067.wav, segment:3
# Dataset/Train/emabega/audio #5067.wav, segment:4
# Dataset/Train/emabega/audio #5058.wav, segment:1
# Dataset/Train/emabega/audio #5058.wav, segment:2
# Dataset/Train/emabega/audio #5058.wav, segment:3
# Dataset/Train/emabega/audio #5058.wav, segment:4
# Dataset/Train/emabega/audio #4611.wav, segment:1
# Dataset/Train/emabega/audio #4611.wav, segment:2
# Dataset/Train/emabega/audio #4611.wav, segment:3
# Dataset/Train/emabega/audio #4905.wav, segment:1
# Dataset/Train/emabega/audio #4905.wav, segment:2
# Dataset/Train/emabega/audio #4905.wav, segment:3
# Dataset/Train/emabega/audio #4828.wav, segment:1
# Dataset/Train/emabega/audio #4828.wav, segment:2
# Dataset/Train/emabega/audio #4828.wav, segment:3
# Dataset/Train/emabega/audio #4343.wav, segment:1
# Dataset/Train/emabega/audio #4343.wav, segment:2
# Dataset/Train/emabega/audio #5010.wav, segment:1
# Dataset/Train/emabega/audio #5010.wav, segment:2
# Dataset/Train/emabega/audio #5010.wav, segment:3
# Dataset/Train/emabega/audio #5010.wav, segment:4
# Dataset/Train/emabega/audio #4902.wav, segment:1
# Dataset/Train/emabega/audio #4902.wav, segment:2
# Dataset/Train/emabega/audio #4902.wav, segment:3
# Dataset/Train/emabega/audio #4758.wav, segment:1
# Dataset/Train/emabega/audio #4758.wav, segment:2
# Dataset/Train/emabega/audio #4758.wav, segment:3
# Dataset/Train/emabega/audio #4758.wav, segment:4
# Dataset/Train/emabega/audio #4619.wav, segment:1
# Dataset/Train/emabega/audio #4619.wav, segment:2
# Dataset/Train/emabega/audio #4619.wav, segment:3
# Dataset/Train/emabega/audio #4668.wav, segment:1
# Dataset/Train/emabega/audio #4668.wav, segment:2
# Dataset/Train/emabega/audio #4668.wav, segment:3
# Dataset/Train/emabega/audio #4668.wav, segment:4
# Dataset/Train/emabega/audio #4668.wav, segment:5
# Dataset/Train/emabega/audio #4546.wav, segment:1
# Dataset/Train/emabega/audio #4546.wav, segment:2
# Dataset/Train/emabega/audio #4546.wav, segment:3
# Dataset/Train/emabega/audio #4951.wav, segment:1
# Dataset/Train/emabega/audio #4951.wav, segment:2
# Dataset/Train/emabega/audio #4951.wav, segment:3
# Dataset/Train/emabega/audio #4700.wav, segment:1
# Dataset/Train/emabega/audio #4700.wav, segment:2
# Dataset/Train/emabega/audio #4700.wav, segment:3
# Dataset/Train/emabega/audio #4700.wav, segment:4
# Dataset/Train/emabega/audio #4904.wav, segment:1
# Dataset/Train/emabega/audio #4904.wav, segment:2
# Dataset/Train/emabega/audio #4958.wav, segment:1
# Dataset/Train/emabega/audio #4958.wav, segment:2
# Dataset/Train/emabega/audio #4958.wav, segment:3
# Dataset/Train/emabega/audio #4622.wav, segment:1
# Dataset/Train/emabega/audio #4622.wav, segment:2
# Dataset/Train/emabega/audio #4622.wav, segment:3
# Dataset/Train/emabega/audio #4622.wav, segment:4
# Dataset/Train/emabega/audio #4836.wav, segment:1
# Dataset/Train/emabega/audio #4836.wav, segment:2
# Dataset/Train/emabega/audio #4836.wav, segment:3
# Dataset/Train/emabega/audio #4607.wav, segment:1
# Dataset/Train/emabega/audio #4607.wav, segment:2
# Dataset/Train/emabega/audio #4607.wav, segment:3
# Dataset/Train/emabega/audio #4736.wav, segment:1
# Dataset/Train/emabega/audio #4736.wav, segment:2
# Dataset/Train/emabega/audio #4736.wav, segment:3
# Dataset/Train/emabega/audio #4736.wav, segment:4
# Dataset/Train/emabega/audio #5060.wav, segment:1
# Dataset/Train/emabega/audio #5060.wav, segment:2
# Dataset/Train/emabega/audio #5060.wav, segment:3
# Dataset/Train/emabega/audio #5060.wav, segment:4
# Dataset/Train/emabega/audio #4555.wav, segment:1
# Dataset/Train/emabega/audio #4555.wav, segment:2
# Dataset/Train/emabega/audio #4555.wav, segment:3
# Dataset/Train/emabega/audio #4906.wav, segment:1
# Dataset/Train/emabega/audio #4906.wav, segment:2
# Dataset/Train/emabega/audio #4906.wav, segment:3
# Dataset/Train/emabega/audio #4574.wav, segment:1
# Dataset/Train/emabega/audio #4574.wav, segment:2
# Dataset/Train/emabega/audio #4574.wav, segment:3
# Dataset/Train/emabega/audio #4595.wav, segment:1
# Dataset/Train/emabega/audio #4595.wav, segment:2
# Dataset/Train/emabega/audio #4595.wav, segment:3
# Dataset/Train/emabega/audio #4913.wav, segment:1
# Dataset/Train/emabega/audio #4913.wav, segment:2
# Dataset/Train/emabega/audio #4913.wav, segment:3
# Dataset/Train/emabega/audio #4724.wav, segment:1
# Dataset/Train/emabega/audio #4724.wav, segment:2
# Dataset/Train/emabega/audio #4724.wav, segment:3
# Dataset/Train/emabega/audio #4724.wav, segment:4
# Dataset/Train/emabega/audio #4879.wav, segment:1
# Dataset/Train/emabega/audio #4879.wav, segment:2
# Dataset/Train/emabega/audio #4879.wav, segment:3
# Dataset/Train/emabega/audio #4323.wav, segment:1
# Dataset/Train/emabega/audio #4323.wav, segment:2
# Dataset/Train/emabega/audio #4921.wav, segment:1
# Dataset/Train/emabega/audio #4921.wav, segment:2
# Dataset/Train/emabega/audio #4921.wav, segment:3
# Dataset/Train/emabega/audio #4921.wav, segment:4
# Dataset/Train/emabega/audio #5028.wav, segment:1
# Dataset/Train/emabega/audio #5028.wav, segment:2
# Dataset/Train/emabega/audio #5028.wav, segment:3
# Dataset/Train/emabega/audio #5028.wav, segment:4
# Dataset/Train/emabega/audio #4980.wav, segment:1
# Dataset/Train/emabega/audio #4980.wav, segment:2
# Dataset/Train/emabega/audio #4980.wav, segment:3
# Dataset/Train/emabega/audio #4588.wav, segment:1
# Dataset/Train/emabega/audio #4588.wav, segment:2
# Dataset/Train/emabega/audio #4588.wav, segment:3
# Dataset/Train/emabega/audio #4688.wav, segment:1
# Dataset/Train/emabega/audio #4688.wav, segment:2
# Dataset/Train/emabega/audio #4688.wav, segment:3
# Dataset/Train/emabega/audio #4688.wav, segment:4
# Dataset/Train/emabega/audio #4824.wav, segment:1
# Dataset/Train/emabega/audio #4824.wav, segment:2
# Dataset/Train/emabega/audio #4934.wav, segment:1
# Dataset/Train/emabega/audio #4934.wav, segment:2
# Dataset/Train/emabega/audio #4934.wav, segment:3
# Dataset/Train/emabega/audio #4719.wav, segment:1
# Dataset/Train/emabega/audio #4719.wav, segment:2
# Dataset/Train/emabega/audio #4719.wav, segment:3
# Dataset/Train/emabega/audio #4730.wav, segment:1
# Dataset/Train/emabega/audio #4730.wav, segment:2
# Dataset/Train/emabega/audio #4730.wav, segment:3
# Dataset/Train/emabega/audio #4926.wav, segment:1
# Dataset/Train/emabega/audio #4926.wav, segment:2
# Dataset/Train/emabega/audio #4926.wav, segment:3
# Dataset/Train/emabega/audio #4677.wav, segment:1
# Dataset/Train/emabega/audio #4677.wav, segment:2
# Dataset/Train/emabega/audio #4677.wav, segment:3
# Dataset/Train/emabega/audio #4741.wav, segment:1
# Dataset/Train/emabega/audio #4741.wav, segment:2
# Dataset/Train/emabega/audio #4741.wav, segment:3
# Dataset/Train/emabega/audio #4889.wav, segment:1
# Dataset/Train/emabega/audio #4889.wav, segment:2
# Dataset/Train/emabega/audio #4625.wav, segment:1
# Dataset/Train/emabega/audio #4625.wav, segment:2
# Dataset/Train/emabega/audio #4625.wav, segment:3
# Dataset/Train/emabega/audio #4625.wav, segment:4
# Dataset/Train/emabega/audio #4625.wav, segment:5
# Dataset/Train/emabega/audio #4598.wav, segment:1
# Dataset/Train/emabega/audio #4598.wav, segment:2
# Dataset/Train/emabega/audio #4598.wav, segment:3
# Dataset/Train/emabega/audio #4344.wav, segment:1
# Dataset/Train/emabega/audio #4344.wav, segment:2
# Dataset/Train/emabega/audio #4344.wav, segment:3
# Dataset/Train/emabega/audio #4945.wav, segment:1
# Dataset/Train/emabega/audio #4945.wav, segment:2
# Dataset/Train/emabega/audio #4945.wav, segment:3
# Dataset/Train/emabega/audio #4820.wav, segment:1
# Dataset/Train/emabega/audio #4820.wav, segment:2
# Dataset/Train/emabega/audio #4820.wav, segment:3
# Dataset/Train/emabega/audio #4535.wav, segment:1
# Dataset/Train/emabega/audio #4535.wav, segment:2
# Dataset/Train/emabega/audio #4535.wav, segment:3
# ...
# Dataset/Train/yimirira/audio #3023.wav, segment:3
# Dataset/Train/yimirira/audio #3514.wav, segment:1
# Dataset/Train/yimirira/audio #3514.wav, segment:2
# Dataset/Train/yimirira/audio #3514.wav, segment:3
# Dataset/Train/yimirira/audio #3401.wav, segment:1
# Dataset/Train/yimirira/audio #3401.wav, segment:2
# Dataset/Train/yimirira/audio #3401.wav, segment:3
# Dataset/Train/yimirira/audio #3401.wav, segment:4
# Dataset/Train/yimirira/audio #3126.wav, segment:1
# Dataset/Train/yimirira/audio #3126.wav, segment:2
# Dataset/Train/yimirira/audio #3003.wav, segment:1
# Dataset/Train/yimirira/audio #3003.wav, segment:2
# Dataset/Train/yimirira/audio #3003.wav, segment:3
# Dataset/Train/yimirira/audio #3477.wav, segment:1
# Dataset/Train/yimirira/audio #3477.wav, segment:2
# Dataset/Train/yimirira/audio #3477.wav, segment:3
# Dataset/Train/yimirira/audio #3404.wav, segment:1
# Dataset/Train/yimirira/audio #3404.wav, segment:2
# Dataset/Train/yimirira/audio #3404.wav, segment:3
# Dataset/Train/yimirira/audio #3404.wav, segment:4
# Dataset/Train/yimirira/audio #3112.wav, segment:1
# Dataset/Train/yimirira/audio #3112.wav, segment:2
# Dataset/Train/yimirira/audio #3007.wav, segment:1
# Dataset/Train/yimirira/audio #3007.wav, segment:2
# Dataset/Train/yimirira/audio #3007.wav, segment:3
# Dataset/Train/yimirira/audio #3318.wav, segment:1
# Dataset/Train/yimirira/audio #3318.wav, segment:2
# Dataset/Train/yimirira/audio #3318.wav, segment:3
# Dataset/Train/yimirira/audio #3117.wav, segment:1
# Dataset/Train/yimirira/audio #3117.wav, segment:2
# Dataset/Train/yimirira/audio #3528.wav, segment:1
# Dataset/Train/yimirira/audio #3528.wav, segment:2
# Dataset/Train/yimirira/audio #3528.wav, segment:3
# Dataset/Train/yimirira/audio #3528.wav, segment:4
# Dataset/Train/yimirira/audio #3528.wav, segment:5
# Dataset/Train/yimirira/audio #3037.wav, segment:1
# Dataset/Train/yimirira/audio #3037.wav, segment:2
# Dataset/Train/yimirira/audio #3037.wav, segment:3
# Dataset/Train/yimirira/audio #3289.wav, segment:1
# Dataset/Train/yimirira/audio #3289.wav, segment:2
# Dataset/Train/yimirira/audio #3289.wav, segment:3
# Dataset/Train/yimirira/audio #3329.wav, segment:1
# Dataset/Train/yimirira/audio #3329.wav, segment:2
# Dataset/Train/yimirira/audio #3535.wav, segment:1
# Dataset/Train/yimirira/audio #3535.wav, segment:2
# Dataset/Train/yimirira/audio #3535.wav, segment:3
# Dataset/Train/yimirira/audio #3393.wav, segment:1
# Dataset/Train/yimirira/audio #3393.wav, segment:2
# Dataset/Train/yimirira/audio #3375.wav, segment:1
# Dataset/Train/yimirira/audio #3375.wav, segment:2
# Dataset/Train/yimirira/audio #3375.wav, segment:3
# Dataset/Train/yimirira/audio #3137.wav, segment:1
# Dataset/Train/yimirira/audio #3137.wav, segment:2
# Dataset/Train/yimirira/audio #3137.wav, segment:3
# Dataset/Train/yimirira/audio #3204.wav, segment:1
# Dataset/Train/yimirira/audio #3204.wav, segment:2
# Dataset/Train/yimirira/audio #3212.wav, segment:1
# Dataset/Train/yimirira/audio #3212.wav, segment:2
# Dataset/Train/yimirira/audio #3445.wav, segment:1
# Dataset/Train/yimirira/audio #3445.wav, segment:2
# Dataset/Train/yimirira/audio #3445.wav, segment:3
# Dataset/Train/yimirira/audio #3186.wav, segment:1
# Dataset/Train/yimirira/audio #3186.wav, segment:2
# Dataset/Train/yimirira/audio #3313.wav, segment:1
# Dataset/Train/yimirira/audio #3313.wav, segment:2
# Dataset/Train/yimirira/audio #3313.wav, segment:3
# Dataset/Train/yimirira/audio #3564.wav, segment:1
# Dataset/Train/yimirira/audio #3564.wav, segment:2
# Dataset/Train/yimirira/audio #3564.wav, segment:3
# Dataset/Train/yimirira/audio #3564.wav, segment:4
# Dataset/Train/yimirira/audio #3133.wav, segment:1
# Dataset/Train/yimirira/audio #3133.wav, segment:2
# Dataset/Train/yimirira/audio #3133.wav, segment:3
# Dataset/Train/yimirira/audio #3546.wav, segment:2
# Dataset/Train/yimirira/audio #3546.wav, segment:3
# Dataset/Train/yimirira/audio #3158.wav, segment:1
# Dataset/Train/yimirira/audio #3158.wav, segment:2
# Dataset/Train/yimirira/audio #3125.wav, segment:1
# Dataset/Train/yimirira/audio #3125.wav, segment:2
# Dataset/Train/yimirira/audio #3125.wav, segment:3
# Dataset/Train/yimirira/audio #3279.wav, segment:1
# Dataset/Train/yimirira/audio #3279.wav, segment:2
# Dataset/Train/yimirira/audio #3279.wav, segment:3
# Dataset/Train/yimirira/audio #3209.wav, segment:1
# Dataset/Train/yimirira/audio #3209.wav, segment:2
# Dataset/Train/yimirira/audio #3209.wav, segment:3
# Dataset/Train/yimirira/audio #3335.wav, segment:1
# Dataset/Train/yimirira/audio #3335.wav, segment:2
# Dataset/Train/yimirira/audio #3335.wav, segment:3
# Dataset/Train/yimirira/audio #3577.wav, segment:1
# Dataset/Train/yimirira/audio #3577.wav, segment:2
# Dataset/Train/yimirira/audio #3577.wav, segment:3
# Dataset/Train/yimirira/audio #3131.wav, segment:1
# Dataset/Train/yimirira/audio #3131.wav, segment:2
# Dataset/Train/yimirira/audio #3131.wav, segment:3
# Dataset/Train/yimirira/audio #3272.wav, segment:1
# Dataset/Train/yimirira/audio #3272.wav, segment:2
# Dataset/Train/yimirira/audio #3272.wav, segment:3
# Dataset/Train/yimirira/audio #3586.wav, segment:1
# Dataset/Train/yimirira/audio #3586.wav, segment:2
# Dataset/Train/yimirira/audio #3586.wav, segment:3
# Dataset/Train/yimirira/audio #3325.wav, segment:1
# Dataset/Train/yimirira/audio #3325.wav, segment:2
# Dataset/Train/yimirira/audio #3533.wav, segment:1
# Dataset/Train/yimirira/audio #3533.wav, segment:2
# Dataset/Train/yimirira/audio #3533.wav, segment:3
# Dataset/Train/yimirira/audio #3151.wav, segment:1
# Dataset/Train/yimirira/audio #3151.wav, segment:2
# Dataset/Train/yimirira/audio #3151.wav, segment:3
# Dataset/Train/yimirira/audio #3084.wav, segment:1
# Dataset/Train/yimirira/audio #3084.wav, segment:2
# Dataset/Train/yimirira/audio #3576.wav, segment:1
# Dataset/Train/yimirira/audio #3576.wav, segment:2
# Dataset/Train/yimirira/audio #3576.wav, segment:3
# Dataset/Train/yimirira/audio #3576.wav, segment:4
# Dataset/Train/yimirira/audio #3355.wav, segment:1
# Dataset/Train/yimirira/audio #3355.wav, segment:2
# Dataset/Train/yimirira/audio #3355.wav, segment:3
# Dataset/Train/yimirira/audio #3075.wav, segment:1
# Dataset/Train/yimirira/audio #3075.wav, segment:2
# Dataset/Train/yimirira/audio #3078.wav, segment:1
# Dataset/Train/yimirira/audio #3078.wav, segment:2
# Dataset/Train/yimirira/audio #3078.wav, segment:3
# Dataset/Train/yimirira/audio #3419.wav, segment:1
# Dataset/Train/yimirira/audio #3419.wav, segment:2
# Dataset/Train/yimirira/audio #3419.wav, segment:3
# Dataset/Train/yimirira/audio #3051.wav, segment:1
# Dataset/Train/yimirira/audio #3051.wav, segment:2
# Dataset/Train/yimirira/audio #3051.wav, segment:3
# Dataset/Train/yimirira/audio #3073.wav, segment:1
# Dataset/Train/yimirira/audio #3073.wav, segment:2
# Dataset/Train/yimirira/audio #3073.wav, segment:3
# Dataset/Train/yimirira/audio #3185.wav, segment:1
# Dataset/Train/yimirira/audio #3185.wav, segment:2
# Dataset/Train/yimirira/audio #3069.wav, segment:1
# Dataset/Train/yimirira/audio #3069.wav, segment:2
# Dataset/Train/yimirira/audio #3069.wav, segment:3
# Dataset/Train/yimirira/audio #3453.wav, segment:1
# Dataset/Train/yimirira/audio #3453.wav, segment:2
# Dataset/Train/yimirira/audio #3453.wav, segment:3
# Dataset/Train/yimirira/audio #3294.wav, segment:1
# Dataset/Train/yimirira/audio #3294.wav, segment:2
# Dataset/Train/yimirira/audio #3294.wav, segment:3
# Dataset/Train/yimirira/audio #3210.wav, segment:1
# Dataset/Train/yimirira/audio #3210.wav, segment:2
# Dataset/Train/yimirira/audio #3120.wav, segment:1
# Dataset/Train/yimirira/audio #3120.wav, segment:2
# Dataset/Train/yimirira/audio #3120.wav, segment:3
# Dataset/Train/yimirira/audio #3020.wav, segment:1
# Dataset/Train/yimirira/audio #3020.wav, segment:2
# Dataset/Train/yimirira/audio #3020.wav, segment:3
# Dataset/Train/yimirira/audio #3304.wav, segment:1
# Dataset/Train/yimirira/audio #3304.wav, segment:2
# Dataset/Train/yimirira/audio #3304.wav, segment:3
# Dataset/Train/yimirira/audio #3015.wav, segment:1
# Dataset/Train/yimirira/audio #3015.wav, segment:2
# Dataset/Train/yimirira/audio #3015.wav, segment:3
# Dataset/Train/yimirira/audio #3251.wav, segment:1
# Dataset/Train/yimirira/audio #3251.wav, segment:2
# Dataset/Train/yimirira/audio #3251.wav, segment:3
# Dataset/Train/yimirira/audio #3251.wav, segment:4
# Dataset/Train/yimirira/audio #3251.wav, segment:5
# Dataset/Train/yimirira/audio #3505.wav, segment:1
# Dataset/Train/yimirira/audio #3505.wav, segment:2
# Dataset/Train/yimirira/audio #3505.wav, segment:3
# Dataset/Train/yimirira/audio #3256.wav, segment:1
# Dataset/Train/yimirira/audio #3256.wav, segment:2
# Dataset/Train/yimirira/audio #3256.wav, segment:3
# Dataset/Train/yimirira/audio #3529.wav, segment:1
# Dataset/Train/yimirira/audio #3529.wav, segment:2
# Dataset/Train/yimirira/audio #3529.wav, segment:3
# Dataset/Train/yimirira/audio #3163.wav, segment:1
# Dataset/Train/yimirira/audio #3163.wav, segment:2
# Dataset/Train/yimirira/audio #3222.wav, segment:1
# Dataset/Train/yimirira/audio #3222.wav, segment:2
# Dataset/Train/yimirira/audio #3222.wav, segment:3
# Dataset/Train/yimirira/audio #3178.wav, segment:1
# Dataset/Train/yimirira/audio #3178.wav, segment:2
# Dataset/Train/yimirira/audio #3178.wav, segment:3
# Dataset/Train/yimirira/audio #3521.wav, segment:1
# Dataset/Train/yimirira/audio #3521.wav, segment:2
# Dataset/Train/yimirira/audio #3521.wav, segment:3
# Dataset/Train/yimirira/audio #3334.wav, segment:1
# Dataset/Train/yimirira/audio #3334.wav, segment:2
# Dataset/Train/yimirira/audio #3334.wav, segment:3
# Dataset/Train/yimirira/audio #3207.wav, segment:1
# Dataset/Train/yimirira/audio #3207.wav, segment:2
# Dataset/Train/yimirira/audio #3207.wav, segment:3
# Dataset/Train/yimirira/audio #3236.wav, segment:1
# Dataset/Train/yimirira/audio #3236.wav, segment:2
# Dataset/Train/yimirira/audio #3358.wav, segment:1
# Dataset/Train/yimirira/audio #3358.wav, segment:2
# Dataset/Train/yimirira/audio #3358.wav, segment:3
# Dataset/Train/yimirira/audio #3244.wav, segment:1
# Dataset/Train/yimirira/audio #3244.wav, segment:2
# Dataset/Train/yimirira/audio #3552.wav, segment:1
# Dataset/Train/yimirira/audio #3552.wav, segment:2
# Dataset/Train/yimirira/audio #3552.wav, segment:3
# Dataset/Train/yimirira/audio #3481.wav, segment:1
# Dataset/Train/yimirira/audio #3481.wav, segment:2
# Dataset/Train/yimirira/audio #3481.wav, segment:3
# Dataset/Train/yimirira/audio #3226.wav, segment:1
# Dataset/Train/yimirira/audio #3226.wav, segment:2
# Dataset/Train/yimirira/audio #3518.wav, segment:1
# Dataset/Train/yimirira/audio #3518.wav, segment:2
# Dataset/Train/yimirira/audio #3518.wav, segment:3
# Dataset/Train/yimirira/audio #3140.wav, segment:1
# Dataset/Train/yimirira/audio #3140.wav, segment:2
# Dataset/Train/yimirira/audio #3513.wav, segment:1
# Dataset/Train/yimirira/audio #3513.wav, segment:2
# Dataset/Train/yimirira/audio #3513.wav, segment:3
# Dataset/Train/yimirira/audio #3156.wav, segment:1
# Dataset/Train/yimirira/audio #3156.wav, segment:2
# Dataset/Train/yimirira/audio #3315.wav, segment:1
# Dataset/Train/yimirira/audio #3315.wav, segment:2
# Dataset/Train/yimirira/audio #3315.wav, segment:3
# Dataset/Train/yimirira/audio #3432.wav, segment:1
# Dataset/Train/yimirira/audio #3432.wav, segment:2
# Dataset/Train/yimirira/audio #3432.wav, segment:3
# Dataset/Train/yimirira/audio #3002.wav, segment:1
# Dataset/Train/yimirira/audio #3002.wav, segment:2
# Dataset/Train/yimirira/audio #3010.wav, segment:1
# Dataset/Train/yimirira/audio #3010.wav, segment:2
# Dataset/Train/yimirira/audio #3297.wav, segment:1
# Dataset/Train/yimirira/audio #3297.wav, segment:2
# Dataset/Train/yimirira/audio #3101.wav, segment:1
# Dataset/Train/yimirira/audio #3101.wav, segment:2
# Dataset/Train/yimirira/audio #3101.wav, segment:3
# Dataset/Train/yimirira/audio #3093.wav, segment:1
# Dataset/Train/yimirira/audio #3093.wav, segment:2
# Dataset/Train/yimirira/audio #3093.wav, segment:3
# Dataset/Train/yimirira/audio #3202.wav, segment:1
# Dataset/Train/yimirira/audio #3202.wav, segment:2
# Dataset/Train/yimirira/audio #3280.wav, segment:1
# Dataset/Train/yimirira/audio #3280.wav, segment:2
# Dataset/Train/yimirira/audio #3280.wav, segment:3
# Dataset/Train/yimirira/audio #3543.wav, segment:1
# Dataset/Train/yimirira/audio #3543.wav, segment:2
# Dataset/Train/yimirira/audio #3543.wav, segment:3
# Dataset/Train/yimirira/audio #3102.wav, segment:1
# Dataset/Train/yimirira/audio #3102.wav, segment:2
# Dataset/Train/yimirira/audio #3102.wav, segment:3
# Dataset/Train/yimirira/audio #3267.wav, segment:1
# Dataset/Train/yimirira/audio #3267.wav, segment:2
# Dataset/Train/yimirira/audio #3267.wav, segment:3
# Dataset/Train/yimirira/audio #3573.wav, segment:1
# Dataset/Train/yimirira/audio #3573.wav, segment:2
# Dataset/Train/yimirira/audio #3573.wav, segment:3
# Dataset/Train/yimirira/audio #3042.wav, segment:1
# Dataset/Train/yimirira/audio #3042.wav, segment:2
# Dataset/Train/yimirira/audio #3042.wav, segment:3
# Dataset/Train/yimirira/audio #3581.wav, segment:1
# Dataset/Train/yimirira/audio #3581.wav, segment:2
# Dataset/Train/yimirira/audio #3581.wav, segment:3
# Dataset/Train/yimirira/audio #3581.wav, segment:4
# Dataset/Train/yimirira/audio #3598.wav, segment:1
# Dataset/Train/yimirira/audio #3598.wav, segment:2
# Dataset/Train/yimirira/audio #3598.wav, segment:3
# Dataset/Train/yimirira/audio #3598.wav, segment:4
# Dataset/Train/yimirira/audio #3468.wav, segment:1
# Dataset/Train/yimirira/audio #3468.wav, segment:2
# Dataset/Train/yimirira/audio #3468.wav, segment:3
# Dataset/Train/yimirira/audio #3512.wav, segment:1
# Dataset/Train/yimirira/audio #3512.wav, segment:2
# Dataset/Train/yimirira/audio #3512.wav, segment:3

# %% [markdown]
# ## Save the mfcc data

# %%
data = save_mfcc(DATASET_PATH, JSON_PATH, num_segments=6)

# %% [markdown]
# ## Load json file

# %%
def load_data(data):

    # convert lists to numpy arrays
    X = np.array(data["mfcc"])
    y = np.array(data["labels"])

    print("Data successfully loaded!")

    return X, y

# %%
X, y = load_data(data)

# %% [markdown]
# # Split Data into Training and Testing Sets

# %% [markdown]
# ## Extracting MFCCS

# %%
def extract_features(root_folder, n_mfcc=13, hop_length=512, n_fft=1024):
    features = []
    labels = []

    for foldername in os.listdir(root_folder):
        folder_path = os.path.join(root_folder, foldername)

        if os.path.isdir(folder_path):
            for audio_filename in os.listdir(folder_path):
                audio_path = os.path.join(folder_path, audio_filename)

                # Load audio file and extract features
                try:
                    audio_signal, sample_rate = librosa.load(audio_path, sr=None)  # Remove duration parameter
                    mfccs = librosa.feature.mfcc(y=audio_signal, sr=sample_rate, n_mfcc=n_mfcc, hop_length=hop_length, n_fft=n_fft)
                    mfccs_mean = np.mean(mfccs, axis=1)  # Take the mean of MFCCs over time
                    features.append(mfccs_mean)
                    labels.append(foldername)  # Assuming folder names are the labels/categories
                except Exception as e:
                    print(f"Error encountered while processing {audio_path}: {e}")

    return np.array(features), np.array(labels)

# %%
features, labels = extract_features(data_dir, n_mfcc=13, hop_length=512, n_fft=1024)

# %%
# Display the shape of the extracted features and labels
print("Features shape:", features.shape)
print("Labels shape:", labels.shape)
print(labels)

# %% [markdown]
# ## Plot MFCC

# %%
def plot_mfcc(mfccs, sample_rate=22050, hop_length=512):
    mfccs_normalized = librosa.util.normalize(mfccs)

    plt.figure(figsize=(10, 4))
    librosa.display.specshow(mfccs_normalized, sr=sample_rate, hop_length=hop_length, x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('Normalized MFCCs')
    plt.xlabel('Time')
    plt.ylabel('MFCC Coefficients')
    plt.show()

# %%
audio_signal, sample_rate = librosa.load(example_audio_path, sr=SAMPLE_RATE)
mfccs = librosa.feature.mfcc(y=audio_signal, sr=SAMPLE_RATE, n_mfcc=13, hop_length=hop_length, n_fft=1024)
plot_mfcc(mfccs)

# %% [markdown]
# # Data augmentation

# %%
def augment_data(features, labels, speed_factors, sample_rate):
    augmented_features = []
    augmented_labels = []

    for idx, feature in enumerate(features):
        for speed_factor in speed_factors:
            # Time stretch the audio feature
            augmented_feature = librosa.effects.time_stretch(feature, rate=speed_factor)
            # Resample the augmented feature to match the original sample rate
            augmented_feature = librosa.resample(augmented_feature, orig_sr=len(augmented_feature), target_sr=sample_rate)
            augmented_features.append(augmented_feature)
            augmented_labels.append(labels[idx])

    return np.array(augmented_features), np.array(augmented_labels)

# %%
# Example usage:
speed_factors = [0.9, 1.1]  # Adjust as needed
augmented_features, augmented_labels = augment_data(features, labels, speed_factors, sample_rate)

# %%
augmented_features.shape

# %% [markdown]
# # Feature Scaling

# %%
def scale_features(features):
    scaler = StandardScaler()
    scaled_features = scaler.fit_transform(features)
    return scaled_features

scaled_features = scale_features(augmented_features)

# %%
scaled_features.shape

# %% [markdown]
# # Splitting data

# %% [markdown]
# ## Model 1
#
# 1. **Input Layer:** Defines the input shape for the model based on the shape of the spectrogram images.
# 2. **Resizing Layer:** Resizes the input spectrogram images to a fixed size of 32x32 pixels.
# 3. **Normalization Layer:** Normalizes the input data using statistics computed from the training dataset.
# 4. **Convolutional Layers:** Two Conv2D layers with ReLU activation functions, followed by max pooling.
# 5. **Dropout Layer:** Applies dropout regularization to prevent overfitting.
# 6. **Flatten Layer:** Flattens the output of the previous layer into a 1D vector.
# 7. **Dense Layers:** Two Dense layers with ReLU activation functions, followed by the output layer with logits for each class.

# %% [markdown]
# ### Model Arch

# %%
input_shape = example_spectrograms.shape[1:]
print('Input shape:', input_shape)
num_labels = len(label_names)
norm_layer = layers.Normalization()
norm_layer.adapt(data=train_spectrogram_ds.map(map_func=lambda spec, label: spec))

model = models.Sequential([
    layers.Input(shape=input_shape),
    layers.Resizing(32, 32),
    norm_layer,
    layers.Conv2D(32, 3, activation='relu'),
    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Dropout(0.25),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(num_labels),
])

model.summary()

# %% [markdown]
# ### Compile the model

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)

# %% [markdown]
# ### Train the model

# %%
EPOCHS = 10
history = model.fit(
    train_spectrogram_ds,
    validation_data=val_spectrogram_ds,
    epochs=EPOCHS,
    callbacks=tf.keras.callbacks.EarlyStopping(verbose=1, patience=2),
)

# %% [markdown]
# ### Plot Accuracy and Loss

# %%
metrics = history.history
plt.figure(figsize=(14,5))
plt.subplot(1,2,1)
plt.plot(history.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.ylim([0, max(plt.ylim())])
plt.xlabel('Epoch')
plt.ylabel('Loss [CrossEntropy]')

plt.subplot(1,2,2)
plt.plot(history.epoch, 100*np.array(metrics['accuracy']), 100*np.array(metrics['val_accuracy']))
plt.legend(['accuracy', 'val_accuracy'])
plt.ylim([0, 100])
plt.xlabel('Epoch')
plt.ylabel('Accuracy [%]')

# %% [markdown]
# ### Evaluate the model performance
#
# Run the model on the test set and check the model's performance:

# %%
model.evaluate(test_spectrogram_ds, return_dict=True)

# %% [markdown]
# ### Display a confusion matrix

# %%
y_pred = model.predict(test_spectrogram_ds)

# %%
y_pred = tf.argmax(y_pred, axis=1)

# %%
y_true = tf.concat(list(test_spectrogram_ds.map(lambda s,lab: lab)), axis=0)

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_mtx,
            xticklabels=label_names,
            yticklabels=label_names,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %% [markdown]
# ## Model 2
#
#
# 1. **Input Layer**: Defines the input shape for the model based on the shape of the spectrogram images.
# 2. **Resizing Layer**: Resizes the input spectrogram images to a fixed size of 32x32 pixels.
# 3. **Normalization Layer**: Normalizes the input data using statistics computed from the training dataset.
# 4. **Convolutional Layers**:
#    - 4.1. First Conv2D Layer: Applies 32 filters with a 3x3 kernel size and ReLU activation function.
#    - 4.2. Batch Normalization Layer: Normalizes the activations of the previous convolutional layer.
#    - 4.3. MaxPooling2D Layer: Performs max pooling to downsample the feature maps.
# 5. **Convolutional Layers**:
#    - 5.1. Second Conv2D Layer: Applies 64 filters with a 3x3 kernel size and ReLU activation function.
#    - 5.2. Batch Normalization Layer: Normalizes the activations of the previous convolutional layer.
#    - 5.3. MaxPooling2D Layer: Performs max pooling to downsample the feature maps.
# 6. **Dropout Layer**: Applies dropout regularization with a dropout rate of 0.25 to prevent overfitting.
# 7. **Flatten Layer**: Flattens the output of the previous layer into a 1D vector.
# 8. **Dense Layers**:
#    - 8.1. First Dense Layer: Applies 128 neurons with ReLU activation function.
#    - 8.2. Dropout Layer: Applies dropout regularization with a dropout rate of 0.5.
#    - 8.3. Second Dense Layer: Outputs logits for each class, with the number of units equal to the number of labels.

# %% [markdown]
# ### Model Arch

# %%
model2 = models.Sequential([
    layers.Input(shape=input_shape),
    layers.Resizing(32, 32),
    norm_layer,
    layers.Conv2D(32, 3, activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),
    layers.Dropout(0.25),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(num_labels),
])

model2.summary()

# %% [markdown]
# ### Compile the  Model

# %%
model2.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)

timizer=tf.keras.optimizers.Adam(),
loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),

# %% [markdown]
# ### Train the Model

# %%
EPOCHS = 10
history = model2.fit(
    train_spectrogram_ds,
    validation_data=val_spectrogram_ds,
    epochs=EPOCHS,
    callbacks=tf.keras.callbacks.EarlyStopping(verbose=1, patience=2),
)

# %% [markdown]
# ### Plot Accuracy and Loss

# %%
metrics = history.history
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
plt.plot(history.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.ylim([0, max(plt.ylim())])
plt.xlabel('Epoch')
plt.ylabel('Loss [CrossEntropy]')

plt.subplot(1,2,2)
plt.plot(history.epoch, 100*np.array(metrics['accuracy']), 100*np.array(metrics['val_accuracy']))
plt.legend(['accuracy', 'val_accuracy'])
plt.ylim([0, 100])
plt.xlabel('Epoch')
plt.ylabel('Accuracy [%]')

# %% [markdown]
# ### Evaluate the model

# %%
model2.evaluate(test_spectrogram_ds, return_dict=True)

# %% [markdown]
# ### Display a confusion matrix

# %%
y_pred = model2.predict(test_spectrogram_ds)
y_pred = tf.argmax(y_pred, axis=1)
y_true = tf.concat(list(test_spectrogram_ds.map(lambda s,lab: lab)), axis=0)

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_mtx,
            xticklabels=label_names,
            yticklabels=label_names,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %% [markdown]
# ## Model 3
#
# 1. **Input Layer**: Defines the input shape for the model based on the shape of the spectrogram images.
# 2. **Convolutional Layers**:
#    - 2.1. First Conv2D Layer: Applies 32 filters with a 3x3 kernel size, ReLU activation function, and dilation rate of (2, 2).
#    - 2.2. MaxPooling2D Layer: Performs max pooling to downsample the feature maps.
# 3. **Convolutional Layers**:
#    - 3.1. Second Conv2D Layer: Applies 64 filters with a 3x3 kernel size, ReLU activation function, and dilation rate of (2, 2).
#    - 3.2. MaxPooling2D Layer: Performs max pooling to downsample the feature maps.
# 4. **Convolutional Layers**:
#    - 4.1. Third Conv2D Layer: Applies 128 filters with a 3x3 kernel size, ReLU activation function, and dilation rate of (2, 2).
#    - 4.2. GlobalAveragePooling2D Layer: Performs global average pooling to reduce spatial dimensions.
# 5. **Dense Layers**:
#    - 5.1. Dense Layer: Applies 128 neurons with ReLU activation function.
#    - 5.2. Dropout Layer: Applies dropout regularization with a dropout rate of 0.5.
#    - 5.3. Dense Layer: Outputs logits for each class, with the number of units equal to the number of labels.

# %% [markdown]
# ### Model Arch

# %%
model3 = models.Sequential([
    layers.Input(shape=input_shape),
    layers.Conv2D(32, 3, activation='relu', dilation_rate=(2, 2)),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, activation='relu', dilation_rate=(2, 2)),
    layers.MaxPooling2D(),
    layers.Conv2D(128, 3, activation='relu', dilation_rate=(2, 2)),
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(num_labels),
])

model3.summary()

# %% [markdown]
# ### Model compile

# %%
model3.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)

# %% [markdown]
# ### Train the model

# %%
EPOCHS = 10
history = model3.fit(
    train_spectrogram_ds,
    validation_data=val_spectrogram_ds,
    epochs=EPOCHS,
    callbacks=tf.keras.callbacks.EarlyStopping(verbose=1, patience=2),
)

# %% [markdown]
# ### Plot Loaa and accuracy

# %%
metrics = history.history
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
plt.plot(history.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.ylim([0, max(plt.ylim())])
plt.xlabel('Epoch')
plt.ylabel('Loss [CrossEntropy]')

plt.subplot(1,2,2)
plt.plot(history.epoch, 100*np.array(metrics['accuracy']), 100*np.array(metrics['val_accuracy']))
plt.legend(['accuracy', 'val_accuracy'])
plt.ylim([0, 100])
plt.xlabel('Epoch')
plt.ylabel('Accuracy [%]')

# %% [markdown]
# ### Evaluate the model

# %%
model3.evaluate(test_spectrogram_ds, return_dict=True)

# %% [markdown]
# ### Display a confusion matrix

# %%
y_pred = model3.predict(test_spectrogram_ds)
y_pred = tf.argmax(y_pred, axis=1)
y_true = tf.concat(list(test_spectrogram_ds.map(lambda s,lab: lab)), axis=0)

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_mtx,
            xticklabels=label_names,
            yticklabels=label_names,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %% [markdown]
# # Exporting a model

# %% [markdown]
# ## Export the model with preprocessing

# %%
class ExportModel(tf.Module):
  def __init__(self, model):
    self.model = model

    # Accept either a string-filename or a batch of waveforms.
    # YOu could add additional signatures for a single wave, or a ragged-batch.
    self.__call__.get_concrete_function(
        x=tf.TensorSpec(shape=(), dtype=tf.string))
    self.__call__.get_concrete_function(
       x=tf.TensorSpec(shape=[None, SAMPLE_RATE], dtype=tf.float32))


  @tf.function
  def __call__(self, x):
    # If they pass a string, load the file and decode it.
    if x.dtype == tf.string:
      x = tf.io.read_file(x)
      x, _ = tf.audio.decode_wav(x, desired_channels=1, desired_samples=SAMPLE_RATE,)
      x = tf.squeeze(x, axis=-1)
      x = x[tf.newaxis, :]

    x = get_spectrogram(x)
    result = self.model(x, training=False)

    class_ids = tf.argmax(result, axis=-1)
    class_names = tf.gather(label_names, class_ids)
    return {'predictions':result,
            'class_ids': class_ids,
            'class_names': class_names}

# %%
export = ExportModel(model)
export(tf.constant(str('own/ddyo/audio #2001.wav')))

# %% [markdown]
# Save and reload the model, the reloaded model gives identical output:

# %%
tf.saved_model.save(export, "saved")
imported = tf.saved_model.load("saved")
imported(waveform[tf.newaxis, :])

# %% [markdown]
# # Load packages and dependencies

# %% [markdown]
# # Load the raw data

# %%
DATASET_PATH = "dataset/"
JSON_PATH = "data.json"
SAMPLE_RATE = 16000
AUDIO_DURATION = 2  # measured in seconds
SAMPLES_PER_AUDIO = SAMPLE_RATE * AUDIO_DURATION

# %% [markdown]
# # Preprocess the data

# %%
def save_mfcc(dataset_path, json_path, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=5):

    # dictionary to store mapping, labels, and MFCCs
    data = {
        "mapping": [],
        "labels": [],
        "mfcc": []
    }

    samples_per_segment = int(SAMPLES_PER_AUDIO / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

    # loop through all sub-folders
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):

        # ensure we're processing the sub-folder level
        if dirpath is not dataset_path:

            # save genre label (i.e., sub-folder name) in the mapping
            semantic_label = dirpath.split("/")[-1]
            data["mapping"].append(semantic_label)
            print(f"\nProcessing: {semantic_label}")

            # process all audio files in genre sub-dir
            for f in filenames:

                # load audio file
                file_path = os.path.join(dirpath, f)
                signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)

                # process all segments of audio file
                for d in range(num_segments):

                    # calculate start and finish sample for the current segment
                    start = samples_per_segment * d
                    finish = start + samples_per_segment

                    # extract mfcc
                    mfcc = librosa.feature.mfcc(y=signal[start:finish],
                                                sr=sample_rate,
                                                n_mfcc=num_mfcc,
                                                n_fft=n_fft,
                                                hop_length=hop_length)

                    mfcc = mfcc.T

                    # store only mfcc feature with the expected number of vectors
                    if len(mfcc) == num_mfcc_vectors_per_segment:
                        data["mfcc"].append(mfcc.tolist())
                        data["labels"].append(i-1)
                        print(f"{file_path}, segment:{d+1}")

    # save MFCCs to json file
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)

    # return the data dictionary
    return data

# %% [markdown]
# ## Save the mfcc data

# %%
data = save_mfcc(DATASET_PATH, JSON_PATH, num_segments=6)
# Out:
# Processing: right
# dataset/right/01d22d03_nohash_1.wav, segment:1
# dataset/right/01d22d03_nohash_1.wav, segment:2
# dataset/right/01d22d03_nohash_1.wav, segment:3
# dataset/right/0ff728b5_nohash_1.wav, segment:1
# dataset/right/0ff728b5_nohash_1.wav, segment:2
# dataset/right/0ff728b5_nohash_1.wav, segment:3
# dataset/right/2fee065a_nohash_0.wav, segment:1
# dataset/right/2fee065a_nohash_0.wav, segment:2
# dataset/right/2fee065a_nohash_0.wav, segment:3
# /home/vx/Desktop/allenv/lib/python3.11/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1
#   warnings.warn(
# /home/vx/Desktop/allenv/lib/python3.11/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=0
#   warnings.warn
# dataset/stop/9c06a3f3_nohash_0.wav, segment:1
# dataset/stop/9c06a3f3_nohash_0.wav, segment:2
# dataset/stop/9c06a3f3_nohash_0.wav, segment:3
# dataset/stop/8fe67225_nohash_1.wav, segment:1
# dataset/stop/8fe67225_nohash_1.wav, segment:2
# dataset/stop/8fe67225_nohash_1.wav, segment:3
# dataset/stop/9b8a7439_nohash_0.wav, segment:1
# dataset/stop/9b8a7439_nohash_0.wav, segment:2
# dataset/stop/9b8a7439_nohash_0.wav, segment:3
# dataset/stop/6c429c7b_nohash_0.wav, segment:1
# dataset/stop/6c429c7b_nohash_0.wav, segment:2
# dataset/stop/6c429c7b_nohash_0.wav, segment:3
# dataset/stop/5f01c798_nohash_0.wav, segment:1
# dataset/stop/5f01c798_nohash_0.wav, segment:2
# dataset/stop/5f01c798_nohash_0.wav, segment:3
# dataset/stop/0fa1e7a9_nohash_2.wav, segment:1
# dataset/stop/0fa1e7a9_nohash_2.wav, segment:2
# dataset/stop/0fa1e7a9_nohash_2.wav, segment:3

# %% [markdown]
# ## Load json file

# %%
def load_data(data):

    # convert lists to numpy arrays
    X = np.array(data["mfcc"])
    y = np.array(data["labels"])

    print("Data successfully loaded!")

    return X, y

# %%
X, y = load_data(data)
# Out:
# Data successfully loaded!

# %% [markdown]
# # Split Data into Training and Testing Sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# # Build a Neural Network Model

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(X.shape[1], X.shape[2])),
    keras.layers.Dense(512, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(256, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(64, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(10, activation='softmax')
])

# %% [markdown]
# ## Compile the model

# %%
optimiser = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=optimiser,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])


model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 143)               0
#
#  dense (Dense)               (None, 512)               73728
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 64)                16448
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 222154 (867.79 KB)
# Trainable params: 222154 (867.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Train the Model

# %%
history = model.fit(X_train,
                    y_train,
                    validation_data=(X_test, y_test),
                    batch_size=32,
                    epochs=50)
# Out:
# Epoch 1/50
# 382/382 [==============================] - 6s 10ms/step - loss: 19.1576 - accuracy: 0.1503 - val_loss: 2.9265 - val_accuracy: 0.1749
# Epoch 2/50
# 382/382 [==============================] - 3s 8ms/step - loss: 3.8350 - accuracy: 0.1604 - val_loss: 2.8944 - val_accuracy: 0.1743
# Epoch 3/50
# 382/382 [==============================] - 3s 8ms/step - loss: 3.1530 - accuracy: 0.1627 - val_loss: 2.8649 - val_accuracy: 0.1745
# Epoch 4/50
# 382/382 [==============================] - 3s 9ms/step - loss: 2.9878 - accuracy: 0.1657 - val_loss: 2.8373 - val_accuracy: 0.1614
# Epoch 5/50
# 382/382 [==============================] - 3s 8ms/step - loss: 2.9112 - accuracy: 0.1706 - val_loss: 2.8104 - val_accuracy: 0.1614
# Epoch 6/50
# 382/382 [==============================] - 3s 8ms/step - loss: 2.8491 - accuracy: 0.1691 - val_loss: 2.7840 - val_accuracy: 0.1614
# Epoch 7/50
# 382/382 [==============================] - 3s 8ms/step - loss: 2.8065 - accuracy: 0.1684 - val_loss: 2.7578 - val_accuracy: 0.1614
# Epoch 8/50
# 382/382 [==============================] - 3s 8ms/step - loss: 2.7707 - accuracy: 0.1682 - val_loss: 2.7317 - val_accuracy: 0.1614
# Epoch 9/50
# 382/382 [==============================] - 3s 8ms/step - loss: 2.7372 - accuracy: 0.1684 - val_loss: 2.7057 - val_accuracy: 0.1615
# Epoch 10/50
50
# 382/382 [==============================] - 1s 4ms/step - loss: 2.0355 - accuracy: 0.1667 - val_loss: 2.0276 - val_accuracy: 0.1614
# Epoch 36/50
# 382/382 [==============================] - 1s 4ms/step - loss: 2.0224 - accuracy: 0.1681 - val_loss: 2.0125 - val_accuracy: 0.1614
# Epoch 37/50
# 382/382 [==============================] - 1s 3ms/step - loss: 2.0131 - accuracy: 0.1631 - val_loss: 1.9991 - val_accuracy: 0.1614
# Epoch 38/50
# 382/382 [==============================] - 1s 4ms/step - loss: 1.9954 - accuracy: 0.1674 - val_loss: 1.9871 - val_accuracy: 0.1614
# Epoch 39/50
# 382/382 [==============================] - 1s 3ms/step - loss: 1.9849 - accuracy: 0.1688 - val_loss: 1.9762 - val_accuracy: 0.1614
# Epoch 40/50
# 382/382 [==============================] - 1s 4ms/step - loss: 1.9716 - accuracy: 0.1661 - val_loss: 1.9663 - val_accuracy: 0.1614
# Epoch 41/50
# 382/382 [==============================] - 1s 4ms/step - loss: 1.9659 - accuracy: 0.1658 - val_loss: 1.9572 - val_accuracy: 0.1614
# Epoch 42/50
# 382/382 [==============================] - 1s 3ms/step - loss: 1.9544 - accuracy: 0.1660 - val_loss: 1.9490 - val_accuracy: 0.1614
# Epoch 43/50
# 382/382 [==============================] - 1s 4ms/step - loss: 1.9518 - accuracy: 0.1675 - val_loss: 1.9414 - val_accuracy: 0.1614
# Epoch 44/50
# 382/382 [==============================] - 2s 6ms/step - loss: 1.9412 - accuracy: 0.1688 - val_loss: 1.9347 - val_accuracy: 0.1606
# Epoch 45/50
# 382/382 [==============================] - 3s 8ms/step - loss: 1.9350 - accuracy: 0.1663 - val_loss: 1.9286 - val_accuracy: 0.1606
# Epoch 46/50
# 382/382 [==============================] - 3s 8ms/step - loss: 1.9277 - accuracy: 0.1665 - val_loss: 1.9229 - val_accuracy: 0.1606
# Epoch 47/50
# 382/382 [==============================] - 3s 9ms/step - loss: 1.9231 - accuracy: 0.1643 - val_loss: 1.9173 - val_accuracy: 0.1606
# Epoch 48/50
# 382/382 [==============================] - 3s 9ms/step - loss: 1.9187 - accuracy: 0.1677 - val_loss: 1.9121 - val_accuracy: 0.1606
# Epoch 49/50
# 382/382 [==============================] - 3s 9ms/step - loss: 1.9104 - accuracy: 0.1681 - val_loss: 1.9072 - val_accuracy: 0.1606
# Epoch 50/50
# 382/382 [==============================] - 3s 8ms/step - loss: 1.9054 - accuracy: 0.1692 - val_loss: 1.9025 - val_accuracy: 0.1606

# %% [markdown]
# ## History

# %%
def plot_history(history):

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()

# %% [markdown]
# ## Plot history

# %%
plot_history(history)

# %% [markdown]
# # Evaluate the Model

# %%
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
print(f'\nTest accuracy: {test_acc}')
print(f'\nTest loss: {test_loss}')
# Out:
# 164/164 - 1s - loss: 1.9025 - accuracy: 0.1606 - 643ms/epoch - 4ms/step
#
# Test accuracy: 0.1605881303548813
#
# Test loss: 1.902482509613037

# %% [markdown]
# # Make Predictions

# %%
predictions = model.predict(X_test)
# Out:
# 164/164 [==============================] - 1s 4ms/step

# %% [markdown]
# # Post-Processing and Analysis

# %% [markdown]
# # Save and Export Model

# %%
model.save('audio_model.h5')
# Out:
# /home/vx/Desktop/allenv/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # confusion matrix

# %%
y_pred = tf.argmax(y_pred, axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 y_pred = tf.argmax(y_pred, axis=1)
#
# NameError: name 'y_pred' is not defined

# %%
y_true = tf.concat(list(test_spectrogram_ds.map(lambda s,lab: lab)), axis=0)

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_mtx,
            xticklabels=label_names,
            yticklabels=label_names,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %% [markdown]
# # Packages and Libraries

# %%
import os
import json
import math
# from google.colab import drive
import wave
import pathlib

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


import tensorflow as tf 
from tensorflow.keras import layers, models
import tensorflow.keras as keras

import librosa
import IPython.display as display
import soundfile as sf

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Commands in the dataset
# The dataset's audio clips are of 5 classes and a wakeword stored in six folders corresponding to each speech command:
# - `gaali` (Wakeword)
# - `ddyo`
# - `kkono`
# - `mu maaso`
# - `emabega`
# - `yimirira`

# %%
commands = np.array(tf.io.gfile.listdir(str(data_dir)))
print('Commands:', commands)
# Out:
# Commands: ['emabega' 'ddyo' 'gaali' 'kkono' 'mu masso' 'yimirira']

# %% [markdown]
# ## Number of audio files per command

# %%
def count_audio_files_in_subfolders(data_dir):
    counts = {}

    # Iterate through subfolders
    for subfolder in os.listdir(data_dir):
        subfolder_path = os.path.join(data_dir, subfolder)

        # Check if it's a directory
        if os.path.isdir(subfolder_path):
            # Count the number of audio files in the subfolder
            audio_files_count = len([f for f in os.listdir(subfolder_path) if f.endswith('.wav')])
            counts[subfolder] = audio_files_count

    return counts

# Get the counts
counts = count_audio_files_in_subfolders(data_dir)

# %%
plt.figure(figsize=(8, 4))
plt.bar(list(counts.keys()), list(counts.values()), color='blue')
plt.xlabel('Number of Audio Files')
plt.ylabel('Subfolders')
plt.title('Number of Audio Files in Each Subfolder')
plt.show()

# %% [markdown]
# # Inspect the audio data

# %% [markdown]
# ## Insect one audio file

# %%
example_audio_path = 'own/ddyo/audio #2001.wav'
audio_signal, sample_rate = librosa.load(example_audio_path)
audio = wave.open(example_audio_path, 'rb')

# %% [markdown]
# ### Audio Parameters

# %%
number_of_channel = audio.getnchannels()
sample_width = audio.getsampwidth()
frame_rate = audio.getframerate()
number_of_frames = audio.getnframes()

# %%
print('Number of channels:', number_of_channel)
print('Sample width:',       sample_width)
print('frame rate:',         frame_rate)
print('Number of frames:',   number_of_frames)
print('Parameters:',         audio.getparams())
# Out:
# Number of channels: 1
# Sample width: 2
# frame rate: 16000
# Number of frames: 15360
# Parameters: _wave_params(nchannels=1, sampwidth=2, framerate=16000, nframes=15360, comptype='NONE', compname='not compressed')

# %%
duration = librosa.get_duration(y=audio_signal, sr=sample_rate)
print(f"Duration: {duration} seconds")
print(f"Sample Rate: {sample_rate} Hz")
# Out:
# Duration: 0.96 seconds
# Sample Rate: 22050 Hz

# %% [markdown]
# ### Visualize the audio waveform

# %%
plt.figure(figsize=(8, 4))
plt.plot(audio_signal, color='green')
plt.title('Audio Waveform')
plt.xlabel('ddyo')
plt.ylabel('Amplitude')
plt.show()

# %% [markdown]
# ### Amplitude Distribution

# %%
plt.figure(figsize=(8, 4))
sns.histplot(audio_signal, bins=50, kde=True)
plt.title('Amplitude Distribution')
plt.xlabel('Amplitude')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Preprocess the audio data

# %%
def process_audio(audio_path, desired_duration=2, noise_level=0.002):
    # Load audio file
    audio_signal, sample_rate = librosa.load(audio_path, sr=None, mono=True)

    # Trim audio to desired duration if needed
    desired_samples = int(desired_duration * sample_rate)
    if len(audio_signal) > desired_samples:
        trimmed_signal, _ = librosa.effects.trim(audio_signal, frame_length=2048)

        # Fix length of the trimmed signal
        if len(trimmed_signal) < desired_samples:
            pad_amount = desired_samples - len(trimmed_signal)
            trimmed_signal = np.pad(trimmed_signal, (0, pad_amount))
        else:
            trimmed_signal = trimmed_signal[:desired_samples]
    else:
        trimmed_signal = audio_signal

    return trimmed_signal, sample_rate

# %%
def preprocess_audio_in_subfolders(root_folder, output_folder, desired_duration=2):
    # Iterate through subfolders
    for subfolder in os.listdir(root_folder):
        subfolder_path = os.path.join(root_folder, subfolder)

        # Check if it's a directory
        if os.path.isdir(subfolder_path):
            # Create output subfolder if it doesn't exist
            output_subfolder = os.path.join(output_folder, subfolder)
            os.makedirs(output_subfolder, exist_ok=True)

            # Iterate through audio files in the subfolder
            for audio_file in os.listdir(subfolder_path):
                audio_path = os.path.join(subfolder_path, audio_file)

                # Process each audio file (trim only)
                trimmed_audio, sample_rate = process_audio(audio_path, desired_duration)

                # Save the preprocessed audio file in the output subfolder using soundfile
                output_audio_path = os.path.join(output_subfolder, audio_file)
                sf.write(output_audio_path, trimmed_audio, sample_rate)

# %%
root_folder = DATASET_PATH
output_folder = PROCESSED_DATA_PATH
preprocess_audio_in_subfolders(root_folder, output_folder)

# %% [markdown]
# ## Set new paths for the processed data

# %%
DATASET_PATH = 'processedData/'
data_dir = pathlib.Path(DATASET_PATH)
JSON_PATH = "data.json"

# %% [markdown]
# # Feature extraction

# %%
def extract_features(root_folder, desired_duration=2, n_mfcc=13, hop_length=512, n_fft=2048):
    features = []
    labels = []

    for foldername in os.listdir(root_folder):
        folder_path = os.path.join(root_folder, foldername)

        if os.path.isdir(folder_path):
            for audio_filename in os.listdir(folder_path):
                audio_path = os.path.join(folder_path, audio_filename)

                # Load audio file and extract features
                try:
                    audio_signal, sample_rate = librosa.load(audio_path, duration=desired_duration)
                    mfccs = librosa.feature.mfcc(y=audio_signal, sr=sample_rate, n_mfcc=n_mfcc, hop_length=hop_length, n_fft=n_fft)
                    mfccs_mean = np.mean(mfccs, axis=1)  # Take the mean of MFCCs over time
                    features.append(mfccs_mean)
                    labels.append(foldername)  # Assuming folder names are the labels/categories
                except Exception as e:
                    print(f"Error encountered while processing {audio_path}: {e}")

    return np.array(features), np.array(labels)

# %%
root_folder = DATASET_PATH
features, labels = extract_features(root_folder)
print("Features shape:", features.shape)
print("Labels:", labels)
# Out:
# Features shape: (3600, 13)
# Labels: ['emabega' 'emabega' 'emabega' ... 'yimirira' 'yimirira' 'yimirira']

# %% [markdown]
# ## Data augmentation

# %%
# Define data augmentation function
def apply_augmentation(audio_signal, sample_rate, desired_duration=2, pitch_shift_range=2, time_stretch_range=0.2, noise_level=0.002):
    # Random pitch shifting
    pitch_shift_steps = np.random.uniform(-pitch_shift_range, pitch_shift_range)
    augmented_audio = librosa.effects.pitch_shift(audio_signal, sr=sample_rate, n_steps=pitch_shift_steps)

    # Random time stretching
    time_stretch_factor = np.random.uniform(1 - time_stretch_range, 1 + time_stretch_range)
    augmented_audio = librosa.effects.time_stretch(augmented_audio, rate=time_stretch_factor)

    # Add random noise
    noise = np.random.normal(scale=noise_level, size=len(augmented_audio))
    augmented_audio += noise

    # Trim audio to desired duration if needed
    desired_samples = int(desired_duration * sample_rate)
    if len(augmented_audio) > desired_samples:
        augmented_audio = augmented_audio[:desired_samples]
    else:
        pad_amount = desired_samples - len(augmented_audio)
        augmented_audio = np.pad(augmented_audio, (0, pad_amount))

    return augmented_audio

def augment_data(audio_signal, sample_rate, label, desired_duration=2, pitch_shift_range=2, time_stretch_range=0.2, noise_level=0.002, n_mfcc=13, hop_length=512, n_fft=2048):
    augmented_features = []
    augmented_labels = []

    # Apply data augmentation to the audio signal
    augmented_audio = apply_augmentation(audio_signal, sample_rate, desired_duration, pitch_shift_range, time_stretch_range, noise_level)
    
    # Extract features from the augmented audio signal
    try:
        mfccs = librosa.feature.mfcc(y=augmented_audio, sr=sample_rate, n_mfcc=n_mfcc, hop_length=hop_length, n_fft=n_fft)
        mfccs_mean = np.mean(mfccs, axis=1)  # Take the mean of MFCCs over time
        augmented_features.append(mfccs_mean)
        augmented_labels.append(label)
    except Exception as e:
        print(f"Error encountered while processing augmented audio: {e}")

    return np.array(augmented_features), np.array(augmented_labels)

# %% [markdown]
# ## Labelling

# %%
def label_audio_files(root_folder):
    labels = []
    file_paths = []

    for foldername in os.listdir(root_folder):
        folder_path = os.path.join(root_folder, foldername)

        if os.path.isdir(folder_path):
            for audio_filename in os.listdir(folder_path):
                audio_path = os.path.join(folder_path, audio_filename)

                # Add label and file path to lists
                labels.append(foldername)
                file_paths.append(audio_path)

    return labels, file_paths

# %%
labels, file_paths = label_audio_files(DATASET_PATH)

# %%
# Instantiate LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform labels
encoded_labels = label_encoder.fit_transform(labels)

# Define the number of classes
num_classes = len(label_encoder.classes_)

# %% [markdown]
# ## Spilt the data

# %%
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (2880, 13)
# (720, 13)

# %% [markdown]
# ## Convert to tf

# %%
def create_dataset(features, labels, batch_size=32, shuffle_buffer_size=1000):
    # Convert features and labels to TensorFlow tensors
    features = tf.constant(features)
    labels = tf.constant(labels)
    
    # Create dataset from tensors
    dataset = tf.data.Dataset.from_tensor_slices((features, labels))
    
    # Shuffle and batch the dataset
    dataset = dataset.shuffle(buffer_size=shuffle_buffer_size).batch(batch_size)
    
    return dataset

train_dataset = create_dataset(X_train, y_train)
test_dataset = create_dataset(X_test, y_test)

# %% [markdown]
# ## Model 1

# %%
num_epochs = 10  # Adjust as needed

# Define the number of features and classes
num_features = features.shape[1]  # Assuming features.shape[1] gives the number of features
num_classes = len(np.unique(labels))

# Define input shape based on your data
input_shape = (num_features,)

# Define model architecture
model = tf.keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=input_shape),
    layers.Dense(32, activation='relu'),
    layers.Dense(num_classes, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['Accuracy'])

# %%
# Train the model
history = model.fit(train_dataset, epochs=num_epochs, validation_data=test_dataset)

# Evaluate the model
loss, accuracy = model.evaluate(test_dataset)

print(f'Test Loss: {loss}')
print(f'Test Accuracy: {accuracy}')
# Out:
# Epoch 1/10
# 2024-02-08 14:11:33.216952: W tensorflow/core/framework/op_kernel.cc:1816] OP_REQUIRES failed at cast_op.cc:122 : UNIMPLEMENTED: Cast string to float is not supported
# ---------------------------------------------------------------------------
# UnimplementedError                        Traceback (most recent call last)
# Cell In[100], line 2
#       1 # Train the model
# ----> 2 history = model.fit(train_dataset, epochs=num_epochs, validation_data=test_dataset)
#       4 # Evaluate the model
#       5 loss, accuracy = model.evaluate(test_dataset)
#
# File ~/Desktop/allenv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/Desktop/allenv/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# UnimplementedError: Graph execution error:
#
# Detected at node Cast_1 defined at (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#
#   File "<frozen runpy>", line 88, in _run_code
#
#   File "/home/vx/Desktop/allenv/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#
#   File "/home/vx/Desktop/allenv/lib/python3.11/site-packages/traitlets/config/application.py", line 1077, in launch_instance
#
#   File "/home/vx/Desktop/allenv/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 739, in start
#
#   File "/home/vx/Desktop/allenv/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 205, in start
#
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#
#   File "/usr/lib/python3.11/asyncio/events.py", line 80, in _run
#
#   File "/home/vx/Desktop/allenv/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 529, in dispatch_queue
#
#   File "/home/vx/Desktop/allenv/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 518, in process_one
#
#   File "/home/vx/Desktop/allenv/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 424, in dispatch_shell
#
#   File "/home/vx/Desktop/allenv/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 766, in execute_request
#
#   File "/home/vx/Desktop/allenv/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 429, in do_execute
#
#   File "/home/vx/Desktop/allenv/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#
#   File "/home/vx/Desktop/allenv/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#
#   File "/home/vx/Desktop/allenv/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#
#   File "/home/vx/Desktop/allenv/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#
#   File "/home/vx/Desktop/allenv/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#
#   File "/home/vx/Desktop/allenv/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#
#   File "/home/vx/Desktop/allenv/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#
#   File "/tmp/ipykernel_13329/3476920975.py", line 2, in <module>
#
#   File "/home/vx/Desktop/allenv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/vx/Desktop/allenv/lib/python3.11/site-packages/keras/src/engine/training.py", line 1807, in fit
#
#   File "/home/vx/Desktop/allenv/lib/python3.11/site-packages/keras/src/engine/training.py", line 1401, in train_function
#
#   File "/home/vx/Desktop/allenv/lib/python3.11/site-packages/keras/src/engine/training.py", line 1384, in step_function
#
#   File "/home/vx/Desktop/allenv/lib/python3.11/site-packages/keras/src/engine/training.py", line 1373, in run_step
#
#   File "/home/vx/Desktop/allenv/lib/python3.11/site-packages/keras/src/engine/training.py", line 1155, in train_step
#
#   File "/home/vx/Desktop/allenv/lib/python3.11/site-packages/keras/src/engine/training.py", line 1249, in compute_metrics
#
#   File "/home/vx/Desktop/allenv/lib/python3.11/site-packages/keras/src/engine/compile_utils.py", line 620, in update_state
#
#   File "/home/vx/Desktop/allenv/lib/python3.11/site-packages/keras/src/utils/metrics_utils.py", line 77, in decorated
#
#   File "/home/vx/Desktop/allenv/lib/python3.11/site-packages/keras/src/metrics/base_metric.py", line 140, in update_state_fn
#
#   File "/home/vx/Desktop/allenv/lib/python3.11/site-packages/keras/src/metrics/base_metric.py", line 708, in update_state
#
# Cast string to float is not supported
# 	 [[{{node Cast_1}}]] [Op:__inference_train_function_4864]

# %% [markdown]
# # Split into Train and validation

# %%
def create_tf_dataset(root_folder, batch_size=64, validation_split=0.2):
    processed_audios = []

    # Iterate through subfolders
    for subfolder in os.listdir(root_folder):
        subfolder_path = os.path.join(root_folder, subfolder)

        # Check if it's a directory
        if os.path.isdir(subfolder_path):
            # Iterate through audio files in the subfolder
            for audio_file in os.listdir(subfolder_path):
                audio_path = os.path.join(subfolder_path, audio_file)

                # Process each audio file
                processed_audio, label = process_audio(audio_path)
                processed_audios.append((processed_audio, label))

    # Shuffle the data
    np.random.shuffle(processed_audios)

    # Split into training and validation sets
    split_index = int(len(processed_audios) * (1 - validation_split))
    train_data = processed_audios[:split_index]
    val_data = processed_audios[split_index:]

    # Create TensorFlow datasets
    train_ds = tf.data.Dataset.from_generator(lambda: train_data, output_signature=(
        tf.TensorSpec(shape=(None,), dtype=tf.float32),
        tf.TensorSpec(shape=(), dtype=tf.int32)
    ))
    val_ds = tf.data.Dataset.from_generator(lambda: val_data, output_signature=(
        tf.TensorSpec(shape=(None,), dtype=tf.float32),
        tf.TensorSpec(shape=(), dtype=tf.int32)
    ))

    # Batch the datasets
    train_ds = train_ds.batch(batch_size)
    val_ds = val_ds.batch(batch_size)

    return train_ds, val_ds

# %%
root_folder = PROCESSED_DATA_PATH
train_ds, val_ds = create_tf_dataset(root_folder, batch_size=64, validation_split=0.2)

# %% [markdown]
# ## spectrograms

# %%
def extract_spectrograms(root_folder, desired_duration=2, noise_level=0.002):
    spectrograms = []
    sample_rates = []

    for foldername in os.listdir(root_folder):
        folder_path = os.path.join(root_folder, foldername)

        if os.path.isdir(folder_path):
            for audio_filename in os.listdir(folder_path):
                audio_path = os.path.join(folder_path, audio_filename)

                # Process audio (trimming and noise removal)
                processed_audio, sample_rate = process_audio(audio_path, desired_duration, noise_level)

                # Extract Mel spectrogram features
                mel_spectrogram = librosa.feature.melspectrogram(y=processed_audio, sr=sample_rate)
                log_mel_spectrogram = librosa.power_to_db(mel_spectrogram, ref=np.max)

                spectrograms.append(log_mel_spectrogram)
                sample_rates.append(sample_rate)

    return spectrograms, sample_rates

# %%
spectrograms, sample_rates = extract_spectrograms(PROCESSED_DATA_PATH)

# %% [markdown]
# ## Augementation

# %%
import numpy as np

def apply_augmentation(spectrograms, sample_rates, pitch_shift_range=2, time_stretch_range=0.2, noise_level=0.002):
    augmented_spectrograms = []
    for spectrogram, sample_rate in zip(spectrograms, sample_rates):
        # Convert spectrogram back to audio signal
        y = librosa.feature.inverse.mel_to_audio(np.asarray(spectrogram), sr=sample_rate)

        # Random pitch shifting
        pitch_shift_steps = np.random.uniform(-pitch_shift_range, pitch_shift_range)
        spectrogram_shifted = librosa.effects.pitch_shift(y, sr=sample_rate, n_steps=pitch_shift_steps)

        # Random time stretching
        time_stretch_factor = np.random.uniform(1 - time_stretch_range, 1 + time_stretch_range)
        spectrogram_stretched = librosa.effects.time_stretch(spectrogram_shifted, rate=time_stretch_factor)

        # Add random noise
        noise = np.random.normal(scale=noise_level, size=len(spectrogram_stretched))
        spectrogram_noisy = spectrogram_stretched + noise

        augmented_spectrograms.append(spectrogram_noisy)

    return augmented_spectrograms

# %% [markdown]
# ## Feature scaling

# %%
# # After extracting spectrograms and applying data augmentation
# augmented_spectrograms = apply_augmentation(spectrograms, sample_rate)

# # After applying data augmentation, scale the features
# scaled_spectrograms, scaler = scale_features(augmented_spectrograms)

# Save the scaler object for later use
# # You can use joblib to save and load the scaler
# from joblib import dump
# dump(scaler, 'scaler.joblib')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 2
#       1 # After extracting spectrograms and applying data augmentation
# ----> 2 augmented_spectrograms = apply_augmentation(spectrograms, sample_rate)
#       4 # After applying data augmentation, scale the features
#       5 scaled_spectrograms, scaler = scale_features(augmented_spectrograms)
#
# Cell In[57], line 5, in apply_augmentation(spectrograms, sample_rates, pitch_shift_range, time_stretch_range, noise_level)
#       3 def apply_augmentation(spectrograms, sample_rates, pitch_shift_range=2, time_stretch_range=0.2, noise_level=0.002):
#       4     augmented_spectrograms = []
# ----> 5     for spectrogram, sample_rate in zip(spectrograms, sample_rates):
#       6         # Convert spectrogram back to audio signal
#       7         y = librosa.feature.inverse.mel_to_audio(np.asarray(spectrogram), sr=sample_rate)
#       9         # Random pitch shifting
#
# TypeError: 'int' object is not iterable

# %%
train_ds, val_ds = tf.keras.utils.audio_dataset_from_directory(
    directory=data_dir,
    batch_size=64,
    validation_split=0.3,
    seed=0,
    output_sequence_length=16000,
    subset='both')

label_names = np.array(train_ds.class_names)
print()
print("label names:", label_names)
# Out:
# Found 3600 files belonging to 6 classes.
# Using 2520 files for training.
# Using 1080 files for validation.
#
# label names: ['ddyo' 'emabega' 'gaali' 'kkono' 'mu masso' 'yimirira']

# %% [markdown]
# ### The audio clips have a shape of `(batch, samples, channels)`.

# %%
train_ds.element_spec
# Out:
# (TensorSpec(shape=(None, 16000, None), dtype=tf.float32, name=None),
#  TensorSpec(shape=(None,), dtype=tf.int32, name=None))

# %%
def squeeze(audio, labels):
  audio = tf.squeeze(audio, axis=-1)
  return audio, labels

train_ds = train_ds.map(squeeze, tf.data.AUTOTUNE)
val_ds = val_ds.map(squeeze, tf.data.AUTOTUNE)

# %%
test_ds = val_ds.shard(num_shards=2, index=0)
val_ds = val_ds.shard(num_shards=2, index=1)

# %%
for example_audio, example_labels in train_ds.take(1):
  print(example_audio.shape)
  print(example_labels.shape)
# Out:
# (64, 16000)
# (64,)

# %% [markdown]
# ### Plot a few audio waveforms:

# %%
label_names[[1,2,3,0,4,5]]
# Out:
# array(['emabega', 'gaali', 'kkono', 'ddyo', 'mu masso', 'yimirira'],
#       dtype='<U8')

# %%
plt.figure(figsize=(16, 10))
rows = 2
cols = 3
n = rows * cols
for i in range(n):
  plt.subplot(rows, cols, i+1)
  audio_signal = example_audio[i]
  plt.plot(audio_signal)
  plt.title(label_names[example_labels[i]])
  plt.yticks(np.arange(-1.2, 1.2, 0.2))
  plt.ylim([-1.1, 1.1])

# %%
def get_spectrogram(waveform):
  # Convert the waveform to a spectrogram via a STFT.
  spectrogram = tf.signal.stft(
      waveform, frame_length=255, frame_step=128)
  # Obtain the magnitude of the STFT.
  spectrogram = tf.abs(spectrogram)
  # Add a `channels` dimension, so that the spectrogram can be used
  # as image-like input data with convolution layers (which expect
  # shape (`batch_size`, `height`, `width`, `channels`).
  spectrogram = spectrogram[..., tf.newaxis]
  return spectrogram

# %% [markdown]
# ### The shapes of a tensorized waveform and the corresponding spectrogram, and play the original audio:

# %%
for i in range(3):
  label = label_names[example_labels[i]]
  waveform = example_audio[i]
  spectrogram = get_spectrogram(waveform)

  print('Label:', label)
  print('Waveform shape:', waveform.shape)
  print('Spectrogram shape:', spectrogram.shape)
  print('Audio playback')
  display.display(display.Audio(waveform, rate=16000))
# Out:
# Label: ddyo
# Waveform shape: (16000,)
# Spectrogram shape: (124, 129, 1)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Label: yimirira
# Waveform shape: (16000,)
# Spectrogram shape: (124, 129, 1)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Label: kkono
# Waveform shape: (16000,)
# Spectrogram shape: (124, 129, 1)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Displaying a spectrogram:

# %%
# Convert the frequencies to log scale and transpose, so that the time is
# represented on the x-axis (columns).
# Add an epsilon to avoid taking a log of zero.

def plot_spectrogram(spectrogram, ax):
  if len(spectrogram.shape) > 2:
    assert len(spectrogram.shape) == 3
    spectrogram = np.squeeze(spectrogram, axis=-1)
      
  log_spec = np.log(spectrogram.T + np.finfo(float).eps)
  height = log_spec.shape[0]
  width = log_spec.shape[1]
  X = np.linspace(0, np.size(spectrogram), num=width, dtype=int)
  Y = range(height)
  ax.pcolormesh(X, Y, log_spec)

# %% [markdown]
# ### Plot of waveform over time and the corresponding spectrogram.

# %%
fig, axes = plt.subplots(2, figsize=(12, 8))
timescale = np.arange(waveform.shape[0])
axes[0].plot(timescale, waveform.numpy())
axes[0].set_title('Waveform')
axes[0].set_xlim([0, 16000])

plot_spectrogram(spectrogram.numpy(), axes[1])
axes[1].set_title('Spectrogram')
plt.suptitle(label.title())
plt.show()

# %% [markdown]
# ## Create spectrogram datasets from the audio datasets:

# %%
def make_spec_ds(ds):
  return ds.map(
      map_func=lambda audio,label: (get_spectrogram(audio), label),
      num_parallel_calls=tf.data.AUTOTUNE)

# %%
train_spectrogram_ds = make_spec_ds(train_ds)
val_spectrogram_ds = make_spec_ds(val_ds)
test_spectrogram_ds = make_spec_ds(test_ds)

# %% [markdown]
# Examine the spectrograms for different examples of the dataset:

# %%
for example_spectrograms, example_spect_labels in train_spectrogram_ds.take(1):
  break

# %%
rows = 2
cols = 3
n = rows*cols
fig, axes = plt.subplots(rows, cols, figsize=(16, 9))

for i in range(n):
    r = i // cols
    c = i % cols
    ax = axes[r][c]
    plot_spectrogram(example_spectrograms[i].numpy(), ax)
    ax.set_title(label_names[example_spect_labels[i].numpy()])

plt.show()

# %% [markdown]
# ### `Dataset.cache` and `Dataset.prefetch` operations to reduce read latency while training the model:

# %%
train_spectrogram_ds = train_spectrogram_ds.cache().shuffle(10000).prefetch(tf.data.AUTOTUNE)
val_spectrogram_ds = val_spectrogram_ds.cache().prefetch(tf.data.AUTOTUNE)
test_spectrogram_ds = test_spectrogram_ds.cache().prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# ## Model 1

# %%
input_shape = example_spectrograms.shape[1:]
print('Input shape:', input_shape)
num_labels = len(label_names)
norm_layer = layers.Normalization()
norm_layer.adapt(data=train_spectrogram_ds.map(map_func=lambda spec, label: spec))

model = models.Sequential([
    layers.Input(shape=input_shape),
    # Downsample the input.
    layers.Resizing(32, 32),
    # Normalize.
    norm_layer,
    layers.Conv2D(32, 3, activation='relu'),
    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Dropout(0.25),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(num_labels),
])

model.summary()
# Out:
# Input shape: (124, 129, 1)
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resizing_2 (Resizing)       (None, 32, 32, 1)         0
#
#  normalization_1 (Normaliza  (None, 32, 32, 1)         3
#  tion)
#
#  conv2d_7 (Conv2D)           (None, 30, 30, 32)        320
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 64)        18496
#
#  max_pooling2d_5 (MaxPoolin  (None, 14, 14, 64)        0
#  g2D)
#
#  dropout_6 (Dropout)         (None, 14, 14, 64)        0
#
#  flatten_2 (Flatten)         (None, 12544)             0
#
#  dense_8 (Dense)             (None, 128)               1605760
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_9 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 1625353 (6.20 MB)
# Trainable params: 1625350 (6.20 MB)
# Non-trainable params: 3 (16.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Keras model with the Adam optimizer and the cross-entropy loss:

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)

# %% [markdown]
# ### Train the model

# %%
EPOCHS = 10
history = model.fit(
    train_spectrogram_ds,
    validation_data=val_spectrogram_ds,
    epochs=EPOCHS,
    callbacks=tf.keras.callbacks.EarlyStopping(verbose=1, patience=2),
)
# Out:
# Epoch 1/10
# 40/40 [==============================] - 4s 92ms/step - loss: 0.1926 - accuracy: 0.9409 - val_loss: 0.2611 - val_accuracy: 0.9160
# Epoch 2/10
# 40/40 [==============================] - 4s 97ms/step - loss: 0.1846 - accuracy: 0.9361 - val_loss: 0.2614 - val_accuracy: 0.9258
# Epoch 3/10
# 40/40 [==============================] - 4s 102ms/step - loss: 0.1793 - accuracy: 0.9385 - val_loss: 0.2590 - val_accuracy: 0.9258
# Epoch 4/10
# 40/40 [==============================] - 4s 98ms/step - loss: 0.1598 - accuracy: 0.9484 - val_loss: 0.2521 - val_accuracy: 0.9336
# Epoch 5/10
# 40/40 [==============================] - 4s 97ms/step - loss: 0.1659 - accuracy: 0.9464 - val_loss: 0.2676 - val_accuracy: 0.9258
# Epoch 6/10
# 40/40 [==============================] - 4s 101ms/step - loss: 0.1315 - accuracy: 0.9552 - val_loss: 0.2688 - val_accuracy: 0.9336
# Epoch 6: early stopping

# %% [markdown]
# ### Plot the training and validation loss curves to check how your model has improved during training:

# %%
metrics = history.history
plt.figure(figsize=(14,5))
plt.subplot(1,2,1)
plt.plot(history.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.ylim([0, max(plt.ylim())])
plt.xlabel('Epoch')
plt.ylabel('Loss [CrossEntropy]')

plt.subplot(1,2,2)
plt.plot(history.epoch, 100*np.array(metrics['accuracy']), 100*np.array(metrics['val_accuracy']))
plt.legend(['accuracy', 'val_accuracy'])
plt.ylim([0, 100])
plt.xlabel('Epoch')
plt.ylabel('Accuracy [%]')
# Out:
# Text(0, 0.5, 'Accuracy [%]')

# %% [markdown]
# ### Evaluate the model performance
#
# Run the model on the test set and check the model's performance:

# %%
model.evaluate(test_spectrogram_ds, return_dict=True)
# Out:
# 9/9 [==============================] - 1s 40ms/step - loss: 0.3087 - accuracy: 0.9049
# {'loss': 0.3086625337600708, 'accuracy': 0.9049295783042908}

# %% [markdown]
# ### Display a confusion matrix

# %%
y_pred = model.predict(test_spectrogram_ds)
# Out:
# 9/9 [==============================] - 0s 22ms/step

# %%
y_pred = tf.argmax(y_pred, axis=1)

# %%
y_true = tf.concat(list(test_spectrogram_ds.map(lambda s,lab: lab)), axis=0)

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_mtx,
            xticklabels=label_names,
            yticklabels=label_names,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %% [markdown]
# ### Export the model with preprocessing

# %%
class ExportModel(tf.Module):
  def __init__(self, model):
    self.model = model

    # Accept either a string-filename or a batch of waveforms.
    # YOu could add additional signatures for a single wave, or a ragged-batch.
    self.__call__.get_concrete_function(
        x=tf.TensorSpec(shape=(), dtype=tf.string))
    self.__call__.get_concrete_function(
       x=tf.TensorSpec(shape=[None, 16000], dtype=tf.float32))


  @tf.function
  def __call__(self, x):
    # If they pass a string, load the file and decode it.
    if x.dtype == tf.string:
      x = tf.io.read_file(x)
      x, _ = tf.audio.decode_wav(x, desired_channels=1, desired_samples=16000,)
      x = tf.squeeze(x, axis=-1)
      x = x[tf.newaxis, :]

    x = get_spectrogram(x)
    result = self.model(x, training=False)

    class_ids = tf.argmax(result, axis=-1)
    class_names = tf.gather(label_names, class_ids)
    return {'predictions':result,
            'class_ids': class_ids,
            'class_names': class_names}

# %% [markdown]
# ## Model 2

# %%
model2 = models.Sequential([
    layers.Input(shape=input_shape),
    layers.Resizing(32, 32),
    norm_layer,
    layers.Conv2D(32, 3, activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),
    layers.Dropout(0.25),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(num_labels),
])

# %%
model2.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resizing_3 (Resizing)       (None, 32, 32, 1)         0
#
#  normalization_1 (Normaliza  (None, 32, 32, 1)         3
#  tion)
#
#  conv2d_9 (Conv2D)           (None, 30, 30, 32)        320
#
#  batch_normalization_2 (Bat  (None, 30, 30, 32)        128
#  chNormalization)
#
#  max_pooling2d_6 (MaxPoolin  (None, 15, 15, 32)        0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 13, 13, 64)        18496
#
#  batch_normalization_3 (Bat  (None, 13, 13, 64)        256
#  chNormalization)
#
#  max_pooling2d_7 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  dropout_8 (Dropout)         (None, 6, 6, 64)          0
#
#  flatten_3 (Flatten)         (None, 2304)              0
#
#  dense_10 (Dense)            (None, 128)               295040
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_11 (Dense)            (None, 6)                 774
#
# =================================================================
# Total params: 315017 (1.20 MB)
# Trainable params: 314822 (1.20 MB)
# Non-trainable params: 195 (784.00 Byte)
# _________________________________________________________________

# %%
model2.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)

timizer=tf.keras.optimizers.Adam(),
loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),

# %%
EPOCHS = 10
history = model2.fit(
    train_spectrogram_ds,
    validation_data=val_spectrogram_ds,
    epochs=EPOCHS,
    callbacks=tf.keras.callbacks.EarlyStopping(verbose=1, patience=2),
)
# Out:
# Epoch 1/10
# 40/40 [==============================] - 3s 44ms/step - loss: 1.3914 - accuracy: 0.5813 - val_loss: 1.6626 - val_accuracy: 0.3496
# Epoch 2/10
# 40/40 [==============================] - 2s 38ms/step - loss: 0.6188 - accuracy: 0.7881 - val_loss: 1.6246 - val_accuracy: 0.3105
# Epoch 3/10
# 40/40 [==============================] - 2s 39ms/step - loss: 0.4703 - accuracy: 0.8405 - val_loss: 1.7445 - val_accuracy: 0.3633
# Epoch 4/10
# 40/40 [==============================] - 2s 39ms/step - loss: 0.3902 - accuracy: 0.8698 - val_loss: 1.9912 - val_accuracy: 0.3789
# Epoch 4: early stopping

# %%
metrics = history.history
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
plt.plot(history.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.ylim([0, max(plt.ylim())])
plt.xlabel('Epoch')
plt.ylabel('Loss [CrossEntropy]')

plt.subplot(1,2,2)
plt.plot(history.epoch, 100*np.array(metrics['accuracy']), 100*np.array(metrics['val_accuracy']))
plt.legend(['accuracy', 'val_accuracy'])
plt.ylim([0, 100])
plt.xlabel('Epoch')
plt.ylabel('Accuracy [%]')
# Out:
# Text(0, 0.5, 'Accuracy [%]')

# %% [markdown]
# ### Evaluate the model

# %%
model2.evaluate(test_spectrogram_ds, return_dict=True)
# Out:
# 6/6 [==============================] - 0s 8ms/step - loss: 2.0983 - accuracy: 0.3568
# {'loss': 2.0982983112335205, 'accuracy': 0.3567708432674408}

# %%
y_pred = model2.predict(test_spectrogram_ds)
y_pred = tf.argmax(y_pred, axis=1)
# Out:
# 6/6 [==============================] - 0s 8ms/step

# %%
y_true = tf.concat(list(test_spectrogram_ds.map(lambda s,lab: lab)), axis=0)

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_mtx,
            xticklabels=label_names,
            yticklabels=label_names,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %% [markdown]
# ## Model 3

# %%
model3 = models.Sequential([
    layers.Input(shape=input_shape),
    layers.Conv2D(32, 3, activation='relu', dilation_rate=(2, 2)),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, activation='relu', dilation_rate=(2, 2)),
    layers.MaxPooling2D(),
    layers.Conv2D(128, 3, activation='relu', dilation_rate=(2, 2)),
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(num_labels),
])

# %%
model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 120, 125, 32)      320
#
#  max_pooling2d_3 (MaxPoolin  (None, 60, 62, 32)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 56, 58, 64)        18496
#
#  max_pooling2d_4 (MaxPoolin  (None, 28, 29, 64)        0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 24, 25, 128)       73856
#
#  global_average_pooling2d (  (None, 128)               0
#  GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 128)               16512
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 109958 (429.52 KB)
# Trainable params: 109958 (429.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model3.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)

# %%
EPOCHS = 10
history = model3.fit(
    train_spectrogram_ds,
    validation_data=val_spectrogram_ds,
    epochs=EPOCHS,
    callbacks=tf.keras.callbacks.EarlyStopping(verbose=1, patience=2),
)
# Out:
# Epoch 1/10
# 45/45 [==============================] - 29s 628ms/step - loss: 1.7431 - accuracy: 0.2149 - val_loss: 1.6141 - val_accuracy: 0.3274
# Epoch 2/10
# 45/45 [==============================] - 30s 661ms/step - loss: 1.3581 - accuracy: 0.4750 - val_loss: 1.2013 - val_accuracy: 0.5446
# Epoch 3/10
# 45/45 [==============================] - 30s 662ms/step - loss: 1.0733 - accuracy: 0.6007 - val_loss: 1.0580 - val_accuracy: 0.5923
# Epoch 4/10
# 45/45 [==============================] - 32s 705ms/step - loss: 0.9482 - accuracy: 0.6510 - val_loss: 0.9867 - val_accuracy: 0.6190
# Epoch 5/10
# 45/45 [==============================] - 32s 722ms/step - loss: 0.8923 - accuracy: 0.6812 - val_loss: 0.9554 - val_accuracy: 0.6101
# Epoch 6/10
# 45/45 [==============================] - 32s 716ms/step - loss: 0.8445 - accuracy: 0.6934 - val_loss: 0.9236 - val_accuracy: 0.6429
# Epoch 7/10
# 45/45 [==============================] - 31s 699ms/step - loss: 0.7996 - accuracy: 0.7160 - val_loss: 0.9121 - val_accuracy: 0.6845
# Epoch 8/10
# 45/45 [==============================] - 33s 727ms/step - loss: 0.7671 - accuracy: 0.7250 - val_loss: 0.8617 - val_accuracy: 0.6786
# Epoch 9/10
# 45/45 [==============================] - 32s 707ms/step - loss: 0.7254 - accuracy: 0.7424 - val_loss: 0.8672 - val_accuracy: 0.6815
# Epoch 10/10
# 45/45 [==============================] - 32s 709ms/step - loss: 0.7080 - accuracy: 0.7434 - val_loss: 0.8422 - val_accuracy: 0.7054

# %%
metrics = history.history
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
plt.plot(history.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.ylim([0, max(plt.ylim())])
plt.xlabel('Epoch')
plt.ylabel('Loss [CrossEntropy]')

plt.subplot(1,2,2)
plt.plot(history.epoch, 100*np.array(metrics['accuracy']), 100*np.array(metrics['val_accuracy']))
plt.legend(['accuracy', 'val_accuracy'])
plt.ylim([0, 100])
plt.xlabel('Epoch')
plt.ylabel('Accuracy [%]')
# Out:
# Text(0, 0.5, 'Accuracy [%]')

# %% [markdown]
# ### Evaluate the model

# %%
model3.evaluate(test_spectrogram_ds, return_dict=True)
# Out:
# 6/6 [==============================] - 1s 246ms/step - loss: 0.6487 - accuracy: 0.7526
# {'loss': 0.6486705541610718, 'accuracy': 0.7526041865348816}

# %%
y_pred = model3.predict(test_spectrogram_ds)
y_pred = tf.argmax(y_pred, axis=1)
# Out:
# 6/6 [==============================] - 2s 251ms/step

# %%
y_true = tf.concat(list(test_spectrogram_ds.map(lambda s,lab: lab)), axis=0)

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_mtx,
            xticklabels=label_names,
            yticklabels=label_names,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %% [markdown]
# ## Model 4

# %%
train_spectrogram_ds = train_spectrogram_ds.map(lambda x, y: (tf.image.grayscale_to_rgb(x), y))
val_spectrogram_ds = val_spectrogram_ds.map(lambda x, y: (tf.image.grayscale_to_rgb(x), y))

# %%
input_shape = (124, 129, 3) 
base_model = tf.keras.applications.MobileNetV2(
    input_shape=input_shape, include_top=False, weights='imagenet')
base_model.trainable = False

model4 = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(num_labels),
])
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
model4.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Func  (None, 4, 5, 1280)        2257984
#  tional)
#
#  global_average_pooling2d_1  (None, 1280)              0
#   (GlobalAveragePooling2D)
#
#  dense_6 (Dense)             (None, 128)               163968
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 2422726 (9.24 MB)
# Trainable params: 164742 (643.52 KB)
# Non-trainable params: 2257984 (8.61 MB)
# _________________________________________________________________

# %%
model4.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)

# %%
EPOCHS = 10
history = model4.fit(
    train_spectrogram_ds,
    validation_data=val_spectrogram_ds,
    epochs=EPOCHS,
    callbacks=tf.keras.callbacks.EarlyStopping(verbose=1, patience=2),
)
# Out:
# Epoch 1/10
# 45/45 [==============================] - 20s 349ms/step - loss: 1.3112 - accuracy: 0.5132 - val_loss: 0.9246 - val_accuracy: 0.6518
# Epoch 2/10
# 45/45 [==============================] - 14s 319ms/step - loss: 0.8616 - accuracy: 0.6892 - val_loss: 0.7472 - val_accuracy: 0.7470
# Epoch 3/10
# 45/45 [==============================] - 14s 323ms/step - loss: 0.7358 - accuracy: 0.7427 - val_loss: 0.6727 - val_accuracy: 0.7738
# Epoch 4/10
# 45/45 [==============================] - 15s 325ms/step - loss: 0.6811 - accuracy: 0.7531 - val_loss: 0.6319 - val_accuracy: 0.7679
# Epoch 5/10
# 45/45 [==============================] - 15s 325ms/step - loss: 0.6111 - accuracy: 0.7767 - val_loss: 0.6026 - val_accuracy: 0.7798
# Epoch 6/10
# 45/45 [==============================] - 15s 327ms/step - loss: 0.5833 - accuracy: 0.7899 - val_loss: 0.5624 - val_accuracy: 0.7917
# Epoch 7/10
# 45/45 [==============================] - 15s 327ms/step - loss: 0.5271 - accuracy: 0.8149 - val_loss: 0.5580 - val_accuracy: 0.8065
# Epoch 8/10
# 45/45 [==============================] - 15s 331ms/step - loss: 0.5131 - accuracy: 0.8135 - val_loss: 0.5453 - val_accuracy: 0.7946
# Epoch 9/10
# 45/45 [==============================] - 15s 330ms/step - loss: 0.4735 - accuracy: 0.8368 - val_loss: 0.5210 - val_accuracy: 0.8095
# Epoch 10/10
# 45/45 [==============================] - 15s 327ms/step - loss: 0.4700 - accuracy: 0.8403 - val_loss: 0.5606 - val_accuracy: 0.7946

# %%
metrics = history.history
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
plt.plot(history.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.ylim([0, max(plt.ylim())])
plt.xlabel('Epoch')
plt.ylabel('Loss [CrossEntropy]')

plt.subplot(1,2,2)
plt.plot(history.epoch, 100*np.array(metrics['accuracy']), 100*np.array(metrics['val_accuracy']))
plt.legend(['accuracy', 'val_accuracy'])
plt.ylim([0, 100])
plt.xlabel('Epoch')
plt.ylabel('Accuracy [%]')
# Out:
# Text(0, 0.5, 'Accuracy [%]')

# %% [markdown]
# ### Evaluate the model

# %%
model4.evaluate(val_spectrogram_ds, return_dict=True)
# Out:
# 6/6 [==============================] - 1s 235ms/step - loss: 0.5606 - accuracy: 0.7946
# {'loss': 0.5606337785720825, 'accuracy': 0.7946428656578064}

# %%
y_pred = model4.predict(val_spectrogram_ds)
y_pred = tf.argmax(y_pred, axis=1)
# Out:
# 6/6 [==============================] - 2s 221ms/step

# %%
y_true = tf.concat(list(val_spectrogram_ds.map(lambda s,lab: lab)), axis=0)

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_mtx,
            xticklabels=label_names,
            yticklabels=label_names,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %% [markdown]
# # Exporting a model

# %% [markdown]
# ## Export the model with preprocessing

# %%
class ExportModel(tf.Module):
  def __init__(self, model):
    self.model = model

    # Accept either a string-filename or a batch of waveforms.
    # YOu could add additional signatures for a single wave, or a ragged-batch.
    self.__call__.get_concrete_function(
        x=tf.TensorSpec(shape=(), dtype=tf.string))
    self.__call__.get_concrete_function(
       x=tf.TensorSpec(shape=[None, 16000], dtype=tf.float32))


  @tf.function
  def __call__(self, x):
    # If they pass a string, load the file and decode it.
    if x.dtype == tf.string:
      x = tf.io.read_file(x)
      x, _ = tf.audio.decode_wav(x, desired_channels=1, desired_samples=16000,)
      x = tf.squeeze(x, axis=-1)
      x = x[tf.newaxis, :]

    x = get_spectrogram(x)
    result = self.model(x, training=False)

    class_ids = tf.argmax(result, axis=-1)
    class_names = tf.gather(label_names, class_ids)
    return {'predictions':result,
            'class_ids': class_ids,
            'class_names': class_names}

# %%
export = ExportModel(model)
export(tf.constant(str('own/ddyo/audio #2001.wav')))
# Out:
# {'predictions': <tf.Tensor: shape=(1, 6), dtype=float32, numpy=
#  array([[-118.83273  ,    3.0168517,  349.7217   ,  -80.65847  ,
#            25.569756 , -174.36504  ]], dtype=float32)>,
#  'class_ids': <tf.Tensor: shape=(1,), dtype=int64, numpy=array([2])>,
#  'class_names': <tf.Tensor: shape=(1,), dtype=string, numpy=array([b'gaali'], dtype=object)>}

# %% [markdown]
# Save and reload the model, the reloaded model gives identical output:

# %%
tf.saved_model.save(export, "saved")
imported = tf.saved_model.load("saved")
imported(waveform[tf.newaxis, :])
# Out:
# INFO:tensorflow:Assets written to: saved/assets
# INFO:tensorflow:Assets written to: saved/assets
# {'class_ids': <tf.Tensor: shape=(1,), dtype=int64, numpy=array([3])>,
#  'class_names': <tf.Tensor: shape=(1,), dtype=string, numpy=array([b'kkono'], dtype=object)>,
#  'predictions': <tf.Tensor: shape=(1, 6), dtype=float32, numpy=
#  array([[-2.153601 , -0.9881042,  0.6586656, 13.002021 , -4.809059 ,
#          -3.7743418]], dtype=float32)>}
